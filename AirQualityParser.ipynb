# %%
from bs4 import BeautifulSoup
import requests
import re
from datetime import datetime
import pandas as pd

#url to scrape for one location and 6 months
url='https://airquality.ie/readings?station=EPA-25&dateFrom=01+Jan+2023&dateTo=30+Jun+2023'
#create content to scrape
r = requests.get(url)
#get webpage
soup = BeautifulSoup(r.content, 'html.parser')
#print response
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <title>Readings | AirQuality.ie</title>
# <meta content="Charts from Ireland's EPA showing average particulate and gas readings from monitoring stations taken at regular intervals throughout the day. Select a monitoring station and date range to view data." name="description"/>
# <!-- Global site tag (gtag.js) - Google Analytics -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-28794554-3"></script>
# <script>
#     window.dataLayer = window.dataLayer || [];
#     function gtag(){dataLayer.push(arguments);}
#     gtag('js', new Date());
#     gtag('config', "UA-28794554-3");
#   </script>
# <!-- Required Meta Tags -->
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/>
# <meta content="ie=edge" http-equiv="x-ua-compatible"/>
# <meta content="air quality ireland, air pollution, air quality index, air qualities, air quality monitoring, air pollution map, air quality map, air quality sensor, air monitoring, environment monitoring system, Environmental Protection Agency, EPA, outdoor air quality monitor, outdoor air quality monitors, air pollution data by county, air quality by county, air quality index for health, AQIH, PM10, particulate matter, suspended particulate matter, atmospheric particulate matter, atmospheric aerosol particles, particulate matter (PM), particulates, PM2.5, NO2, Nitogen Dioxide, Ozone, Sulphur Dioxide, nitrogen oxides, SO2, NOx, O3, Nitrogen Dioxide Diffusion Tube, Nitrogen Dioxide Diffusion Tubes, Diffusion Tube, Diffusion Tubes, Sonitus, Sonitus Systems, environment, air, lung, breathing, asthma, WHO Air Quality Guidelines, Solid fuel, Turnkey Osiris, Palas Fidas, S.I. 180, Ambient Air Quality and Cleaner Air for Europe Directive 2008/50/EC, 2004/107/EC, AAQD, AAQ, average exposure indicator (AEI), smoke, EN/ISO 17025, air monitoring equipments, air monitoring instruments, air monitoring methods, air monitoring ppt, air monitoring station, air pollution checker, air pollution control measures, air pollution data, air pollution detector, air pollution figures, air pollution graph, air pollution index, air pollution index by city, air pollution information, air pollution levels, air pollution measure, air pollution measurement device, air pollution measurement unit, air pollution measuring instruments, air pollution meter, air pollution monitoring, air pollution monitoring devices, air pollution monitoring methods, air pollution monitoring sensors, air pollution monitoring system, air pollution quality, air pollution report, air pollution reports, air pollution sensor, air quality analyser, air quality analyzer, air quality and pollution, air quality aqi, air quality assessment, air quality assurance, air quality data, air quality data set, air quality detector, air quality device, air quality for today, air quality forecasting, air quality historical data, air quality index calculation, air quality index data, air quality index map, air quality index meter, air quality information, air quality instrument, air quality iot, air quality levels, air quality measure, air quality measure device, air quality measurement units, air quality meters, air quality monitor app, air quality monitoring data, air quality monitoring device, air quality monitoring instruments, air quality monitoring methods, air quality monitoring report, air quality monitoring sensors, air quality monitoring station, air quality monitoring system, air quality network, air quality project, air quality reader, air quality report, air quality sampling, air quality station, air quality survey, ambient air monitor, ambient air monitoring station, ambient air pollution, ambient air quality, ambient air quality monitoring, ambient air quality monitoring station, ambient air sampling, ambient monitoring, ambient monitoring system, aqi data, aqi historical data, aqi map, aqi monitor, atmospheric monitoring, current air conditions, current air pollution, current air quality, environmental air monitoring, environmental pollution data, environmental quality monitoring, epa air quality map, epa air quality monitoring, instrument used to measure air pollution, measure air quality, monitor air, monitoring pollution, national air quality monitoring programme, national ambient air quality monitoring programme, particulate monitor, pollution data, pollution measurement, pollution measurement device, pollution measuring instruments, pollution measuring unit, pollution meter, pollution monitoring devices, pollution sensor, quality station, real time air pollution, real time air quality, real time air quality monitoring, smart air quality monitor, smart air quality sensor, ways to measure air pollution, air monitoring sensors, air pollution, air pollution checking device, air pollu ...
# <meta content="Sonitus Systems" name="author"/>
# <!-- Favicon -->
# <link href="../favicon.ico" rel="shortcut icon"/>
# <!-- Google Fonts -->
# <link href="//fonts.googleapis.com/css?family=Open+Sans%3A400%2C300%2C500%2C600%2C700%7CPlayfair+Display%7CRoboto%7CRaleway%7CSpectral%7CRubik" rel="stylesheet"/>
# <!-- CSS Global Compulsory -->
# <link href="/assets/vendor/bootstrap/bootstrap.min.css" rel="stylesheet"/>
# <!-- CSS Global Icons -->
# <link href="/assets/vendor/icon-awesome/css/font-awesome.min.css" rel="stylesheet"/>
# <link href="/assets/vendor/icon-line/css/simple-line-icons.css" rel="stylesheet"/>
# <link href="/assets/vendor/icon-etlinefont/style.css" rel="stylesheet"/>
# <link href="/assets/vendor/icon-line-pro/style.css" rel="stylesheet"/>
# <link href="/assets/vendor/icon-hs/style.css" rel="stylesheet"/>
# <link href="/assets/vendor/hs-admin-icons/hs-admin-icons.css" rel="stylesheet"/>
# <link href="/assets/vendor/animate.css" rel="stylesheet"/>
# <link href="/assets/vendor/malihu-scrollbar/jquery.mCustomScrollbar.min.css" rel="stylesheet"/>
# <link href="/assets/vendor/flatpickr/dist/css/flatpickr.min.css" rel="stylesheet"/>
# <link href="/assets/vendor/bootstrap-select/css/bootstrap-select.min.css" rel="stylesheet"/>
# <link href="/assets/vendor/fancybox/jquery.fancybox.min.css" rel="stylesheet"/>
# <link href="/assets/vendor/hamburgers/hamburgers.min.css" rel="stylesheet"/>
# <!-- CSS Unify -->
# <link href="/assets/css/unify-admin.min.css" rel="stylesheet"/>
# <!-- CSS Customisation -->
# <link href="/assets/css/custom.css" rel="stylesheet"/>
# <!-- EPA CSS -->
# <link href="/assets/css/epa.css" rel="stylesheet"/>
# <!-- Cookie Consent -->
# <link href="/assets/css/cookie-consent.min.css" rel="stylesheet" type="text/css">
# <link href="../../assets/vendor/icon-material/material-icons.css" rel="stylesheet"/>
# </link></head>
# <body>
# <!-- Header -->
# <header class="u-header u-header--sticky-top" id="js-header">
# <div class="u-header__section u-header__section--admin-light u-shadow-v18 g-min-height-100">
# <nav class="navbar no-gutters g-pa-0">
# <div class="col-auto d-flex flex-nowrap u-header-logo-toggler g-py-12">
# <!-- Logo -->
# <a class="navbar-brand d-flex align-self-center g-hidden-xs-down g-line-height-1 py-0" href="https://www.epa.ie" title="Go to EPA Homepage">
# <img alt="EPA Logo" src="/assets/img/logos/epa.jpg"/>
# </a>
# <!-- End Logo -->
# <!-- Sidebar Toggler -->
# <a class="js-side-nav u-header__nav-toggler d-flex align-self-center ml-auto" data-hssm-body-class="u-side-nav-mini" data-hssm-class="u-side-nav--mini u-sidebar-navigation-v1--mini" data-hssm-is-close-all-except-this="true" data-hssm-target="#sideNav" href="#!">
# <i class="hs-admin-align-left"></i>
# </a>
# <!-- End Sidebar Toggler -->
# </div>
# <!-- Mobile Logo -->
# <div class="col-auto d-flex d-sm-none flex-nowrap" id="mobile-logo-container">
# <a class="navbar-brand d-flex align-self-center g-line-height-1 py-0" href="https://www.epa.ie" title="Go to EPA Homepage">
# <img alt="EPA Logo" src="/assets/img/logos/epa.jpg"/>
# </a>
# </div>
# <!-- End Mobile Logo -->
# <!-- Site Title -->
# <div class="mr-auto g-font-size-17 g-font-weight-300" id="site-title">
#           AirQuality.ie        </div>
# <!-- End Site Title -->
# </nav>
# </div><!-- ./u-header -->
# </header>
# <!-- End Header -->
# <main>
# <section class="container-fluid px-0 g-pt-110">
# <div class="row no-gutters g-pos-rel g-overflow-x-hidden">
# <!-- Sidebar Nav -->
# <div class="col-auto u-sidebar-navigation-v1 u-sidebar-navigation--dark" id="sideNav">
# <ul class="u-sidebar-navigation-v1-menu u-side-nav--top-level-menu g-min-height-100vh mb-0 g-mt-8" id="sideNavMenu">
# <!-- Home -->
# <li class="u-sidebar-navigation-v1-menu-item u-side-nav--top-level-menu-item">
# <a class="media u-side-nav--top-level-menu-link u-side-nav--hide-on-hidden g-px-15 g-py-12" href="/" title="Home">
# <span class="d-flex align-self-center g-pos-rel g-font-size-18 g-mr-18">
# <i class="hs-admin-home"></i>
# </span>
# <span class="media-body align-self-center">Home</span>
# </a>
# </li>
# <!-- End Home -->
# <!-- Stations -->
# <li class="u-sidebar-navigation-v1-menu-item u-side-nav--top-level-menu-item">
# <a class="media u-side-nav--top-level-menu-link u-side-nav--hide-on-hidden g-px-15 g-py-12" href="/stations" title="Stations">
# <span class="d-flex align-self-center g-pos-rel g-font-size-18 g-mr-18">
# <i class="hs-admin-location-pin"></i>
# </span>
# <span class="media-body align-self-center">Stations</span>
# </a>
# </li>
# <!-- End Stations -->
# <!-- Calendar -->
# <li class="u-sidebar-navigation-v1-menu-item u-side-nav--top-level-menu-item">
# <a class="media u-side-nav--top-level-menu-link u-side-nav--hide-on-hidden g-px-15 g-py-12" href="/calendar" title="Calendar">
# <span class="d-flex align-self-center g-pos-rel g-font-size-18 g-mr-18">
# <i class="hs-admin-calendar"></i>
# </span>
# <span class="media-body align-self-center">Calendar</span>
# </a>
# </li>
# <!-- End Calendar -->
# <!-- Readings -->
# <li class="u-sidebar-navigation-v1-menu-item u-side-nav--top-level-menu-item">
# <a class="media u-side-nav--top-level-menu-link u-side-nav--hide-on-hidden g-px-15 g-py-12 active" href="/readings" title="Readings">
# <span class="d-flex align-self-center g-pos-rel g-font-size-18 g-mr-18">
# <i class="hs-admin-bar-chart"></i>
# </span>
# <span class="media-body align-self-center">Readings</span>
# </a>
# </li>
# <!-- End Readings -->
# <!-- Annual Maps -->
# <li class="u-sidebar-navigation-v1-menu-item u-side-nav--top-level-menu-item">
# <a class="media u-side-nav--top-level-menu-link u-side-nav--hide-on-hidden g-px-15 g-py-12" href="/annual-maps" title="Annual Maps">
# <span class="d-flex align-self-center g-pos-rel g-font-size-18 g-mr-18">
# <i class="hs-admin-time"></i>
# </span>
# <span class="media-body align-self-center">Annual Maps</span>
# </a>
# </li>
# <!-- End Annual Maps -->
# <!-- Info -->
# <li class="u-sidebar-navigation-v1-menu-item u-side-nav--has-sub-menu u-side-nav--top-level-menu-item">
# <a class="media u-side-nav--top-level-menu-link u-side-nav--hide-on-hidden g-px-15 g-py-12" data-hssm-target="#info-submenu" href="#!" title="Information">
# <span class="d-flex align-self-center g-pos-rel g-font-size-18 g-mr-18">
# <i class="hs-admin-info-alt"></i>
# </span>
# <span class="media-body align-self-center">Information</span>
# <span class="d-flex align-self-center u-side-nav--control-icon">
# <i class="hs-admin-angle-right"></i>
# </span>
# <span class="u-side-nav--has-sub-menu__indicator"></span>
# </a>
# <!-- Submenu -->
# <ul class="u-sidebar-navigation-v1-menu u-side-nav--second-level-menu mb-0" id="info-submenu">
# <li class="u-sidebar-navigation-v1-menu-item u-side-nav--second-level-menu-item">
# <a class="media u-side-nav--second-level-menu-link g-px-15 g-py-12" href="/information/air-quality-index-for-health">
# <span class="media-body align-self-center">Air Quality Index for Health</span>
# </a>
# </li>
# <li class="u-sidebar-navigation-v1-menu-item u-side-nav--second-level-menu-item">
# <a class="media u-side-nav--second-level-menu-link g-px-15 g-py-12" href="/information/air-quality-standards">
# <span class="media-body align-self-center">Air Quality Standards</span>
# </a>
# </li>
# <li class="u-sidebar-navigation-v1-menu-item u-side-nav--second-level-menu-item">
# <a class="media u-side-nav--second-level-menu-link g-px-15 g-py-12" href="/information/what-we-monitor">
# <span class="media-body align-self-center">What We Monitor</span>
# </a>
# </li>
# <li class="u-sidebar-navigation-v1-menu-item u-side-nav--second-level-menu-item">
# <a class="media u-side-nav--second-level-menu-link g-px-15 g-py-12" href="/information/for-health-professionals">
# <span class="media-body align-self-center">For Health Professionals</span>
# </a>
# </li>
# <li class="u-sidebar-navigation-v1-menu-item u-side-nav--second-level-menu-item">
# <a class="media u-side-nav--second-level-menu-link g-px-15 g-py-12" href="/information/air-quality-zones">
# <span class="media-body align-self-center">Air Quality Zones</span>
# </a>
# </li>
# <li class="u-sidebar-navigation-v1-menu-item u-side-nav--second-level-menu-item">
# <a class="media u-side-nav--second-level-menu-link g-px-15 g-py-12" href="https://www.epa.ie/environment-and-you/air/faqs/" target="_blank">
# <span class="media-body align-self-center">FAQs</span>
# </a>
# </li>
# <li class="u-sidebar-navigation-v1-menu-item u-side-nav--second-level-menu-item">
# <a class="media u-side-nav--second-level-menu-link g-px-15 g-py-12" href="https://www.epa.ie/environment-and-you/air/life-emerald/" target="_blank">
# <span class="media-body align-self-center">Life Emerald</span>
# </a>
# </li>
# <li class="u-sidebar-navigation-v1-menu-item u-side-nav--second-level-menu-item">
# <a class="media u-side-nav--second-level-menu-link g-px-15 g-py-12" href="https://www.epa.ie/publications/monitoring--assessment/air/" target="_blank">
# <span class="media-body align-self-center">Reports</span>
# </a>
# </li>
# <li class="u-sidebar-navigation-v1-menu-item u-side-nav--second-level-menu-item">
# <a class="media u-side-nav--second-level-menu-link g-px-15 g-py-12" href="/information/air-quality-bulletins">
# <span class="media-body align-self-center">Air Quality Bulletins</span>
# </a>
# </li>
# <li class="u-sidebar-navigation-v1-menu-item u-side-nav--second-level-menu-item">
# <a class="media u-side-nav--second-level-menu-link g-px-15 g-py-12" href="https://www.epa.ie/environment-and-you/air/diffusion-tube-results/" target="_blank">
# <span class="media-body align-self-center">Diffusion Tube Results</span>
# </a>
# </li>
# <li class="u-sidebar-navigation-v1-menu-item u-side-nav--second-level-menu-item">
# <a class="media u-side-nav--second-level-menu-link g-px-15 g-py-12" href="https://eparesearch.epa.ie/safer/" target="_blank">
# <span class="media-body align-self-center">Historical Monitoring Results</span>
# </a>
# </li>
# </ul>
# <!-- Submenu -->
# </li>
# <!-- End Info -->
# </ul>
# </div>
# <!-- End Sidebar Nav -->
# <div class="col g-ml-45 g-ml-0--lg g-pb-65--md">
# <div class="g-hidden-sm-down g-pa-20" id="breadcrumb">
# <ul class="u-list-inline g-color-gray-dark-v6">
# <li class="list-inline-item g-mr-10">
# <a class="u-link-v5 g-color-gray-dark-v6 g-color-secondary--hover g-valign-middle" href="/">Home</a>
# <i class="hs-admin-angle-right g-font-size-12 g-color-gray-light-v6 g-valign-middle g-ml-10"></i>
# </li>
# <li class="list-inline-item">
# <span class="g-valign-middle">Readings</span>
# </li>
# </ul>
# </div>
# <div class="g-pa-20">
# <h1 class="g-font-weight-300 g-font-size-28 g-color-black g-mb-30">Readings</h1>
# <div class="row">
# <div class="col-md-10 g-mb-30 g-mb-0--md">
# <p class="lead g-mb-40 g-color-gray-dark-v3">
#                   The charts below show the average particulate and gas readings collected by the monitoring stations. Measurements are recorded at regular intervals throughout the day. You can select a date range to look at how levels change over time.
#                 </p>
# <form action="" class="js-validate g-brd-around g-brd-gray-light-v4 g-pa-20 g-mb-30" id="readings-form" method="get">
# <div class="row">
# <!-- Station Select -->
# <div class="col-md-4 g-mb-10">
# <label class="g-mb-10">Station</label>
# <div class="form-group u-select--v3 g-pos-rel g-brd-gray-light-v7 g-rounded-4 mb-0">
# <select class="no-display js-select u-select--v3-select u-sibling w-100" id="station" name="station" required="required">
# <option data-content="&lt;span class='d-flex align-items-center w-100'&gt;&lt;span&gt;Carlow Town&lt;/span&gt;&lt;/span&gt;" value="EPA-54">
#                             Carlow Town                          </option>
# <option data-content="&lt;span class='d-flex align-items-center w-100'&gt;&lt;span&gt;Cavan Town&lt;/span&gt;&lt;/span&gt;" value="EPA-78">
#                             Cavan Town                          </option>
# <option data-content="&lt;span class='d-flex align-items-center w-100'&gt;&lt;span&gt;Ennis, Co. Clare&lt;/span&gt;&lt;/span&gt;" selected="selected" value="EPA-25">
#                             Ennis, Co. Clare                          </option>
# <option data-content="&lt;span class='d-flex align-items-center w-100'&gt;&lt;span&gt;Ennistymon, Co. Clare&lt;/span&gt;&lt;/span&gt;" value="TNO3947">
#                             Ennistymon, Co. Clare                          </option>
# <option data-content="&lt;span class='d-flex align-items-center w-100'&gt;&lt;span&gt;Carrigaline, Co. Cork&lt;/span&gt;&lt;/span&gt;" value="EPA-88">
#                             Carrigaline, Co. Cork                          </option>
# <option data-content="&lt;span class='d-flex align-items-center w-100'&gt;&lt;span&gt;Clonakilty, Co. Cork&lt;/span&gt;&lt;/span&gt;" value="EPA-89">
#                             Clonakilty, Co. Cork                          </option>
# <option data-content="&lt;span class='d-flex align-items-center w-100'&gt;&lt;span&gt;Cobh Carrignafoy, Co. Cork&lt;/span&gt;&lt;/span&gt;" value="EPA-60">
#                             Cobh Carrignafoy, Co. Cork                          </option>
# <option data-content="&lt;span class='d-flex align-items-center w-100'&gt;&lt;span&gt;Munster Technological University, Cork&lt;/span&gt;&lt;/span&gt;" value="EPA-110">
#                             Munster Technological University, Cork                          </option>
# <option data-content="&lt;span class='d-flex align-items-center w-100'&gt;&lt;span&gt;Cork Airport&lt;/span&gt;&lt;/span&gt;" value="EPA-90">
#                             Cork Airport                          </option>
# <option data-content="&lt;span class='d-flex align-items-center w-100'&gt;&lt;span&gt;Cork Harbour&lt;/span&gt;&lt;/span&gt;" value="EPA-72">
#                             Cork Harbour                          </option>
# <option data-content="&lt;span class='d-flex align-items-center w-100'&gt;&lt;span&gt;Cork Lower Glanmire Road&lt;/span&gt;&lt;/span&gt;" value="EPA-104">
#                             Cork Lower Glanmire Road                          </option>
# <option data-content="&lt;span class='d-flex align-items-center w-100'&gt;&lt;span&gt;Heatherton Park, Cork&lt;/span&gt;&lt;/span&gt;" value="EPA-10">
#                             Heatherton Park, Cork                          </option>
# <option data-content="&lt;span class='d-flex align-items-center w-100'&gt;&lt;span&gt;Macroom, Co. Cork&lt;/span&gt;&lt;/span&gt;" value="EPA-67">
#                             Macroom, Co. Cork                          </option>
# <option data-content="&lt;span class='d-flex align-items-center w-100'&gt;&lt;span&gt;Mallow, Co. Cork&lt;/span&gt;&lt;/span&gt;" value="EPA-82">
#                             Mallow, Co. Cork                          </option>
# <option data-content="&lt;span class='d-flex align-items-center w-100'&gt;&lt;span&gt;Port of Cork&lt;/span&gt;&lt;/span&gt;" value="FIDAS-0110-000177-000000">
#                             Port of Cork                          </option>
# <option data-content="&lt;span class='d-flex align-items-center w-100'&gt;&lt;span&gt;South Link Road, Cork&lt;/span&gt;&lt;/span&gt;" value="EPA-56">
#                             South Link Road, Cork                          </option>
# <option data-content="&lt;span class='d-flex align-items-center w-100'&gt;&lt;span&gt;University College Cork&lt;/span&gt;&lt;/span&gt;" value="EPA-21">
#                             University College Cork                          </option>
# <option data-content="&lt;span class='d-flex align-items-center w-100'&gt;&lt;span&gt;Buncranna, Co. Donegal&lt;/span&gt;&lt;/span&gt;" value="TNO3955">
#                             Buncranna, Co. Donegal                          </option>
# <option data-content="&lt;span class='d-flex align-items-center w-100'&gt;&lt;span&gt;Letterkenny, Co. Donegal&lt;/span&gt;&lt;/span&gt;" value="EPA-64">
#                             Letterkenny, Co. Donegal                          </option>
# <option data-content="&lt;span class='d-flex align-items-center w-100'&gt;&lt;span&gt;Malin Head, Co. Donegal&lt;/span&gt;&lt;/span&gt;" value="EPA-27">
#                             Malin Head, Co. Donegal                          </option>
# <option data-content="&lt;span class='d-flex align-items-center w-100'&gt;&lt;span&gt;Amiens Street, Dublin 1&lt;/span&gt;&lt;/span&gt;" value="EPA-91">
#                             Amiens Street, Dublin 1                          </option>
# <option data-content="&lt;span class='d-flex align-items-center w-100'&gt;&lt;span&gt;Amiens Street, Dublin 1&lt;/span&gt;&lt;/span&gt;" value="TNO2579-EPA">
#                             Amiens Street, Dublin 1                          </option>
# <option data-content="&lt;span class='d-flex align-items-center w-100'&gt;&lt;span&gt;Ballyfermot, Dublin 10&lt;/span&gt;&lt;/span&gt;" value="EPA-50">
#                             Ballyfermot, Dublin 10                          </option>
# <option data-content="&lt;span class='d-flex align-items-center w-100'&gt;&lt;span&gt;Ballymun Library, Dublin 9&lt;/span&gt;&lt;/span&gt;" value="TNO4437-EPA">
#                             Ballymun Library, Dublin 9                          </option>
# <option data-content="&lt;span class='d-flex align-items-center w-100'&gt;&lt;span&gt;Blanchardstown, Dublin 15&lt;/span&gt;&lt;/span&gt;" value="EPA-29">
#                             Blanchardstown, Dublin 15                          </option>
# <option data-content="&lt;span class='d-flex align-items-center w-100'&gt;&lt;span&gt;Cabra Community College, Dublin 7&lt;/span&gt;&lt;/span&gt;" value="TNO4438-EPA">
#                             Cabra Community College, Dublin 7                          </option>
# <option data-content="&lt;span class='d-flex align-items-center w-100'&gt;&lt;span&gt;Clonskeagh, Dublin 14&lt;/span&gt;&lt;/span&gt;" value="EPA-33">
#                             Clonskeagh, Dublin 14                          </option>
# <option data-content="&lt;span class='d-flex align-items-center w-100'&gt;&lt;span&gt;Coolock, Dublin 5&lt;/span&gt;&lt;/span&gt;" value="TNO2162-EPA">
#                             Coolock, Dublin 5                          </option>
# <option data-content="&lt;span class='d-flex align-items-center w-100'&gt;&lt;span&gt;Custom House Quay, Dublin 1&lt;/span&gt;&lt;/span&gt;" value="TNO2161-EPA">
#                             Custom House Quay, Dublin 1                          </option>
# <option data-content="&lt;span class='d-flex align-items-center w-100'&gt;&lt;span&gt;Davitt Road, Inchicore, Dublin 12&lt;/span&gt;&lt;/span&gt;" value="EPA-49">
#                             Davitt Road, Inchicore, Dublin 12                          </option>
# <option data-content="&lt;span class='d-flex align-items-center w-100'&gt;&lt;span&gt;Deansgrange, Co. Dublin&lt;/span&gt;&lt;/span&gt;" value="TNO4158">
#                             Deansgrange, Co. Dublin                          </option>
# <option data-content="&lt;span class='d-flex align-items-center w-100'&gt;&lt;span&gt;Donnybrook Fire Station&lt;/span&gt;&lt;/span&gt;" value="DM30-00531-EPA">
#                             Donnybrook Fire Station                          </option>
# <option data-content="&lt;span class='d-flex align-items-center w-100'&gt;&lt;span&gt;Drumcondra Library, Dublin 9&lt;/span&gt;&lt;/span&gt;" value="TNO4435-EPA">
#                             Drumcondra Library, Dublin 9                          </option>
# <option data-content="&lt;span class='d-flex align-items-center w-100'&gt;&lt;span&gt;Dublin Airport, Swords, Co. Dublin&lt;/span&gt;&lt;/span&gt;" value="EPA-55">
#                             Dublin Airport, Swords, Co. Dublin                          </option>
# <option data-content="&lt;span class='d-flex align-items-center w-100'&gt;&lt;span&gt;Dublin Port, Dublin 1&lt;/span&gt;&lt;/span&gt;" value="EPA-76">
#                             Dublin Port, Dublin 1                          </option>
# <option data-content="&lt;span class='d-flex align-items-center w-100'&gt;&lt;span&gt;Dún Laoghaire, Co. Dublin&lt;/span&gt;&lt;/span&gt;" value="EPA-34">
#                             Dún Laoghaire, Co. Dublin                          </option>
# <option data-content="&lt;span class='d-flex align-items-center w-100'&gt;&lt;span&gt;Finglas, Dublin 11&lt;/span&gt;&lt;/span&gt;" value="EPA-46">
#                             Finglas, Dublin 11                          </option>
# <option data-content="&lt;span class='d-flex align-items-center w-100'&gt;&lt;span&gt;Kylemore, Dublin 10&lt;/span&gt;&lt;/span&gt;" value="AQG-0110-000180-000000-EPA">
#                             Kylemore, Dublin 10                          </option>
# <option data-content="&lt;span class='d-flex align-items-center w-100'&gt;&lt;span&gt;Lord Edward Street, Dublin 2&lt;/span&gt;&lt;/span&gt;" value="TNO4324-EPA">
#                             Lord Edward Street, Dublin 2                          </option>
# <option data-content="&lt;span class='d-flex align-items-center w-100'&gt;&lt;span&gt;Lucan, Co. Dublin&lt;/span&gt;&lt;/span&gt;" value="EPA-108">
#                             Lucan, Co. Dublin                          </option>
# <option data-content="&lt;span class='d-flex align-items-center w-100'&gt;&lt;span&gt;Marino, Dublin 3&lt;/span&gt;&lt;/span&gt;" value="EPA-47">
#                             Marino, Dublin 3                          </option>
# <option data-content="&lt;span class='d-flex align-items-center w-100'&gt;&lt;span&gt;Mountjoy Square, Dublin 1&lt;/span&gt;&lt;/span&gt;" value="AQG-0110-000157-000000-EPA">
#                             Mountjoy Square, Dublin 1                          </option>
# <option data-content="&lt;span class='d-flex align-items-center w-100'&gt;&lt;span&gt;Pearse Street, Dublin 2&lt;/span&gt;&lt;/span&gt;" value="EPA-69">
#                             Pearse Street, Dublin 2                          </option>
# <option data-content="&lt;span class='d-flex align-items-center w-100'&gt;&lt;span&gt;Phoenix Park, Dublin 8&lt;/span&gt;&lt;/span&gt;" value="EPA-48">
#                             Phoenix Park, Dublin 8                          </option>
# <option data-content="&lt;span class='d-flex align-items-center w-100'&gt;&lt;span&gt;Ringsend, Dublin 4&lt;/span&gt;&lt;/span&gt;" value="EPA-17">
#                             Ringsend, Dublin 4                          </option>
# <option data-content="&lt;span class='d-flex align-items-center w-100'&gt;&lt;span&gt;Rathmines, Dublin 6&lt;/span&gt;&lt;/span&gt;" value="EPA-22">
#                             Rathmines, Dublin 6                          </option>
# <option data-content="&lt;span class='d-flex align-items-center w-100'&gt;&lt;span&gt;Sandymount Green, Dublin 4&lt;/span&gt;&lt;/span&gt;" value="DM30-00530-EPA">
#                             Sandymount Green, Dublin 4                          </option>
# <option data-content="&lt;span class='d-flex align-items-center w-100'&gt;&lt;span&gt;St. Anne's Park, Dublin 5&lt;/span&gt;&lt;/span&gt;" value="EPA-52">
#                             St. Anne's Park, Dublin 5                          </option>
# <option data-content="&lt;span class='d-flex align-items-center w-100'&gt;&lt;span&gt;St. John’s Road, Kilmainham, Dublin 8&lt;/span&gt;&lt;/span&gt;" value="EPA-57">
#                             St. John’s Road, Kilmainham, Dublin 8                          </option>
# <option data-content="&lt;span class='d-flex align-items-center w-100'&gt;&lt;span&gt;Swords Council Depot, Co. Dublin&lt;/span&gt;&lt;/span&gt;" value="EPA-61">
#                             Swords Council Depot, Co. Dublin                          </option>
# <option data-content="&lt;span class='d-flex align-items-center w-100'&gt;&lt;span&gt;Tallaght, Dublin 24&lt;/span&gt;&lt;/span&gt;" value="EPA-44">
#                             Tallaght, Dublin 24                          </option>
# <option data-content="&lt;span class='d-flex align-items-center w-100'&gt;&lt;span&gt;TU Dublin, Dublin 7&lt;/span&gt;&lt;/span&gt;" value="TNO4390-EPA">
#                             TU Dublin, Dublin 7                          </option>
# <option data-content="&lt;span class='d-flex align-items-center w-100'&gt;&lt;span&gt;Walkinstown Library, Dublin 12&lt;/span&gt;&lt;/span&gt;" value="TNO4323-EPA">
#                             Walkinstown Library, Dublin 12                          </option>
# <option data-content="&lt;span class='d-flex align-items-center w-100'&gt;&lt;span&gt;Weaver Park, Dublin 8&lt;/span&gt;&lt;/span&gt;" value="AQG-15966">
#                             Weaver Park, Dublin 8                          </option>
# <option data-content="&lt;span class='d-flex align-items-center w-100'&gt;&lt;span&gt;Winetavern Street, Dublin 8&lt;/span&gt;&lt;/span&gt;" value="EPA-11">
#                             Winetavern Street, Dublin 8                          </option>
# <option data-content="&lt;span class='d-flex align-items-center w-100'&gt;&lt;span&gt;Ballinasloe, Co. Galway&lt;/span&gt;&lt;/span&gt;" value="EPA-92">
#                             Ballinasloe, Co. Galway                          </option>
# <option data-content="&lt;span class='d-flex align-items-center w-100'&gt;&lt;span&gt;Briarhill, Co. Galway&lt;/span&gt;&lt;/span&gt;" value="EPA-109">
#                             Briarhill, Co. Galway                          </option>
# <option data-content="&lt;span class='d-flex align-items-center w-100'&gt;&lt;span&gt;Eyre Square, Galway&lt;/span&gt;&lt;/span&gt;" value="EPA-105">
#                             Eyre Square, Galway                          </option>
# <option data-content="&lt;span class='d-flex align-items-center w-100'&gt;&lt;span&gt;Mace Head, Carna, Co. Galway&lt;/span&gt;&lt;/span&gt;" value="EPA-51">
#                             Mace Head, Carna, Co. Galway                          </option>
# <option data-content="&lt;span class='d-flex align-items-center w-100'&gt;&lt;span&gt;Tuam, Co. Galway&lt;/span&gt;&lt;/span&gt;" value="AQG-21140">
#                             Tuam, Co. Galway                          </option>
# <option data-content="&lt;span class='d-flex align-items-center w-100'&gt;&lt;span&gt;Killarney Anam Arts and Cultural Centre, Co. Kerry&lt;/span&gt;&lt;/span&gt;" value="EPA-107">
#                             Killarney Anam Arts and Cultural Centre, Co. Kerry                          </option>
# <option data-content="&lt;span class='d-flex align-items-center w-100'&gt;&lt;span&gt;Tralee Library, Co. Kerry&lt;/span&gt;&lt;/span&gt;" value="EPA-71">
#                             Tralee Library, Co. Kerry                          </option>
# <option data-content="&lt;span class='d-flex align-items-center w-100'&gt;&lt;span&gt;Valentia Observatory, Caherciveen, Co. Kerry&lt;/span&gt;&lt;/span&gt;" value="EPA-45">
#                             Valentia Observatory, Caherciveen, Co. Kerry                          </option>
# <option data-content="&lt;span class='d-flex align-items-center w-100'&gt;&lt;span&gt;Celbridge, Co. Kildare&lt;/span&gt;&lt;/span&gt;" value="AQG-21134">
#                             Celbridge, Co. Kildare                          </option>
# <option data-content="&lt;span class='d-flex align-items-center w-100'&gt;&lt;span&gt;Leixlip Library, Co. Kildare&lt;/span&gt;&lt;/span&gt;" value="EPA-106">
#                             Leixlip Library, Co. Kildare                          </option>
# <option data-content="&lt;span class='d-flex align-items-center w-100'&gt;&lt;span&gt;Naas, Co. Kildare&lt;/span&gt;&lt;/span&gt;" value="EPA-83">
#                             Naas, Co. Kildare                          </option>
# <option data-content="&lt;span class='d-flex align-items-center w-100'&gt;&lt;span&gt;Newbridge, Co. Kildare&lt;/span&gt;&lt;/span&gt;" value="AQG-21139">
#                             Newbridge, Co. Kildare                          </option>
# <option data-content="&lt;span class='d-flex align-items-center w-100'&gt;&lt;span&gt;Callan Road, Kilkenny&lt;/span&gt;&lt;/span&gt;" value="EPA-36">
#                             Callan Road, Kilkenny                          </option>
# <option data-content="&lt;span class='d-flex align-items-center w-100'&gt;&lt;span&gt;Thomastown, Co. Kilkenny&lt;/span&gt;&lt;/span&gt;" value="TNO4157">
#                             Thomastown, Co. Kilkenny                          </option>
# <option data-content="&lt;span class='d-flex align-items-center w-100'&gt;&lt;span&gt;Emo, Co. Laois&lt;/span&gt;&lt;/span&gt;" value="EPA-62">
#                             Emo, Co. Laois                          </option>
# <option data-content="&lt;span class='d-flex align-items-center w-100'&gt;&lt;span&gt;Mountrath, Co. Laois&lt;/span&gt;&lt;/span&gt;" value="AQG-21136">
#                             Mountrath, Co. Laois                          </option>
# <option data-content="&lt;span class='d-flex align-items-center w-100'&gt;&lt;span&gt;Portlaoise, Co. Laois&lt;/span&gt;&lt;/span&gt;" value="EPA-16">
#                             Portlaoise, Co. Laois                          </option>
# <option data-content="&lt;span class='d-flex align-items-center w-100'&gt;&lt;span&gt;Carrick-on-Shannon, Co. Leitrim&lt;/span&gt;&lt;/span&gt;" value="EPA-80">
#                             Carrick-on-Shannon, Co. Leitrim                          </option>
# <option data-content="&lt;span class='d-flex align-items-center w-100'&gt;&lt;span&gt;Abbeyfeale, Limerick&lt;/span&gt;&lt;/span&gt;" value="TNO3951">
#                             Abbeyfeale, Limerick                          </option>
# <option data-content="&lt;span class='d-flex align-items-center w-100'&gt;&lt;span&gt;Askeaton, Co. Limerick&lt;/span&gt;&lt;/span&gt;" value="EPA-74">
#                             Askeaton, Co. Limerick                          </option>
# <option data-content="&lt;span class='d-flex align-items-center w-100'&gt;&lt;span&gt;Castletroy, Limerick&lt;/span&gt;&lt;/span&gt;" value="TNO3840">
#                             Castletroy, Limerick                          </option>
# <option data-content="&lt;span class='d-flex align-items-center w-100'&gt;&lt;span&gt;Henry Street, Limerick&lt;/span&gt;&lt;/span&gt;" value="EPA-85">
#                             Henry Street, Limerick                          </option>
# <option data-content="&lt;span class='d-flex align-items-center w-100'&gt;&lt;span&gt;Mungret, Co. Limerick&lt;/span&gt;&lt;/span&gt;" value="TNO3841">
#                             Mungret, Co. Limerick                          </option>
# <option data-content="&lt;span class='d-flex align-items-center w-100'&gt;&lt;span&gt;O'Connell St, Limerick&lt;/span&gt;&lt;/span&gt;" value="TNO3839">
#                             O'Connell St, Limerick                          </option>
# <option data-content="&lt;span class='d-flex align-items-center w-100'&gt;&lt;span&gt;People's Park, Limerick&lt;/span&gt;&lt;/span&gt;" value="EPA-39">
#                             People's Park, Limerick                          </option>
# <option data-content="&lt;span class='d-flex align-items-center w-100'&gt;&lt;span&gt;Longford Town&lt;/span&gt;&lt;/span&gt;" value="EPA-43">
#                             Longford Town                          </option>
# <option data-content="&lt;span class='d-flex align-items-center w-100'&gt;&lt;span&gt;Drogheda, Co. Louth&lt;/span&gt;&lt;/span&gt;" value="EPA-84">
#                             Drogheda, Co. Louth                          </option>
# <option data-content="&lt;span class='d-flex align-items-center w-100'&gt;&lt;span&gt;Dundalk, Co. Louth&lt;/span&gt;&lt;/span&gt;" value="EPA-23">
#                             Dundalk, Co. Louth                          </option>
# <option data-content="&lt;span class='d-flex align-items-center w-100'&gt;&lt;span&gt;Achill Island, Co. Mayo&lt;/span&gt;&lt;/span&gt;" value="AQG-19334">
#                             Achill Island, Co. Mayo                          </option>
# <option data-content="&lt;span class='d-flex align-items-center w-100'&gt;&lt;span&gt;Ballina, Co. Mayo&lt;/span&gt;&lt;/span&gt;" value="TNO4468">
#                             Ballina, Co. Mayo                          </option>
# <option data-content="&lt;span class='d-flex align-items-center w-100'&gt;&lt;span&gt;Castlebar, Co. Mayo&lt;/span&gt;&lt;/span&gt;" value="EPA-26">
#                             Castlebar, Co. Mayo                          </option>
# <option data-content="&lt;span class='d-flex align-items-center w-100'&gt;&lt;span&gt;Claremorris, Co. Mayo&lt;/span&gt;&lt;/span&gt;" value="EPA-103">
#                             Claremorris, Co. Mayo                          </option>
# <option data-content="&lt;span class='d-flex align-items-center w-100'&gt;&lt;span&gt;Navan, Co. Meath&lt;/span&gt;&lt;/span&gt;" value="EPA-68">
#                             Navan, Co. Meath                          </option>
# <option data-content="&lt;span class='d-flex align-items-center w-100'&gt;&lt;span&gt;Kilkitt, Co. Monaghan&lt;/span&gt;&lt;/span&gt;" value="EPA-58">
#                             Kilkitt, Co. Monaghan                          </option>
# <option data-content="&lt;span class='d-flex align-items-center w-100'&gt;&lt;span&gt;Monaghan Town&lt;/span&gt;&lt;/span&gt;" value="TNO3952">
#                             Monaghan Town                          </option>
# <option data-content="&lt;span class='d-flex align-items-center w-100'&gt;&lt;span&gt;Banagher, Co. Offaly&lt;/span&gt;&lt;/span&gt;" value="TNO4465">
#                             Banagher, Co. Offaly                          </option>
# <option data-content="&lt;span class='d-flex align-items-center w-100'&gt;&lt;span&gt;Birr, Co. Offaly&lt;/span&gt;&lt;/span&gt;" value="EPA-79">
#                             Birr, Co. Offaly                          </option>
# <option data-content="&lt;span class='d-flex align-items-center w-100'&gt;&lt;span&gt;Edenderry Library, Co. Offaly&lt;/span&gt;&lt;/span&gt;" value="EPA-102">
#                             Edenderry Library, Co. Offaly                          </option>
# <option data-content="&lt;span class='d-flex align-items-center w-100'&gt;&lt;span&gt;Tullamore, Co. Offaly&lt;/span&gt;&lt;/span&gt;" value="TNO3948">
#                             Tullamore, Co. Offaly                          </option>
# <option data-content="&lt;span class='d-flex align-items-center w-100'&gt;&lt;span&gt;Roscommon Town&lt;/span&gt;&lt;/span&gt;" value="EPA-53">
#                             Roscommon Town                          </option>
# <option data-content="&lt;span class='d-flex align-items-center w-100'&gt;&lt;span&gt;Sligo Town&lt;/span&gt;&lt;/span&gt;" value="EPA-77">
#                             Sligo Town                          </option>
# <option data-content="&lt;span class='d-flex align-items-center w-100'&gt;&lt;span&gt;Clonmel, Co. Tipperary&lt;/span&gt;&lt;/span&gt;" value="EPA-75">
#                             Clonmel, Co. Tipperary                          </option>
# <option data-content="&lt;span class='d-flex align-items-center w-100'&gt;&lt;span&gt;Nenagh, Co. Tipperary&lt;/span&gt;&lt;/span&gt;" value="AQG-21137">
#                             Nenagh, Co. Tipperary                          </option>
# <option data-content="&lt;span class='d-flex align-items-center w-100'&gt;&lt;span&gt;Tipperary Town&lt;/span&gt;&lt;/span&gt;" value="EPA-66">
#                             Tipperary Town                          </option>
# <option data-content="&lt;span class='d-flex align-items-center w-100'&gt;&lt;span&gt;Paddy Browne's Road, Waterford&lt;/span&gt;&lt;/span&gt;" value="EPA-59">
#                             Paddy Browne's Road, Waterford                          </option>
# <option data-content="&lt;span class='d-flex align-items-center w-100'&gt;&lt;span&gt;Dungarvan, Co. Waterford&lt;/span&gt;&lt;/span&gt;" value="AQG-21135">
#                             Dungarvan, Co. Waterford                          </option>
# <option data-content="&lt;span class='d-flex align-items-center w-100'&gt;&lt;span&gt;Merchants Quay, Waterford City&lt;/span&gt;&lt;/span&gt;" value="EPA-87">
#                             Merchants Quay, Waterford City                          </option>
# <option data-content="&lt;span class='d-flex align-items-center w-100'&gt;&lt;span&gt;Athlone Civic Centre &amp; Library, Co. Westmeath&lt;/span&gt;&lt;/span&gt;" value="EPA-70">
#                             Athlone Civic Centre &amp; Library, Co. Westmeath                          </option>
# <option data-content="&lt;span class='d-flex align-items-center w-100'&gt;&lt;span&gt;Mullingar, Co. Westmeath&lt;/span&gt;&lt;/span&gt;" value="AQG-21141">
#                             Mullingar, Co. Westmeath                          </option>
# <option data-content="&lt;span class='d-flex align-items-center w-100'&gt;&lt;span&gt;Carnsore Point, Co. Wexford&lt;/span&gt;&lt;/span&gt;" value="EPA-28">
#                             Carnsore Point, Co. Wexford                          </option>
# <option data-content="&lt;span class='d-flex align-items-center w-100'&gt;&lt;span&gt;Enniscorthy, Co. Wexford&lt;/span&gt;&lt;/span&gt;" value="EPA-24">
#                             Enniscorthy, Co. Wexford                          </option>
# <option data-content="&lt;span class='d-flex align-items-center w-100'&gt;&lt;span&gt;Enniscorthy, Co. Wexford&lt;/span&gt;&lt;/span&gt;" value="DM30-00684-EPA">
#                             Enniscorthy, Co. Wexford                          </option>
# <option data-content="&lt;span class='d-flex align-items-center w-100'&gt;&lt;span&gt;Gorey, Co. Wexford&lt;/span&gt;&lt;/span&gt;" value="DM30-00717-EPA">
#                             Gorey, Co. Wexford                          </option>
# <option data-content="&lt;span class='d-flex align-items-center w-100'&gt;&lt;span&gt;New Ross, Co. Wexford&lt;/span&gt;&lt;/span&gt;" value="DM30-00608-EPA">
#                             New Ross, Co. Wexford                          </option>
# <option data-content="&lt;span class='d-flex align-items-center w-100'&gt;&lt;span&gt;Talbot Green, Wexford&lt;/span&gt;&lt;/span&gt;" value="DM30-00610-EPA">
#                             Talbot Green, Wexford                          </option>
# <option data-content="&lt;span class='d-flex align-items-center w-100'&gt;&lt;span&gt;Wexford Opera House&lt;/span&gt;&lt;/span&gt;" value="EPA-63">
#                             Wexford Opera House                          </option>
# <option data-content="&lt;span class='d-flex align-items-center w-100'&gt;&lt;span&gt;Bray, Co. Wicklow&lt;/span&gt;&lt;/span&gt;" value="EPA-13">
#                             Bray, Co. Wicklow                          </option>
# <option data-content="&lt;span class='d-flex align-items-center w-100'&gt;&lt;span&gt;Greystones Fire Station&lt;/span&gt;&lt;/span&gt;" value="EPA-101">
#                             Greystones Fire Station                          </option>
# </select>
# <div class="d-flex align-items-center g-absolute-centered--y g-right-0 g-color-gray-light-v6 g-color-lightblue-v9--sibling-opened g-mr-15">
# <i class="hs-admin-angle-down"></i>
# </div>
# </div>
# </div>
# <!-- End Station Select -->
# <!-- Date Range -->
# <div class="col-md-3 g-mb-10">
# <label class="g-mb-10" for="#dateFrom">From</label>
# <div class="form-group mb-0">
# <div class="form-group mb-0">
# <div class="u-datepicker-right u-datepicker--v3 g-pos-rel w-100 g-cursor-pointer g-brd-around g-brd-gray-light-v7 g-rounded-4" id="dateFromWrapper">
# <input class="form-control form-control-md g-bg-white g-brd-gray-light-v7 g-brd-lightblue-v3--focus g-rounded-4 g-px-20 g-py-12" data-rp-date-format="d M Y" data-rp-wrapper="#dateFromWrapper" id="dateFrom" name="dateFrom" type="text" value="01 Jan 2023"/>
# <span class="g-pos-abs g-top-0 g-right-0 g-z-index-2 g-width-40 h-100 g-font-size-18 g-color-gray-light-v6 rounded-0">
# <i class="hs-admin-calendar input-calendar-icon"></i>
# </span>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-3 g-mb-10">
# <label class="g-mb-10" for="#dateTo">To</label>
# <div class="form-group mb-0">
# <div class="u-datepicker-right u-datepicker--v3 w-100 g-pos-rel g-cursor-pointer g-brd-around g-brd-gray-light-v7 g-rounded-4" id="dateToWrapper">
# <input class="form-control form-control-md g-bg-white g-brd-gray-light-v7 g-brd-lightblue-v3--focus g-rounded-4 g-px-20 g-py-12" data-rp-date-format="d M Y" data-rp-wrapper="#dateToWrapper" id="dateTo" name="dateTo" type="text" value="30 Jun 2023"/>
# <span class="g-pos-abs g-top-0 g-right-0 g-z-index-2 g-width-40 h-100 g-font-size-18 g-color-gray-light-v6 rounded-0">
# <i class="hs-admin-calendar input-calendar-icon"></i>
# </span>
# </div>
# </div>
# </div>
# <!-- End Date Range -->
# <div class="col-md-2 g-mb-10">
# <button class="btn btn-md u-btn-primary g-mt-30" type="submit">Submit</button>
# </div>
# </div><!--./row-->
# </form>
# </div><!-- /.col-md-10 -->
# </div><!-- /.row-->
# <div class="row">
# <div class="col-md-10 g-mb-30">
# <!-- include jQuery and Highcharts -->
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/3.2.1/jquery.min.js" type="text/javascript"></script>
# <script src="/assets/js/highcharts/highcharts.js" type="text/javascript"></script>
# <script src="/assets/js/highcharts/modules/exporting.js" type="text/javascript"></script>
# <script src="/assets/js/highcharts/modules/export-data.js" type="text/javascript"></script>
# <script src="/assets/js/default-highcharts-chart.js" type="text/javascript"></script>
# <div id="line-graph" style="height:450px;"></div>
# <script type="text/javascript">
#
#                 var lineChart = {
#
#                     chartContent: 'line-graph',
#                     options: {
#                         chart: {
#                             type: 'line',
#                             zoomType: 'xy'
#                         },
#
#                         title: {
#                             text: 'Air Quality Levels at Ennis, Co. Clare',
#                             style: {
#                                 fontSize: '17px',
#                                 color: '#333'
#                             }
#                         },
#
#                         xAxis: {
#                             type: 'datetime',
#                             dateTimeLabelFormats: {
#                                 hour:'%e %b, %H:%M',
#                                 minute:'%e %b, %H:%M'
#                             },
#                             minRange: 3600000, // 1 hour
#                             title: {
#                                 text: 'Date and Time',
#                                 style: {
#                                     fontSize: '14px',
#                                     color: '#666'
#                                 }
#                             },
#                             labels: {
#                                 style: {
#                                     fontSize: '12px',
#                                 }
#                             }
#                         },
#                         yAxis: [
#                             {
#                                 title: {
#                                     useHTML: true,
#                                     text: "Concentrations (&micro;g/m&sup3;)",
#                                     style: {
#                                         fontSize: '14px',
#                                         color: '#666'
#                                     }
#                                 },
#                                 labels: {
#                                     style: {
#                                         fontSize: '12px'
#                                     }
#                                 },
#                                 min: 0,
#                                 startOnTick: false
#                             },
# ...
#
#                                 ]
#                             },
#                                                     {
#                                 type: 'line',
#                                 name: 'PM<sub>2.5</sub>',
#                                 color: '#1b1b1b',
#                                 cursor: 'pointer',
#                                 tooltip: {
#                                     valueSuffix: ' µg/m³'
#                                 },
#                                 events: {
#                                     click: function(event) {
#                                         showModal("PM2.5", "PM2.5 are particles with diameters of 2.5 microns or less. The main sources are solid fuel burning and vehicular traffic. Other sources are soil and road surfaces, construction works and industrial emissions or natural sources such as windblown salt, plant spores and pollens. These direct emissions are known as primary PM. Particulate matter can also be formed from reactions between different pollutant gases (secondary sources).");
#                                     }
#                                 },
#                                 data: [
#
#                                                                     [ Date.UTC(2023,0,1,1,0,0), 29.01 ],                                                                    [ Date.UTC(2023,0,1,2,0,0), 20.66 ],                                                                    [ Date.UTC(2023,0,1,3,0,0), 12.75 ],                                                                    [ Date.UTC(2023,0,1,4,0,0), 13.5 ],                                                                    [ Date.UTC(2023,0,1,5,0,0), 11.54 ],                                                                    [ Date.UTC(2023,0,1,6,0,0), 10.36 ],                                                                    [ Date.UTC(2023,0,1,7,0,0), 11.58 ],                                                                    [ Date.UTC(2023,0,1,8,0,0), 23.01 ],                                                                    [ Date.UTC(2023,0,1,9,0,0), 9.23 ],                                                                    [ Date.UTC(2023,0,1,10,0,0), 11.89 ],                                                                    [ Date.UTC(2023,0,1,11,0,0), 9.74 ],                                                                    [ Date.UTC(2023,0,1,12,0,0), 9.2 ],                                                                    [ Date.UTC(2023,0,1,13,0,0), 8.72 ],                                                                    [ Date.UTC(2023,0,1,14,0,0), 8.85 ],                                                                    [ Date.UTC(2023,0,1,15,0,0), 14.8 ],                                                                    [ Date.UTC(2023,0,1,16,0,0), 64.33 ],                                                                    [ Date.UTC(2023,0,1,17,0,0), 94 ],                                                                    [ Date.UTC(2023,0,1,18,0,0), 125.44 ],                                                                    [ Date.UTC(2023,0,1,19,0,0), 117.25 ],                                                                    [ Date.UTC(2023,0,1,20,0,0), 111.69 ],                                                                    [ Date.UTC(2023,0,1,21,0,0), 132.9 ],                                                                    [ Date.UTC(2023,0,1,22,0,0), 120.38 ],                                                                    [ Date.UTC(2023,0,1,23,0,0), 96.79 ],                                                                    [ Date.UTC(2023,0,2,0,0,0), 89.8 ],                                                                    [ Date.UTC(2023,0,2,1,0,0), 60.89 ],                                                                    [ Date.UTC(2023,0,2,2,0,0), 44.93 ],                                                                    [ Date.UTC(2023,0,2,3,0,0), 31.78 ],                                                                    [ Date.UTC(2023,0,2,4,0,0), 16.48 ],                                                                    [ Date.UTC(2023,0,2,5,0,0), 19.04 ],                                                                    [ Date.UTC(2023,0,2,6,0,0), 13.18 ],                                                                    [ Date.UTC(2023,0,2,7,0,0), 13.02 ],                                                                    [ Date.UTC(2023,0,2,8,0,0), 14.14 ],                                                                    [ Date.UTC(2023,0,2,9,0,0), 21.8 ],                                                                    [ Date.UTC(2023,0,2,10,0,0), 31.46 ],                                                                    [ Date.UTC(2023,0,2,11,0,0), 23.67 ],                                                                    [ Date.UTC(2023,0,2,12,0,0), 12.44 ],                                                                    [ Date.UTC(2023,0,2,13,0,0), 14.75 ],                                                                    [ Date.UTC(2023,0,2,14,0,0), 18.63 ],                                       ...
#
#                                 ]
#                             },
#
#                         ]
#                     }
#                 };
#
#                 // give lineChart all defaultChart functions, add options and create
#                 lineChart = jQuery.extend(true, {}, defaultChart, lineChart);
#                 lineChart.init(lineChart.options);
#                 lineChart.create();
#
#             </script>
# </div><!-- /.col-->
# </div><!-- /.row-->
# <div class="row">
# <div class="col-md-10 g-mt-30 g-mb-30">
# <div class="g-brd-around g-brd-gray-light-v7 g-rounded-4 g-pa-15 g-pa-20--md">
# <h3 class="d-flex align-self-center text-uppercase g-font-size-12 g-font-size-default--md g-color-black g-mb-20">Disclaimer</h3>
# <div class="g-pa-20--md">
# <p class="g-color-gray-dark-v4">Data downloaded from this website has been collected automatically from the monitoring sites and has not yet been validated. Therefore, following validation this data may be subject to revision. Sharp spikes should be treated cautiously and may be the result of a calibration or a monitor malfunction.</p>
# <p class="g-color-gray-dark-v4">When using this data you must comply to the terms described in the <a href="https://creativecommons.org/licenses/by/4.0/" target="_blank">Creative Commons Attribution</a> licence.</p>
# <p class="g-color-gray-dark-v4">Caution should be applied when comparing data from different monitoring sites. Some monitoring sites are roadside locations while others are background locations or rural locations. Background sites generally represent overall area-wide exposure more closely than roadside sites.</p>
# </div>
# </div>
# </div>
# </div>
# </div>
# <!-- Footer -->
# <footer class="u-footer--bottom-sticky g-bg-white g-color-gray-dark-v6 g-brd-top g-brd-gray-light-v7 g-pa-20" id="footer">
# <div class="row align-items-center">
# <div class="col-md-4 g-mb-10 g-mb-0--md">
# <ul class="list-inline text-center text-md-left mb-0">
# <!-- <li class="list-inline-item">
#                   <a class="g-color-gray-dark-v6" href="#">Contact Us</a>
#                 </li>
#                 <li class="list-inline-item">
#                   <span class="g-color-gray-dark-v6">|</span>
#                 </li> -->
# <li class="list-inline-item">
# <a class="g-color-gray-dark-v6" href="https://www.epa.ie/footer/privacy/" target="_blank">Privacy Policy</a>
# </li>
# <li class="list-inline-item">
# <span class="g-color-gray-dark-v6">|</span>
# </li>
# <li class="list-inline-item">
# <a class="g-color-gray-dark-v6" href="https://www.epa.ie/footer/termsofuse/" target="_blank">Terms of Use</a>
# </li>
# </ul>
# </div>
# <!-- Footer Socials -->
# <div class="col-md-4 g-mb-10 g-mb-0--md">
# <ul class="list-inline g-font-size-16 text-center mb-0">
# <li class="list-inline-item g-mx-10">
# <a class="g-color-twitter" href="https://twitter.com/EPAireland" target="_blank" title="EPA on Twitter">
# <i class="fa fa-twitter"></i>
# </a>
# </li>
# </ul>
# </div>
# <!-- End Footer Socials -->
# <!-- Footer Copyright -->
# <div class="col-md-4 text-center text-md-right" id="copyright">
# <small class="d-block g-font-size-default">© 2025 <a href="https://www.sonitussystems.com" target="_blank">Sonitus Systems</a>. <span>All Rights Reserved.</span></small>
# </div>
# <!-- End Footer Copyright -->
# </div>
# </footer>
# <!-- End Footer -->
# </div>
# </div>
# </section>
# </main>
# <!-- Modal -->
# <div class="modal fade" id="definition-modal" role="dialog" tabindex="-1">
# <div class="modal-dialog">
# <div class="modal-content">
# <div class="modal-header">
# <h4 class="g-mb-20 modal-title"></h4>
# <button aria-hidden="true" class="close" data-dismiss="modal" type="button">
# <i class="hs-icon hs-icon-close"></i>
# </button>
# </div>
# <div class="modal-body">
# </div>
# <div class="modal-footer">
# <button class="btn btn-default" data-dismiss="modal" type="button">OK</button>
# </div>
# </div><!--/.modal-content-->
# </div><!--/.modal-dialog-->
# </div><!--/.modal -->
# <!-- JS Global Compulsory -->
# <script src="/assets/vendor/jquery/jquery.min.js"></script>
# <script src="/assets/vendor/jquery-migrate/jquery-migrate.min.js"></script>
# <script src="/assets/vendor/popper.min.js"></script>
# <script src="/assets/vendor/bootstrap/bootstrap.min.js"></script>
# <script src="/assets/vendor/cookiejs/jquery.cookie.js"></script>
# <!-- jQuery UI Core -->
# <script src="/assets/vendor/jquery-ui/ui/widget.js"></script>
# <script src="/assets/vendor/jquery-ui/ui/version.js"></script>
# <script src="/assets/vendor/jquery-ui/ui/keycode.js"></script>
# <script src="/assets/vendor/jquery-ui/ui/position.js"></script>
# <script src="/assets/vendor/jquery-ui/ui/unique-id.js"></script>
# <script src="/assets/vendor/jquery-ui/ui/safe-active-element.js"></script>
# <!-- jQuery UI Helpers -->
# <script src="/assets/vendor/jquery-ui/ui/widgets/menu.js"></script>
# <script src="/assets/vendor/jquery-ui/ui/widgets/mouse.js"></script>
# <!-- jQuery UI Widgets -->
# <script src="/assets/vendor/jquery-ui/ui/widgets/datepicker.js"></script>
# <!-- JS Plugins Init. -->
# <script src="/assets/vendor/appear.js"></script>
# <script src="/assets/vendor/bootstrap-select/js/bootstrap-select.min.js"></script>
# <script src="/assets/vendor/flatpickr/dist/js/flatpickr.min.js"></script>
# <script src="/assets/vendor/malihu-scrollbar/jquery.mCustomScrollbar.concat.min.js"></script>
# <script src="/assets/vendor/chartist-js/chartist.min.js"></script>
# <script src="/assets/vendor/chartist-js-tooltip/chartist-plugin-tooltip.js"></script>
# <script src="/assets/vendor/fancybox/jquery.fancybox.min.js"></script>
# <!-- JS Unify -->
# <script src="/assets/js/hs.core.js"></script>
# <script src="/assets/js/components/hs.side-nav.js"></script>
# <script src="/assets/js/helpers/hs.hamburgers.js"></script>
# <script src="/assets/js/components/hs.range-datepicker.js"></script>
# <script src="/assets/js/components/hs.datepicker.js"></script>
# <script src="/assets/js/components/hs.dropdown.js"></script>
# <script src="/assets/js/components/hs.scrollbar.js"></script>
# <script src="/assets/js/components/hs.area-chart.js"></script>
# <script src="/assets/js/components/hs.donut-chart.js"></script>
# <script src="/assets/js/components/hs.bar-chart.js"></script>
# <script src="/assets/js/helpers/hs.focus-state.js"></script>
# <script src="/assets/js/components/hs.popup.js"></script>
# <script src="/assets/js/components/hs.validation.js"></script>
# <script data-cfasync="false" src="https://cdn.jsdelivr.net/npm/cookieconsent@3/build/cookieconsent.min.js"></script>
# <script src="/assets/js/cookie-consent.js"></script>
# <script src="../assets/vendor/jquery-validation/dist/jquery.validate.min.js"></script>
# <!-- JS Plugins Init. -->
# <script>
#     $(document).on('ready', function () {
#       // initialization of custom scrollbar
#       $.HSCore.components.HSScrollBar.init($('.js-custom-scroll'));
#
#       // initialization of HSDropdown component
#       $.HSCore.components.HSDropdown.init($('[data-dropdown-target]'), {dropdownHideOnScroll: false});
#
#       // initialization of hamburger
#       $.HSCore.helpers.HSHamburgers.init('.hamburger');
#
#       // initialization of sidebar navigation component
#       $.HSCore.components.HSSideNav.init('.js-side-nav');
#
#       // initialization of custom select
#       $('.js-select').selectpicker();
#
#       // initialization of range datepicker
#       $.HSCore.components.HSRangeDatepicker.init('#dateFrom, #dateTo');
#
#       // initialization of form validation
#       $.HSCore.components.HSValidation.init('.js-validate');
#
#       // initialization of charts
#       $.HSCore.components.HSBarChart.init('.js-bar-chart');
#
#       // initialization of popups
#       $.HSCore.components.HSPopup.init('.js-fancybox', {
#         btnTpl: {
#           smallBtn: '<button data-fancybox-close class="btn g-pos-abs g-top-25 g-right-30 g-line-height-1 g-bg-transparent g-font-size-16 g-color-gray-light-v6 g-brd-none p-0" title=""><i class="hs-admin-close"></i></button>'
#         }
#       });
#
#
#       $.validator.addMethod("greaterOrEqual", function(value, element, params){
#           if (!/Invalid|NaN/.test(new Date(value))) {
#               return new Date(value) >= new Date($(params).val());
#           }
#
#           return isNaN(value) && isNaN($(params).val()) || (Number(value) >= Number($(params).val()));
#       }, "To date cannot be before From date");
#
#       $.validator.addMethod("maxRange", function(value, element, params) {
#           var firstDate = new Date($(params).val());
#           var firstTs = Math.round(firstDate.getTime() / 1000);
#           var secondDate = new Date(value);
#           var secondTs = Math.round(secondDate.getTime() / 1000);
#
#           // 3 months = 7890000 secs
#           // 6 months = 15768000 secs
#           if ((secondTs - firstTs) <= 15768000)
#               return true;
#
#           return false;
#       }, "Maximum range is six months");
#
#       $("#dateTo").rules('add', { greaterOrEqual: "#dateFrom", maxRange: "#dateFrom" });
#     });
#
#     function showModal(title, body){
#       $('#definition-modal h4').html(title);
#       $('#definition-modal .modal-body').html(body);
#       $('#definition-modal').modal('toggle');
#     }
#
#   </script>
# </body>
# </html>

# %%
#look at the javascript that contains the timestamps and values
get_data = soup.find('script', string=re.compile('Date.UTC')).string

#use reqex to match the date and values
pattern = r'Date\.UTC\((\d+),(\d+),(\d+),(\d+),(\d+),(\d+)\),\s*([\d.]+)'

#get all matches
matches = re.findall(pattern, get_data)

#convert to datetimes and pm values
data = []
for match in matches:
    year, month, day, hour, minute, second, value = map(float, match)
    
    #looks like month is set from 0 so Jan = 0 month.. add a 1 to make it right
    timestamp = datetime(int(year), int(month)+1, int(day), int(hour), int(minute), int(second))
    #append each row
    data.append((timestamp, float(value)))

#create dataframe
df = pd.DataFrame(data, columns=['Timestamp', 'Value'])

#print data
print(df)
# Out:
#                 Timestamp  Value
# 0     2023-01-01 01:00:00  10.80
# 1     2023-01-01 02:00:00   7.89
# 2     2023-01-01 03:00:00   5.84
# 3     2023-01-01 04:00:00   5.12
# 4     2023-01-01 05:00:00   4.58
# ...                   ...    ...
# 12856 2023-06-30 19:00:00   3.67
# 12857 2023-06-30 20:00:00   4.16
# 12858 2023-06-30 21:00:00   4.65
# 12859 2023-06-30 22:00:00   6.02
# 12860 2023-06-30 23:00:00   6.11
#
# [12861 rows x 2 columns]

# %%
#put it together with more variables and date ranges so it can pull all locations, all months for all specified years.
#starting date point
dateFrom = '01+Jan+'
#dateFrom = '01+Jul+'
#end date point
dateTo = '30+Jun+'
#dateTo = '31+Dec+'
#years to capture
year = {2023}

dataset = pd.DataFrame(columns=["Timestamp", "Value", "PM", "Location"])
#all_dataset = pd.DataFrame(columns=["Timestamp", "Value", "PM", "Location"])

for y in year:
    for i in range(10,110):#range should go to 110
        
        #break the url up into the string and variables
        url='https://airquality.ie/readings?station=EPA-'+str(i)+'&dateFrom='+dateFrom+str(y)+'&dateTo='+dateTo+str(y)
        #print it to keep track of which location and date is being processes as the script is running
        print(url)
        #create content to scrape
        r = requests.get(url)
        soup = BeautifulSoup(r.content, 'html.parser')
        #print(soup)
        #if there is no data the m-0 class is called with a no data message..
        no_data = soup.select(".m-0")
        if no_data:
            #print to track what locations exist/don't exist
            print(no_data)
        else:
            # find the date and values within the data tag..
            get_data = soup.find_all('script')#, string=re.compile('Date.UTC')).string
            #print("get_data")
            #print(get_data)
         #   print("get_data.string")
        #    print(get_data.string)
            #look for the same message to get the location of the air quality monitor, begins with Air Quality Levels at then has a comma and ends with a single quote.
            location = re.search(r"Air Quality Levels at.*?,*?'", str(get_data))

            #if location exists assign it.. otherwise mark it as unknown
            if location:
                loc = location.group(0)
                print(loc)
            else:
                loc = "Unknown Location"

            #look for PM2.5 data
            pm2_5 = re.search(r'"PM2.5",', str(get_data))
            pm2_5_values = []

            #if it exists pull the full block from pm2.5 to //endforeach to get all timestamp and pm values data
            if pm2_5:
                pattern = r'"PM2.5".*?//endforeach'
                
                #search for the entire block from 'pm2_5' to '//endforeach'
                pm2_5_data_block = re.search(pattern, str(get_data), re.DOTALL)
              #  print(pm2_5_data_block.group(0))
                if pm2_5_data_block:
                    #print(pm2_5_data_block)
                    #asked chatgpt to 'give me the regex to parse this date and value, [ Date.UTC(2023,0,9,4,0,0), 2.86]'
                    #match the timestamp and value portion only
                    pattern = r'Date\.UTC\((\d+),(\d+),(\d+),(\d+),(\d+),(\d+)\),\s*([\d.]+)'
      
                   #get all matches in the pm2.5 block only
                    pm2_5_values = re.findall(pattern, pm2_5_data_block.group(0))
                else:
                    print("No match found")

            #print(pm2_5_values)
            
            #do the same again for pm10
            pm10 = re.search(r'"PM10",', str(get_data))
            pm10_values = []
            if pm10:
                pattern = r'"PM10".*?//endforeach'
                
                #search for the entire block from 'pm10' to '//endforeach'
                pm10_data_block = re.search(pattern,str(get_data), re.DOTALL)

                #get all matches in the pm10 block only
                if pm10_data_block:
                    pattern = r'Date\.UTC\((\d+),(\d+),(\d+),(\d+),(\d+),(\d+)\),\s*([\d.]+)'
                    pm10_values = re.findall(pattern, pm10_data_block.group(0))
                else:
                    print("No match found")

            #print(pm10_values)
            pm_val = float
        
            #assign the values to the name of the pm type for easier adding to the dataset
            records = {'pm_2.5':pm2_5_values,'pm_10':pm10_values}
            # print(records)
            mydata = []
            if records:
                #get the key value pairs
                for key, vals in records.items():
                    #define the pm_val based on the key
                    if key == 'pm_2.5':
                        pm_val = 2.5
                    elif key == 'pm_10':
                        pm_val = 10
                    else:
                        pm_val = 0  #0 can be used for unknown so it doesn't break the parser

                    #parse out the values into the timestamps and pm vals
                    for val in vals:
                     #   print(val)
                        year, month, day, hour, minute, second, value = map(float, val)
                        #add 1 to the month as it looks like January = month 0 (days not affected)
                        timestamp = datetime(int(year), int(month)+1, int(day), int(hour), int(minute), int(second))
                    
                        #put it together in a data frame
                        mydata.append({"Timestamp": timestamp, "Value": float(value), "PM":pm_val, "Location": loc})

        newdata = pd.DataFrame(mydata)      
        dataset = pd.concat([newdata,dataset])
#save to a csv file so it's available to read in (but don't open and save as it will have millions of rows and they will be lost by Excel!
dataset.to_csv('air_quality_data_Jan_Jun_2023.csv', index=False)
# Out:
# https://airquality.ie/readings?station=EPA-10&dateFrom=01+Jan+2023&dateTo=30+Jun+2023
# Air Quality Levels at Heatherton Park, Cork'
# https://airquality.ie/readings?station=EPA-11&dateFrom=01+Jan+2023&dateTo=30+Jun+2023
# C:\Users\lsmyth\AppData\Local\Temp\ipykernel_24844\3292849743.py:116: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   dataset = pd.concat([newdata,dataset])
# Air Quality Levels at Winetavern Street, Dublin 8'
# https://airquality.ie/readings?station=EPA-12&dateFrom=01+Jan+2023&dateTo=30+Jun+2023
# [<p class="m-0">
#                     No data found for this station and date range.
#                                     </p>]
# https://airquality.ie/readings?station=EPA-13&dateFrom=01+Jan+2023&dateTo=30+Jun+2023
# Air Quality Levels at Bray, Co. Wicklow'
# https://airquality.ie/readings?station=EPA-14&dateFrom=01+Jan+2023&dateTo=30+Jun+2023
# [<p class="m-0">
#                     No data found for this station and date range.
#                                     </p>]
# https://airquality.ie/readings?station=EPA-15&dateFrom=01+Jan+2023&dateTo=30+Jun+2023
# [<p class="m-0">
#                     No data found for this station and date range.
#                                     </p>]
# https://airquality.ie/readings?station=EPA-16&dateFrom=01+Jan+2023&dateTo=30+Jun+2023
# Air Quality Levels at Portlaoise, Co. Laois'
# https://airquality.ie/readings?station=EPA-17&dateFrom=01+Jan+2023&dateTo=30+Jun+2023
# Air Quality Levels at Ringsend, Dublin 4'
# https://airquality.ie/readings?station=EPA-18&dateFrom=01+Jan+2023&dateTo=30+Jun+2023
# [<p class="m-0">
#                     No data found for this station and date range.
#                                     </p>]
# https://airquality.ie/readings?station=EPA-19&dateFrom=01+Jan+2023&dateTo=30+Jun+2023
# [<p class="m-0">
#                     No data found for this station and date range.
#                                     </p>]
# https://airquality.ie/readings?station=EPA-20&dateFrom=01+Jan+2023&dateTo=30+Jun+2023
# [<p class="m-0">
#                     No data found for this station and date range.
#                                     </p>]
# https://airquality.ie/readings?station=EPA-21&dateFrom=01+Jan+2023&dateTo=30+Jun+2023
# Air Quality Levels at University College Cork'
# https://airquality.ie/readings?station=EPA-22&dateFrom=01+Jan+2023&dateTo=30+Jun+2023
# Air Quality Levels at Rathmines, Dublin 6'
# https://airquality.ie/readings?station=EPA-23&dateFrom=01+Jan+2023&dateTo=30+Jun+2023
# Air Quality Levels at Dundalk, Co. Louth'
# https://airquality.ie/readings?station=EPA-24&dateFrom=01+Jan+2023&dateTo=30+Jun+2023
# Air Quality Levels at Enniscorthy, Co. Wexford'
# https://airquality.ie/readings?station=EPA-25&dateFrom=01+Jan+2023&dateTo=30+Jun+2023
# Air Quality Levels at Ennis, Co. Clare'
# https://airquality.ie/readings?station=EPA-26&dateFrom=01+Jan+2023&dateTo=30+Jun+2023
# Air Quality Levels at Castlebar, Co. Mayo'
# https://airquality.ie/readings?station=EPA-27&dateFrom=01+Jan+2023&dateTo=30+Jun+2023
# Air Quality Levels at Malin Head, Co. Donegal'
# https://airquality.ie/readings?station=EPA-28&dateFrom=01+Jan+2023&dateTo=30+Jun+2023
# Air Quality Levels at Carnsore Point, Co. Wexford'
# https://airquality.ie/readings?station=EPA-29&dateFrom=01+Jan+2023&dateTo=30+Jun+2023
# Air Quality Levels at Blanchardstown, Dublin 15'
# https://airquality.ie/readings?station=EPA-30&dateFrom=01+Jan+2023&dateTo=30+Jun+2023
# [<p class="m-0">
#                     No data found for this station and date range.
#                                     </p>]
# https://airquality.ie/readings?station=EPA-31&dateFrom=01+Jan+2023&dateTo=30+Jun+2023
# [<p class="m-0">
#                     No data found for this station and date range.
#                                     </p>]
# https://airquality.ie/readings?station=EPA-32&dateFrom=01+Jan+2023&dateTo=30+Jun+2023
# [<p class="m-0">
#                     No data found for this station and date range.
#                                     </p>]
# https://airquality.ie/readings?station=EPA-33&dateFrom=01+Jan+2023&dateTo=30+Jun+2023
# Air Quality Levels at Clonskeagh, Dublin 14'
# https://airquality.ie/readings?station=EPA-34&dateFrom=01+Jan+2023&dateTo=30+Jun+2023
# Air Quality Levels at Dún Laoghaire, Co. Dublin'
# https://airquality.ie/readings?station=EPA-35&dateFrom=01+Jan+2023&dateTo=30+Jun+2023
# [<p class="m-0">
#                     No data found for this station and date range.
#                                     </p>]
# https://airquality.ie/readings?station=EPA-36&dateFrom=01+Jan+2023&dateTo=30+Jun+2023
# Air Quality Levels at Callan Road, Kilkenny'
# https://airquality.ie/readings?station=EPA-37&dateFrom=01+Jan+2023&dateTo=30+Jun+2023
# [<p class="m-0">
#                     No data found for this station and date range.
#                                     </p>]
# https://airquality.ie/readings?station=EPA-38&dateFrom=01+Jan+2023&dateTo=30+Jun+2023
# [<p class="m-0">
#                     No data found for this station and date range.
#                                     </p>]
# https://airquality.ie/readings?station=EPA-39&dateFrom=01+Jan+2023&dateTo=30+Jun+2023
# Air Quality Levels at People\'
# https://airquality.ie/readings?station=EPA-40&dateFrom=01+Jan+2023&dateTo=30+Jun+2023
# [<p class="m-0">
#                     No data found for this station and date range.
#                                     </p>]
# https://airquality.ie/readings?station=EPA-41&dateFrom=01+Jan+2023&dateTo=30+Jun+2023
# [<p class="m-0">
#                     No data found for this station and date range.
#                                     </p>]
# https://airquality.ie/readings?station=EPA-42&dateFrom=01+Jan+2023&dateTo=30+Jun+2023
# [<p class="m-0">
#                     No data found for this station and date range.
#                                     </p>]
# https://airquality.ie/readings?station=EPA-43&dateFrom=01+Jan+2023&dateTo=30+Jun+2023
# Air Quality Levels at Longford Town'
# https://airquality.ie/readings?station=EPA-44&dateFrom=01+Jan+2023&dateTo=30+Jun+2023
# Air Quality Levels at Tallaght, Dublin 24'
# https://airquality.ie/readings?station=EPA-45&dateFrom=01+Jan+2023&dateTo=30+Jun+2023
# Air Quality Levels at Valentia Observatory, Caherciveen, Co. Kerry'
# https://airquality.ie/readings?station=EPA-46&dateFrom=01+Jan+2023&dateTo=30+Jun+2023
# Air Quality Levels at Finglas, Dublin 11'
# https://airquality.ie/readings?station=EPA-47&dateFrom=01+Jan+2023&dateTo=30+Jun+2023
# Air Quality Levels at Marino, Dublin 3'
# https://airquality.ie/readings?station=EPA-48&dateFrom=01+Jan+2023&dateTo=30+Jun+2023
# Air Quality Levels at Phoenix Park, Dublin 8'
# https://airquality.ie/readings?station=EPA-49&dateFrom=01+Jan+2023&dateTo=30+Jun+2023
# Air Quality Levels at Davitt Road, Inchicore, Dublin 12'
# https://airquality.ie/readings?station=EPA-50&dateFrom=01+Jan+2023&dateTo=30+Jun+2023
# Air Quality Levels at Ballyfermot, Dublin 10'
# https://airquality.ie/readings?station=EPA-51&dateFrom=01+Jan+2023&dateTo=30+Jun+2023
# Air Quality Levels at Mace Head, Carna, Co. Galway'
# https://airquality.ie/readings?station=EPA-52&dateFrom=01+Jan+2023&dateTo=30+Jun+2023
# Air Quality Levels at St. Anne\'
# https://airquality.ie/readings?station=EPA-53&dateFrom=01+Jan+2023&dateTo=30+Jun+2023
# Air Quality Levels at Roscommon Town'
# https://airquality.ie/readings?station=EPA-54&dateFrom=01+Jan+2023&dateTo=30+Jun+2023
# Air Quality Levels at Carlow Town'
# https://airquality.ie/readings?station=EPA-55&dateFrom=01+Jan+2023&dateTo=30+Jun+2023
# Air Quality Levels at Dublin Airport, Swords, Co. Dublin'
# https://airquality.ie/readings?station=EPA-56&dateFrom=01+Jan+2023&dateTo=30+Jun+2023
# Air Quality Levels at South Link Road, Cork'
# https://airquality.ie/readings?station=EPA-57&dateFrom=01+Jan+2023&dateTo=30+Jun+2023
# Air Quality Levels at St. John’s Road, Kilmainham, Dublin 8'
# https://airquality.ie/readings?station=EPA-58&dateFrom=01+Jan+2023&dateTo=30+Jun+2023
# Air Quality Levels at Kilkitt, Co. Monaghan'
# https://airquality.ie/readings?station=EPA-59&dateFrom=01+Jan+2023&dateTo=30+Jun+2023
# Air Quality Levels at Paddy Browne\'
# https://airquality.ie/readings?station=EPA-60&dateFrom=01+Jan+2023&dateTo=30+Jun+2023
# Air Quality Levels at Cobh Carrignafoy, Co. Cork'
# https://airquality.ie/readings?station=EPA-61&dateFrom=01+Jan+2023&dateTo=30+Jun+2023
# Air Quality Levels at Swords Council Depot, Co. Dublin'
# https://airquality.ie/readings?station=EPA-62&dateFrom=01+Jan+2023&dateTo=30+Jun+2023
# Air Quality Levels at Emo, Co. Laois'
# https://airquality.ie/readings?station=EPA-63&dateFrom=01+Jan+2023&dateTo=30+Jun+2023
# Air Quality Levels at Wexford Opera House'
# https://airquality.ie/readings?station=EPA-64&dateFrom=01+Jan+2023&dateTo=30+Jun+2023
# Air Quality Levels at Letterkenny, Co. Donegal'
# https://airquality.ie/readings?station=EPA-65&dateFrom=01+Jan+2023&dateTo=30+Jun+2023
# [<p class="m-0">
#                     No data found for this station and date range.
#                                     </p>]
# https://airquality.ie/readings?station=EPA-66&dateFrom=01+Jan+2023&dateTo=30+Jun+2023
# Air Quality Levels at Tipperary Town'
# https://airquality.ie/readings?station=EPA-67&dateFrom=01+Jan+2023&dateTo=30+Jun+2023
# Air Quality Levels at Macroom, Co. Cork'
# https://airquality.ie/readings?station=EPA-68&dateFrom=01+Jan+2023&dateTo=30+Jun+2023
# Air Quality Levels at Navan, Co. Meath'
# https://airquality.ie/readings?station=EPA-69&dateFrom=01+Jan+2023&dateTo=30+Jun+2023
# Air Quality Levels at Pearse Street, Dublin 2'
# https://airquality.ie/readings?station=EPA-70&dateFrom=01+Jan+2023&dateTo=30+Jun+2023
# Air Quality Levels at Athlone Civic Centre & Library, Co. Westmeath'
# https://airquality.ie/readings?station=EPA-71&dateFrom=01+Jan+2023&dateTo=30+Jun+2023
# Air Quality Levels at Tralee Library, Co. Kerry'
# https://airquality.ie/readings?station=EPA-72&dateFrom=01+Jan+2023&dateTo=30+Jun+2023
# Air Quality Levels at Cork Harbour'
# https://airquality.ie/readings?station=EPA-73&dateFrom=01+Jan+2023&dateTo=30+Jun+2023
# [<p class="m-0">
#                     No data found for this station and date range.
#                                     </p>]
# https://airquality.ie/readings?station=EPA-74&dateFrom=01+Jan+2023&dateTo=30+Jun+2023
# Air Quality Levels at Askeaton, Co. Limerick'
# https://airquality.ie/readings?station=EPA-75&dateFrom=01+Jan+2023&dateTo=30+Jun+2023
# Air Quality Levels at Clonmel, Co. Tipperary'
# https://airquality.ie/readings?station=EPA-76&dateFrom=01+Jan+2023&dateTo=30+Jun+2023
# Air Quality Levels at Dublin Port, Dublin 1'
# https://airquality.ie/readings?station=EPA-77&dateFrom=01+Jan+2023&dateTo=30+Jun+2023
# [<p class="m-0">
#                     No data found for this station and date range.
#
#                     <a class="alert-link" href="/readings?station=EPA-77&amp;dateFrom=23+Feb+2025&amp;dateTo=23+Feb+2025">View most recent readings</a>
# </p>]
# https://airquality.ie/readings?station=EPA-78&dateFrom=01+Jan+2023&dateTo=30+Jun+2023
# Air Quality Levels at Cavan Town'
# https://airquality.ie/readings?station=EPA-79&dateFrom=01+Jan+2023&dateTo=30+Jun+2023
# Air Quality Levels at Birr, Co. Offaly'
# https://airquality.ie/readings?station=EPA-80&dateFrom=01+Jan+2023&dateTo=30+Jun+2023
# Air Quality Levels at Carrick-on-Shannon, Co. Leitrim'
# https://airquality.ie/readings?station=EPA-81&dateFrom=01+Jan+2023&dateTo=30+Jun+2023
# [<p class="m-0">
#                     No data found for this station and date range.
#                                     </p>]
# https://airquality.ie/readings?station=EPA-82&dateFrom=01+Jan+2023&dateTo=30+Jun+2023
# Air Quality Levels at Mallow, Co. Cork'
# https://airquality.ie/readings?station=EPA-83&dateFrom=01+Jan+2023&dateTo=30+Jun+2023
# Air Quality Levels at Naas, Co. Kildare'
# https://airquality.ie/readings?station=EPA-84&dateFrom=01+Jan+2023&dateTo=30+Jun+2023
# Air Quality Levels at Drogheda, Co. Louth'
# https://airquality.ie/readings?station=EPA-85&dateFrom=01+Jan+2023&dateTo=30+Jun+2023
# Air Quality Levels at Henry Street, Limerick'
# https://airquality.ie/readings?station=EPA-86&dateFrom=01+Jan+2023&dateTo=30+Jun+2023
# [<p class="m-0">
#                     No data found for this station and date range.
#                                     </p>]
# https://airquality.ie/readings?station=EPA-87&dateFrom=01+Jan+2023&dateTo=30+Jun+2023
# Air Quality Levels at Merchants Quay, Waterford City'
# https://airquality.ie/readings?station=EPA-88&dateFrom=01+Jan+2023&dateTo=30+Jun+2023
# Air Quality Levels at Carrigaline, Co. Cork'
# https://airquality.ie/readings?station=EPA-89&dateFrom=01+Jan+2023&dateTo=30+Jun+2023
# Air Quality Levels at Clonakilty, Co. Cork'
# https://airquality.ie/readings?station=EPA-90&dateFrom=01+Jan+2023&dateTo=30+Jun+2023
# Air Quality Levels at Cork Airport'
# https://airquality.ie/readings?station=EPA-91&dateFrom=01+Jan+2023&dateTo=30+Jun+2023
# [<p class="m-0">
#                     No data found for this station and date range.
#
#                     <a class="alert-link" href="/readings?station=EPA-91&amp;dateFrom=23+Feb+2025&amp;dateTo=23+Feb+2025">View most recent readings</a>
# </p>]
# https://airquality.ie/readings?station=EPA-92&dateFrom=01+Jan+2023&dateTo=30+Jun+2023
# [<p class="m-0">
#                     No data found for this station and date range.
#
#                     <a class="alert-link" href="/readings?station=EPA-92&amp;dateFrom=23+Feb+2025&amp;dateTo=23+Feb+2025">View most recent readings</a>
# </p>]
# https://airquality.ie/readings?station=EPA-93&dateFrom=01+Jan+2023&dateTo=30+Jun+2023
# [<p class="m-0">
#                     No data found for this station and date range.
#                                     </p>]
# https://airquality.ie/readings?station=EPA-94&dateFrom=01+Jan+2023&dateTo=30+Jun+2023
# [<p class="m-0">
#                     No data found for this station and date range.
#                                     </p>]
# https://airquality.ie/readings?station=EPA-95&dateFrom=01+Jan+2023&dateTo=30+Jun+2023
# [<p class="m-0">
#                     No data found for this station and date range.
#                                     </p>]
# https://airquality.ie/readings?station=EPA-96&dateFrom=01+Jan+2023&dateTo=30+Jun+2023
# [<p class="m-0">
#                     No data found for this station and date range.
#                                     </p>]
# https://airquality.ie/readings?station=EPA-97&dateFrom=01+Jan+2023&dateTo=30+Jun+2023
# [<p class="m-0">
#                     No data found for this station and date range.
#                                     </p>]
# https://airquality.ie/readings?station=EPA-98&dateFrom=01+Jan+2023&dateTo=30+Jun+2023
# [<p class="m-0">
#                     No data found for this station and date range.
#                                     </p>]
# https://airquality.ie/readings?station=EPA-99&dateFrom=01+Jan+2023&dateTo=30+Jun+2023
# [<p class="m-0">
#                     No data found for this station and date range.
#                                     </p>]
# https://airquality.ie/readings?station=EPA-100&dateFrom=01+Jan+2023&dateTo=30+Jun+2023
# [<p class="m-0">
#                     No data found for this station and date range.
#                                     </p>]
# https://airquality.ie/readings?station=EPA-101&dateFrom=01+Jan+2023&dateTo=30+Jun+2023
# Air Quality Levels at Greystones Fire Station'
# https://airquality.ie/readings?station=EPA-102&dateFrom=01+Jan+2023&dateTo=30+Jun+2023
# Air Quality Levels at Edenderry Library, Co. Offaly'
# https://airquality.ie/readings?station=EPA-103&dateFrom=01+Jan+2023&dateTo=30+Jun+2023
# Air Quality Levels at Claremorris, Co. Mayo'
# https://airquality.ie/readings?station=EPA-104&dateFrom=01+Jan+2023&dateTo=30+Jun+2023
# Air Quality Levels at Cork Lower Glanmire Road'
# https://airquality.ie/readings?station=EPA-105&dateFrom=01+Jan+2023&dateTo=30+Jun+2023
# Air Quality Levels at Eyre Square, Galway'
# https://airquality.ie/readings?station=EPA-106&dateFrom=01+Jan+2023&dateTo=30+Jun+2023
# Air Quality Levels at Leixlip Library, Co. Kildare'
# https://airquality.ie/readings?station=EPA-107&dateFrom=01+Jan+2023&dateTo=30+Jun+2023
# Air Quality Levels at Killarney Anam Arts and Cultural Centre, Co. Kerry'
# https://airquality.ie/readings?station=EPA-108&dateFrom=01+Jan+2023&dateTo=30+Jun+2023
# Air Quality Levels at Lucan, Co. Dublin'
# https://airquality.ie/readings?station=EPA-109&dateFrom=01+Jan+2023&dateTo=30+Jun+2023
# Air Quality Levels at Briarhill, Co. Galway'

# %%
#2021 ... 17,21-29,33,34,36,39,43-54,56-64,66-72,74-85,101-103,  done 10,11,13,16 still to be done
#2022 ... 17,21-29,33,34,36,39,43-54,56-64,66-72,74-76,78-80,82-85,101-109
#2023 ... 17,21-29,33,34,36,39,43-64,66-67 stuck on 67..

# %%
#url to scrape
url='https://airquality.ie/readings?station=EPA-16&dateFrom=01+Jan+2023&dateTo=30+Jun+2023'
#create content to scrape
r = requests.get(url)
#r = requests.get(url,headers={'user-agent':'some agent'})
#html_doc= r.text
#soup = BeautifulSoup(html_doc)
soup = BeautifulSoup(r.content, 'html.parser')

print(soup)

# %%
dataset.head(10)
# Out:
#             Timestamp  Value   PM                                 Location
# 0 2023-07-01 01:00:00  17.02  2.5  Air Quality Levels at Ennis, Co. Clare'
# 1 2023-07-01 02:00:00  13.70  2.5  Air Quality Levels at Ennis, Co. Clare'
# 2 2023-07-01 03:00:00  11.32  2.5  Air Quality Levels at Ennis, Co. Clare'
# 3 2023-07-01 04:00:00  15.25  2.5  Air Quality Levels at Ennis, Co. Clare'
# 4 2023-07-01 05:00:00  17.57  2.5  Air Quality Levels at Ennis, Co. Clare'
# 5 2023-07-01 06:00:00  22.84  2.5  Air Quality Levels at Ennis, Co. Clare'
# 6 2023-07-01 07:00:00  30.43  2.5  Air Quality Levels at Ennis, Co. Clare'
# 7 2023-07-01 08:00:00  25.79  2.5  Air Quality Levels at Ennis, Co. Clare'
# 8 2023-07-01 09:00:00  22.03  2.5  Air Quality Levels at Ennis, Co. Clare'
# 9 2023-07-01 10:00:00  21.50  2.5  Air Quality Levels at Ennis, Co. Clare'

# %%
newdata
# Out:
#                Timestamp  Value  PM  \
# 0    2023-01-01 01:00:00   98.0  10
# 1    2023-01-01 02:00:00   77.0  10
# 2    2023-01-01 03:00:00   43.0  10
# 3    2023-01-01 04:00:00   29.0  10
# 4    2023-01-01 05:00:00   38.0  10
# ...                  ...    ...  ..
# 4118 2023-06-30 19:00:00    6.0  10
# 4119 2023-06-30 20:00:00   11.0  10
# 4120 2023-06-30 21:00:00    6.0  10
# 4121 2023-06-30 22:00:00    5.0  10
# 4122 2023-06-30 23:00:00    8.0  10
#
#                                         Location
# 0     Air Quality Levels at Castlebar, Co. Mayo'
# 1     Air Quality Levels at Castlebar, Co. Mayo'
# 2     Air Quality Levels at Castlebar, Co. Mayo'
# 3     Air Quality Levels at Castlebar, Co. Mayo'
# 4     Air Quality Levels at Castlebar, Co. Mayo'
# ...                                          ...
# 4118  Air Quality Levels at Castlebar, Co. Mayo'
# 4119  Air Quality Levels at Castlebar, Co. Mayo'
# 4120  Air Quality Levels at Castlebar, Co. Mayo'
# 4121  Air Quality Levels at Castlebar, Co. Mayo'
# 4122  Air Quality Levels at Castlebar, Co. Mayo'
#
# [4123 rows x 4 columns]

# %%
mydata
# Out:
# [{'Timestamp': datetime.datetime(2023, 1, 1, 1, 0),
#   'Value': 98.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 1, 2, 0),
#   'Value': 77.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 1, 3, 0),
#   'Value': 43.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 1, 4, 0),
#   'Value': 29.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 1, 5, 0),
#   'Value': 38.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 1, 6, 0),
#   'Value': 41.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 1, 7, 0),
#   'Value': 44.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 1, 8, 0),
#   'Value': 31.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 1, 9, 0),
#   'Value': 21.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 1, 10, 0),
#   'Value': 23.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 1, 11, 0),
#   'Value': 25.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 1, 12, 0),
#   'Value': 21.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 1, 13, 0),
#   'Value': 18.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 1, 14, 0),
#   'Value': 17.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 1, 15, 0),
#   'Value': 10.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 1, 16, 0),
#   'Value': 14.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 1, 17, 0),
#   'Value': 32.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 1, 18, 0),
#   'Value': 36.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 1, 19, 0),
#   'Value': 23.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 1, 20, 0),
#   'Value': 15.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 1, 21, 0),
#   'Value': 14.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 1, 22, 0),
#   'Value': 10.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 1, 23, 0),
#   'Value': 17.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 2, 0, 0),
#   'Value': 12.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 2, 1, 0),
#   'Value': 7.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 2, 2, 0),
#   'Value': 7.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 2, 3, 0),
#   'Value': 8.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 2, 4, 0),
#   'Value': 7.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 2, 5, 0),
#   'Value': 9.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 2, 6, 0),
#   'Value': 7.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 2, 7, 0),
#   'Value': 6.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 2, 8, 0),
#   'Value': 6.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 2, 9, 0),
#   'Value': 12.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 2, 10, 0),
#   'Value': 15.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 2, 11, 0),
#   'Value': 12.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 2, 12, 0),
#   'Value': 8.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 2, 13, 0),
#   'Value': 10.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 2, 14, 0),
#   'Value': 15.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 2, 15, 0),
#   'Value': 13.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 2, 16, 0),
#   'Value': 16.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 2, 17, 0),
#   'Value': 13.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 2, 18, 0),
#   'Value': 11.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 2, 19, 0),
#   'Value': 31.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 2, 20, 0),
#   'Value': 17.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 2, 21, 0),
#   'Value': 11.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 2, 22, 0),
#   'Value': 16.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 2, 23, 0),
#   'Value': 16.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 3, 0, 0),
#   'Value': 10.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 3, 1, 0),
#   'Value': 7.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 3, 2, 0),
#   'Value': 5.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 3, 3, 0),
#   'Value': 5.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 3, 4, 0),
#   'Value': 5.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 3, 5, 0),
#   'Value': 8.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 3, 6, 0),
#   'Value': 15.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 3, 7, 0),
#   'Value': 12.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 3, 8, 0),
#   'Value': 12.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 3, 9, 0),
#   'Value': 7.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 3, 10, 0),
#   'Value': 11.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 3, 11, 0),
#   'Value': 9.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 3, 12, 0),
#   'Value': 5.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 3, 13, 0),
#   'Value': 3.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 3, 14, 0),
#   'Value': 1.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 3, 15, 0),
#   'Value': 1.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 3, 16, 0),
#   'Value': 12.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 3, 17, 0),
#   'Value': 13.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 3, 18, 0),
#   'Value': 11.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 3, 19, 0),
#   'Value': 8.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 3, 20, 0),
#   'Value': 9.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 3, 21, 0),
#   'Value': 7.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 3, 22, 0),
#   'Value': 20.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 3, 23, 0),
#   'Value': 17.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 4, 0, 0),
#   'Value': 15.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 4, 1, 0),
#   'Value': 24.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 4, 2, 0),
#   'Value': 32.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 4, 3, 0),
#   'Value': 24.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 4, 4, 0),
#   'Value': 31.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 4, 5, 0),
#   'Value': 33.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 4, 6, 0),
#   'Value': 37.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 4, 7, 0),
#   'Value': 25.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 4, 8, 0),
#   'Value': 26.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 4, 9, 0),
#   'Value': 33.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 4, 10, 0),
#   'Value': 22.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 4, 11, 0),
#   'Value': 26.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 4, 12, 0),
#   'Value': 23.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 4, 13, 0),
#   'Value': 20.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 4, 14, 0),
#   'Value': 24.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 4, 15, 0),
#   'Value': 25.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 4, 16, 0),
#   'Value': 22.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 4, 17, 0),
#   'Value': 9.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 4, 18, 0),
#   'Value': 21.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 4, 19, 0),
#   'Value': 23.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 4, 20, 0),
#   'Value': 17.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 4, 21, 0),
#   'Value': 19.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 4, 22, 0),
#   'Value': 23.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 4, 23, 0),
#   'Value': 26.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 5, 0, 0),
#   'Value': 20.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 5, 1, 0),
#   'Value': 24.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 5, 2, 0),
#   'Value': 18.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 5, 3, 0),
#   'Value': 16.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 5, 4, 0),
#   'Value': 16.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 5, 5, 0),
#   'Value': 10.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 5, 6, 0),
#   'Value': 9.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 5, 7, 0),
#   'Value': 4.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 5, 8, 0),
#   'Value': 15.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 5, 9, 0),
#   'Value': 14.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 5, 10, 0),
#   'Value': 18.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 5, 11, 0),
#   'Value': 15.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 5, 12, 0),
#   'Value': 8.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 5, 13, 0),
#   'Value': 6.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 5, 14, 0),
#   'Value': 23.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 5, 15, 0),
#   'Value': 20.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 5, 16, 0),
#   'Value': 17.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 5, 17, 0),
#   'Value': 22.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 5, 18, 0),
#   'Value': 22.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 5, 19, 0),
#   'Value': 23.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 5, 20, 0),
#   'Value': 19.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 5, 21, 0),
#   'Value': 24.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 5, 22, 0),
#   'Value': 23.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 5, 23, 0),
#   'Value': 27.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 6, 0, 0),
#   'Value': 25.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 6, 1, 0),
#   'Value': 23.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 6, 2, 0),
#   'Value': 27.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 6, 3, 0),
#   'Value': 22.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 6, 4, 0),
#   'Value': 22.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 6, 5, 0),
#   'Value': 18.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 6, 6, 0),
#   'Value': 17.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 6, 7, 0),
#   'Value': 17.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 6, 8, 0),
#   'Value': 17.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 6, 9, 0),
#   'Value': 18.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 6, 10, 0),
#   'Value': 18.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 6, 11, 0),
#   'Value': 9.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 6, 12, 0),
#   'Value': 8.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 6, 13, 0),
#   'Value': 11.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 6, 14, 0),
#   'Value': 13.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 6, 15, 0),
#   'Value': 17.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 6, 16, 0),
#   'Value': 14.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 6, 17, 0),
#   'Value': 12.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 6, 18, 0),
#   'Value': 9.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 6, 19, 0),
#   'Value': 10.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 6, 20, 0),
#   'Value': 13.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 6, 21, 0),
#   'Value': 8.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 6, 22, 0),
#   'Value': 20.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 6, 23, 0),
#   'Value': 23.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 7, 0, 0),
#   'Value': 21.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 7, 1, 0),
#   'Value': 24.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 7, 2, 0),
#   'Value': 27.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 7, 3, 0),
#   'Value': 26.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 7, 4, 0),
#   'Value': 26.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 7, 5, 0),
#   'Value': 25.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 7, 6, 0),
#   'Value': 31.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 7, 7, 0),
#   'Value': 23.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 7, 8, 0),
#   'Value': 20.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 7, 9, 0),
#   'Value': 13.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 7, 10, 0),
#   'Value': 20.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 7, 11, 0),
#   'Value': 14.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 7, 12, 0),
#   'Value': 11.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 7, 13, 0),
#   'Value': 10.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 7, 14, 0),
#   'Value': 14.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 7, 15, 0),
#   'Value': 16.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 7, 16, 0),
#   'Value': 9.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 7, 17, 0),
#   'Value': 16.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 7, 18, 0),
#   'Value': 21.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 7, 19, 0),
#   'Value': 24.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 7, 20, 0),
#   'Value': 26.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 7, 21, 0),
#   'Value': 27.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 7, 22, 0),
#   'Value': 26.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 7, 23, 0),
#   'Value': 42.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 8, 0, 0),
#   'Value': 31.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 8, 1, 0),
#   'Value': 31.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 8, 2, 0),
#   'Value': 44.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 8, 3, 0),
#   'Value': 33.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 8, 4, 0),
#   'Value': 34.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 8, 5, 0),
#   'Value': 33.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 8, 6, 0),
#   'Value': 31.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 8, 7, 0),
#   'Value': 37.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 8, 8, 0),
#   'Value': 27.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 8, 9, 0),
#   'Value': 32.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 8, 10, 0),
#   'Value': 25.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 8, 11, 0),
#   'Value': 22.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 8, 12, 0),
#   'Value': 10.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 8, 13, 0),
#   'Value': 9.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 8, 14, 0),
#   'Value': 15.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 8, 15, 0),
#   'Value': 17.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 8, 16, 0),
#   'Value': 18.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 8, 17, 0),
#   'Value': 22.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 8, 18, 0),
#   'Value': 18.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 8, 19, 0),
#   'Value': 17.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 8, 20, 0),
#   'Value': 20.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 8, 21, 0),
#   'Value': 19.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 8, 22, 0),
#   'Value': 23.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 8, 23, 0),
#   'Value': 19.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 9, 0, 0),
#   'Value': 16.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 9, 1, 0),
#   'Value': 5.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 9, 2, 0),
#   'Value': 15.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 9, 3, 0),
#   'Value': 17.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 9, 4, 0),
#   'Value': 15.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 9, 5, 0),
#   'Value': 22.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 9, 6, 0),
#   'Value': 17.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 9, 7, 0),
#   'Value': 17.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 9, 8, 0),
#   'Value': 18.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 9, 9, 0),
#   'Value': 16.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 9, 10, 0),
#   'Value': 17.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 9, 11, 0),
#   'Value': 21.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 9, 12, 0),
#   'Value': 24.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 9, 13, 0),
#   'Value': 30.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 9, 14, 0),
#   'Value': 31.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 9, 15, 0),
#   'Value': 18.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 9, 16, 0),
#   'Value': 27.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 9, 17, 0),
#   'Value': 35.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 9, 18, 0),
#   'Value': 32.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 9, 19, 0),
#   'Value': 32.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 9, 20, 0),
#   'Value': 24.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 9, 21, 0),
#   'Value': 20.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 9, 22, 0),
#   'Value': 26.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 9, 23, 0),
#   'Value': 27.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 10, 0, 0),
#   'Value': 21.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 10, 1, 0),
#   'Value': 25.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 10, 2, 0),
#   'Value': 18.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 10, 3, 0),
#   'Value': 13.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 10, 4, 0),
#   'Value': 10.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 10, 5, 0),
#   'Value': 7.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 10, 6, 0),
#   'Value': 6.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 10, 7, 0),
#   'Value': 3.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 10, 8, 0),
#   'Value': 2.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 10, 9, 0),
#   'Value': 1.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 10, 10, 0),
#   'Value': 1.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 10, 11, 0),
#   'Value': 4.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 10, 12, 0),
#   'Value': 3.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 10, 13, 0),
#   'Value': 4.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 10, 14, 0),
#   'Value': 12.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 10, 15, 0),
#   'Value': 11.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 10, 16, 0),
#   'Value': 12.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 10, 17, 0),
#   'Value': 15.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 10, 18, 0),
#   'Value': 15.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 10, 19, 0),
#   'Value': 20.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 10, 20, 0),
#   'Value': 33.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 10, 21, 0),
#   'Value': 31.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 10, 22, 0),
#   'Value': 25.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 10, 23, 0),
#   'Value': 22.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 11, 0, 0),
#   'Value': 26.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 11, 1, 0),
#   'Value': 16.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 11, 2, 0),
#   'Value': 11.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 11, 3, 0),
#   'Value': 25.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 11, 4, 0),
#   'Value': 25.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 11, 5, 0),
#   'Value': 36.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 11, 6, 0),
#   'Value': 23.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 11, 7, 0),
#   'Value': 20.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 11, 8, 0),
#   'Value': 17.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 11, 9, 0),
#   'Value': 16.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 11, 10, 0),
#   'Value': 28.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 11, 11, 0),
#   'Value': 13.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 11, 12, 0),
#   'Value': 18.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 11, 13, 0),
#   'Value': 29.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 11, 14, 0),
#   'Value': 32.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 11, 15, 0),
#   'Value': 31.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 11, 16, 0),
#   'Value': 39.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 11, 17, 0),
#   'Value': 40.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 11, 18, 0),
#   'Value': 30.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 11, 19, 0),
#   'Value': 15.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 11, 20, 0),
#   'Value': 19.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 11, 21, 0),
#   'Value': 14.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 11, 22, 0),
#   'Value': 16.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 11, 23, 0),
#   'Value': 19.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 12, 0, 0),
#   'Value': 10.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 12, 1, 0),
#   'Value': 15.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 12, 2, 0),
#   'Value': 7.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 12, 3, 0),
#   'Value': 14.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 12, 4, 0),
#   'Value': 36.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 12, 5, 0),
#   'Value': 35.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 12, 6, 0),
#   'Value': 23.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 12, 7, 0),
#   'Value': 19.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 12, 8, 0),
#   'Value': 42.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 12, 9, 0),
#   'Value': 43.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 12, 10, 0),
#   'Value': 35.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 12, 11, 0),
#   'Value': 36.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 12, 12, 0),
#   'Value': 20.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 12, 13, 0),
#   'Value': 29.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 12, 14, 0),
#   'Value': 36.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 12, 15, 0),
#   'Value': 29.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 12, 16, 0),
#   'Value': 40.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 12, 17, 0),
#   'Value': 29.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 12, 18, 0),
#   'Value': 32.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 12, 19, 0),
#   'Value': 50.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 12, 20, 0),
#   'Value': 31.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 12, 21, 0),
#   'Value': 26.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 12, 22, 0),
#   'Value': 18.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 12, 23, 0),
#   'Value': 23.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 13, 0, 0),
#   'Value': 17.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 13, 1, 0),
#   'Value': 17.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 13, 2, 0),
#   'Value': 13.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 13, 3, 0),
#   'Value': 13.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 13, 4, 0),
#   'Value': 13.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 13, 5, 0),
#   'Value': 28.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 13, 6, 0),
#   'Value': 22.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 13, 7, 0),
#   'Value': 15.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 13, 8, 0),
#   'Value': 16.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 13, 9, 0),
#   'Value': 18.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 13, 10, 0),
#   'Value': 17.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 13, 11, 0),
#   'Value': 28.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 13, 12, 0),
#   'Value': 24.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 13, 13, 0),
#   'Value': 26.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 13, 14, 0),
#   'Value': 32.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 13, 15, 0),
#   'Value': 20.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 13, 16, 0),
#   'Value': 27.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 16, 18, 0),
#   'Value': 34.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 16, 19, 0),
#   'Value': 43.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 16, 20, 0),
#   'Value': 76.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 16, 21, 0),
#   'Value': 211.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 16, 22, 0),
#   'Value': 158.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 16, 23, 0),
#   'Value': 109.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 17, 0, 0),
#   'Value': 54.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 17, 1, 0),
#   'Value': 54.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 17, 2, 0),
#   'Value': 46.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 17, 3, 0),
#   'Value': 17.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 17, 4, 0),
#   'Value': 20.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 17, 5, 0),
#   'Value': 18.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 17, 6, 0),
#   'Value': 10.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 17, 7, 0),
#   'Value': 15.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 17, 8, 0),
#   'Value': 15.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 17, 9, 0),
#   'Value': 11.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 17, 10, 0),
#   'Value': 8.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 17, 11, 0),
#   'Value': 6.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 17, 12, 0),
#   'Value': 12.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 17, 13, 0),
#   'Value': 16.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 17, 14, 0),
#   'Value': 9.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 17, 15, 0),
#   'Value': 9.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 17, 16, 0),
#   'Value': 8.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 17, 17, 0),
#   'Value': 12.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 17, 18, 0),
#   'Value': 12.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 17, 19, 0),
#   'Value': 16.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 17, 20, 0),
#   'Value': 16.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 17, 21, 0),
#   'Value': 12.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 17, 22, 0),
#   'Value': 16.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 17, 23, 0),
#   'Value': 14.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 18, 0, 0),
#   'Value': 12.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 1, 18, 1, 0),
#   'Value': 17.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
# ...
#   'Value': 21.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 2, 13, 2, 0),
#   'Value': 17.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 2, 13, 3, 0),
#   'Value': 24.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 2, 13, 4, 0),
#   'Value': 31.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 2, 13, 5, 0),
#   'Value': 22.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 2, 13, 6, 0),
#   'Value': 24.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 2, 13, 7, 0),
#   'Value': 21.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 2, 13, 8, 0),
#   'Value': 20.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 2, 13, 9, 0),
#   'Value': 22.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 2, 13, 10, 0),
#   'Value': 27.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 2, 13, 11, 0),
#   'Value': 20.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 2, 13, 12, 0),
#   'Value': 25.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 2, 13, 13, 0),
#   'Value': 24.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 2, 13, 14, 0),
#   'Value': 30.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 2, 13, 15, 0),
#   'Value': 26.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 2, 13, 16, 0),
#   'Value': 26.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 2, 13, 17, 0),
#   'Value': 20.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 2, 13, 18, 0),
#   'Value': 27.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 2, 13, 19, 0),
#   'Value': 27.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 2, 13, 20, 0),
#   'Value': 34.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 2, 13, 21, 0),
#   'Value': 29.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 2, 13, 22, 0),
#   'Value': 31.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 2, 13, 23, 0),
#   'Value': 27.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 2, 14, 0, 0),
#   'Value': 24.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 2, 14, 1, 0),
#   'Value': 22.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 2, 14, 2, 0),
#   'Value': 19.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 2, 14, 3, 0),
#   'Value': 20.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 2, 14, 4, 0),
#   'Value': 21.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 2, 14, 5, 0),
#   'Value': 21.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 2, 14, 6, 0),
#   'Value': 22.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 2, 14, 7, 0),
#   'Value': 16.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 2, 14, 8, 0),
#   'Value': 13.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 2, 14, 9, 0),
#   'Value': 18.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 2, 14, 10, 0),
#   'Value': 17.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 2, 14, 11, 0),
#   'Value': 15.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 2, 14, 12, 0),
#   'Value': 10.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 2, 14, 13, 0),
#   'Value': 9.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 2, 14, 14, 0),
#   'Value': 34.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 2, 14, 15, 0),
#   'Value': 45.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 2, 14, 16, 0),
#   'Value': 57.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 2, 14, 17, 0),
#   'Value': 59.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 2, 14, 18, 0),
#   'Value': 58.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 2, 14, 19, 0),
#   'Value': 50.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 2, 14, 20, 0),
#   'Value': 41.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 2, 14, 21, 0),
#   'Value': 42.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 2, 14, 22, 0),
#   'Value': 37.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 2, 14, 23, 0),
#   'Value': 38.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 2, 15, 0, 0),
#   'Value': 33.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 2, 15, 1, 0),
#   'Value': 35.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 2, 15, 2, 0),
#   'Value': 14.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 2, 15, 3, 0),
#   'Value': 9.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 2, 15, 4, 0),
#   'Value': 9.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 2, 15, 5, 0),
#   'Value': 9.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 2, 15, 6, 0),
#   'Value': 6.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 2, 15, 7, 0),
#   'Value': 5.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 2, 15, 8, 0),
#   'Value': 8.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 2, 15, 9, 0),
#   'Value': 8.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 2, 15, 10, 0),
#   'Value': 7.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 2, 15, 11, 0),
#   'Value': 16.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 2, 15, 12, 0),
#   'Value': 15.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 2, 15, 13, 0),
#   'Value': 15.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 2, 15, 14, 0),
#   'Value': 12.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 2, 15, 15, 0),
#   'Value': 20.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 2, 15, 16, 0),
#   'Value': 16.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 2, 15, 17, 0),
#   'Value': 18.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 2, 15, 18, 0),
#   'Value': 17.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 2, 15, 19, 0),
#   'Value': 14.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 2, 15, 20, 0),
#   'Value': 17.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 2, 15, 21, 0),
#   'Value': 20.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 2, 15, 22, 0),
#   'Value': 12.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 2, 15, 23, 0),
#   'Value': 14.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 2, 16, 0, 0),
#   'Value': 8.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 2, 16, 1, 0),
#   'Value': 5.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 2, 16, 2, 0),
#   'Value': 9.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 2, 16, 3, 0),
#   'Value': 6.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 2, 16, 4, 0),
#   'Value': 7.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 2, 16, 5, 0),
#   'Value': 7.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 2, 16, 6, 0),
#   'Value': 9.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 2, 16, 7, 0),
#   'Value': 9.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 2, 16, 8, 0),
#   'Value': 9.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 2, 16, 9, 0),
#   'Value': 6.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 2, 16, 10, 0),
#   'Value': 8.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 2, 16, 11, 0),
#   'Value': 11.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 2, 16, 12, 0),
#   'Value': 8.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 2, 16, 13, 0),
#   'Value': 5.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 2, 16, 14, 0),
#   'Value': 5.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 2, 16, 15, 0),
#   'Value': 4.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 2, 16, 16, 0),
#   'Value': 2.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 2, 16, 17, 0),
#   'Value': 9.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 2, 16, 18, 0),
#   'Value': 8.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 2, 16, 19, 0),
#   'Value': 5.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 2, 16, 20, 0),
#   'Value': 9.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 2, 16, 21, 0),
#   'Value': 12.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 2, 16, 22, 0),
#   'Value': 9.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 2, 16, 23, 0),
#   'Value': 9.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 2, 17, 0, 0),
#   'Value': 5.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 2, 17, 1, 0),
#   'Value': 7.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 2, 17, 2, 0),
#   'Value': 6.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 2, 17, 3, 0),
#   'Value': 4.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 2, 17, 4, 0),
#   'Value': 2.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 2, 17, 5, 0),
#   'Value': 6.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 2, 17, 6, 0),
#   'Value': 25.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 2, 17, 7, 0),
#   'Value': 34.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 2, 17, 8, 0),
#   'Value': 24.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 2, 17, 9, 0),
#   'Value': 12.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 2, 17, 10, 0),
#   'Value': 21.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 2, 17, 11, 0),
#   'Value': 26.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 2, 17, 12, 0),
#   'Value': 33.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 2, 17, 13, 0),
#   'Value': 27.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 2, 17, 14, 0),
#   'Value': 36.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 2, 17, 15, 0),
#   'Value': 29.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  {'Timestamp': datetime.datetime(2023, 2, 17, 16, 0),
#   'Value': 29.0,
#   'PM': 10,
#   'Location': "Air Quality Levels at Castlebar, Co. Mayo'"},
#  ...]

# %%
dataset
# Out:
#                Timestamp  Value    PM  \
# 0    2023-01-01 01:00:00  98.00  10.0
# 1    2023-01-01 02:00:00  77.00  10.0
# 2    2023-01-01 03:00:00  43.00  10.0
# 3    2023-01-01 04:00:00  29.00  10.0
# 4    2023-01-01 05:00:00  38.00  10.0
# ...                  ...    ...   ...
# 8599 2023-06-30 19:00:00   7.55  10.0
# 8600 2023-06-30 20:00:00   8.13  10.0
# 8601 2023-06-30 21:00:00   8.36  10.0
# 8602 2023-06-30 22:00:00   9.38  10.0
# 8603 2023-06-30 23:00:00   9.83  10.0
#
#                                         Location
# 0     Air Quality Levels at Castlebar, Co. Mayo'
# 1     Air Quality Levels at Castlebar, Co. Mayo'
# 2     Air Quality Levels at Castlebar, Co. Mayo'
# 3     Air Quality Levels at Castlebar, Co. Mayo'
# 4     Air Quality Levels at Castlebar, Co. Mayo'
# ...                                          ...
# 8599     Air Quality Levels at Ennis, Co. Clare'
# 8600     Air Quality Levels at Ennis, Co. Clare'
# 8601     Air Quality Levels at Ennis, Co. Clare'
# 8602     Air Quality Levels at Ennis, Co. Clare'
# 8603     Air Quality Levels at Ennis, Co. Clare'
#
# [12727 rows x 4 columns]

# %%
#put it together with more variables and date ranges so it can pull all locations, all months for all specified years.
#starting date point
#dateFrom = '01+Jan+'
dateFrom = '01+Jul+'
#end date point
#dateTo = '30+Jun+'
dateTo = '31+Dec+'
#years to capture
year = {2023}

dataset = pd.DataFrame(columns=["Timestamp", "Value", "PM", "Location"])
#all_dataset = pd.DataFrame(columns=["Timestamp", "Value", "PM", "Location"])

for y in year:
    for i in range(10,110):#range should go to 110
        
        #break the url up into the string and variables
        url='https://airquality.ie/readings?station=EPA-'+str(i)+'&dateFrom='+dateFrom+str(y)+'&dateTo='+dateTo+str(y)
        #print it to keep track of which location and date is being processes as the script is running
        print(url)
        #create content to scrape
        r = requests.get(url)
        soup = BeautifulSoup(r.content, 'html.parser')
        #print(soup)
        #if there is no data the m-0 class is called with a no data message..
        no_data = soup.select(".m-0")
        if no_data:
            #print to track what locations exist/don't exist
            print(no_data)
        else:
            # find the date and values within the data tag..
            get_data = soup.find_all('script')#, string=re.compile('Date.UTC')).string
            #print("get_data")
            #print(get_data)
         #   print("get_data.string")
        #    print(get_data.string)
            #look for the same message to get the location of the air quality monitor, begins with Air Quality Levels at then has a comma and ends with a single quote.
            location = re.search(r"Air Quality Levels at.*?,*?'", str(get_data))

            #if location exists assign it.. otherwise mark it as unknown
            if location:
                loc = location.group(0)
                print(loc)
            else:
                loc = "Unknown Location"

            #look for PM2.5 data
            pm2_5 = re.search(r'"PM2.5",', str(get_data))
            pm2_5_values = []

            #if it exists pull the full block from pm2.5 to //endforeach to get all timestamp and pm values data
            if pm2_5:
                pattern = r'"PM2.5".*?//endforeach'
                
                #search for the entire block from 'pm2_5' to '//endforeach'
                pm2_5_data_block = re.search(pattern, str(get_data), re.DOTALL)
              #  print(pm2_5_data_block.group(0))
                if pm2_5_data_block:
                    #print(pm2_5_data_block)
                    #asked chatgpt to 'give me the regex to parse this date and value, [ Date.UTC(2023,0,9,4,0,0), 2.86]'
                    #match the timestamp and value portion only
                    pattern = r'Date\.UTC\((\d+),(\d+),(\d+),(\d+),(\d+),(\d+)\),\s*([\d.]+)'
      
                   #get all matches in the pm2.5 block only
                    pm2_5_values = re.findall(pattern, pm2_5_data_block.group(0))
                else:
                    print("No match found")

            #print(pm2_5_values)
            
            #do the same again for pm10
            pm10 = re.search(r'"PM10",', str(get_data))
            pm10_values = []
            if pm10:
                pattern = r'"PM10".*?//endforeach'
                
                #search for the entire block from 'pm10' to '//endforeach'
                pm10_data_block = re.search(pattern,str(get_data), re.DOTALL)

                #get all matches in the pm10 block only
                if pm10_data_block:
                    pattern = r'Date\.UTC\((\d+),(\d+),(\d+),(\d+),(\d+),(\d+)\),\s*([\d.]+)'
                    pm10_values = re.findall(pattern, pm10_data_block.group(0))
                else:
                    print("No match found")

            #print(pm10_values)
            pm_val = float
        
            #assign the values to the name of the pm type for easier adding to the dataset
            records = {'pm_2.5':pm2_5_values,'pm_10':pm10_values}
            # print(records)
            mydata = []
            if records:
                #get the key value pairs
                for key, vals in records.items():
                    #define the pm_val based on the key
                    if key == 'pm_2.5':
                        pm_val = 2.5
                    elif key == 'pm_10':
                        pm_val = 10
                    else:
                        pm_val = 0  #0 can be used for unknown so it doesn't break the parser

                    #parse out the values into the timestamps and pm vals
                    for val in vals:
                     #   print(val)
                        year, month, day, hour, minute, second, value = map(float, val)
                        #add 1 to the month as it looks like January = month 0 (days not affected)
                        timestamp = datetime(int(year), int(month)+1, int(day), int(hour), int(minute), int(second))
                    
                        #put it together in a data frame
                        mydata.append({"Timestamp": timestamp, "Value": float(value), "PM":pm_val, "Location": loc})

        newdata = pd.DataFrame(mydata)      
        dataset = pd.concat([newdata,dataset])
#save to a csv file so it's available to read in (but don't open and save as it will have millions of rows and they will be lost by Excel!
dataset.to_csv('air_quality_data_Jul_Dec_2023.csv', index=False)
# Out:
# https://airquality.ie/readings?station=EPA-10&dateFrom=01+Jul+2023&dateTo=31+Dec+2023
# Air Quality Levels at Heatherton Park, Cork'
# https://airquality.ie/readings?station=EPA-11&dateFrom=01+Jul+2023&dateTo=31+Dec+2023
# C:\Users\lsmyth\AppData\Local\Temp\ipykernel_24844\1458424820.py:116: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   dataset = pd.concat([newdata,dataset])
# Air Quality Levels at Winetavern Street, Dublin 8'
# https://airquality.ie/readings?station=EPA-12&dateFrom=01+Jul+2023&dateTo=31+Dec+2023
# [<p class="m-0">
#                     No data found for this station and date range.
#                                     </p>]
# https://airquality.ie/readings?station=EPA-13&dateFrom=01+Jul+2023&dateTo=31+Dec+2023
# Air Quality Levels at Bray, Co. Wicklow'
# https://airquality.ie/readings?station=EPA-14&dateFrom=01+Jul+2023&dateTo=31+Dec+2023
# [<p class="m-0">
#                     No data found for this station and date range.
#                                     </p>]
# https://airquality.ie/readings?station=EPA-15&dateFrom=01+Jul+2023&dateTo=31+Dec+2023
# [<p class="m-0">
#                     No data found for this station and date range.
#                                     </p>]
# https://airquality.ie/readings?station=EPA-16&dateFrom=01+Jul+2023&dateTo=31+Dec+2023
# Air Quality Levels at Portlaoise, Co. Laois'
# https://airquality.ie/readings?station=EPA-17&dateFrom=01+Jul+2023&dateTo=31+Dec+2023
# Air Quality Levels at Ringsend, Dublin 4'
# https://airquality.ie/readings?station=EPA-18&dateFrom=01+Jul+2023&dateTo=31+Dec+2023
# [<p class="m-0">
#                     No data found for this station and date range.
#                                     </p>]
# https://airquality.ie/readings?station=EPA-19&dateFrom=01+Jul+2023&dateTo=31+Dec+2023
# [<p class="m-0">
#                     No data found for this station and date range.
#                                     </p>]
# https://airquality.ie/readings?station=EPA-20&dateFrom=01+Jul+2023&dateTo=31+Dec+2023
# [<p class="m-0">
#                     No data found for this station and date range.
#                                     </p>]
# https://airquality.ie/readings?station=EPA-21&dateFrom=01+Jul+2023&dateTo=31+Dec+2023
# Air Quality Levels at University College Cork'
# https://airquality.ie/readings?station=EPA-22&dateFrom=01+Jul+2023&dateTo=31+Dec+2023
# Air Quality Levels at Rathmines, Dublin 6'
# https://airquality.ie/readings?station=EPA-23&dateFrom=01+Jul+2023&dateTo=31+Dec+2023
# Air Quality Levels at Dundalk, Co. Louth'
# https://airquality.ie/readings?station=EPA-24&dateFrom=01+Jul+2023&dateTo=31+Dec+2023
# Air Quality Levels at Enniscorthy, Co. Wexford'
# https://airquality.ie/readings?station=EPA-25&dateFrom=01+Jul+2023&dateTo=31+Dec+2023
# Air Quality Levels at Ennis, Co. Clare'
# https://airquality.ie/readings?station=EPA-26&dateFrom=01+Jul+2023&dateTo=31+Dec+2023
# Air Quality Levels at Castlebar, Co. Mayo'
# https://airquality.ie/readings?station=EPA-27&dateFrom=01+Jul+2023&dateTo=31+Dec+2023
# Air Quality Levels at Malin Head, Co. Donegal'
# https://airquality.ie/readings?station=EPA-28&dateFrom=01+Jul+2023&dateTo=31+Dec+2023
# Air Quality Levels at Carnsore Point, Co. Wexford'
# https://airquality.ie/readings?station=EPA-29&dateFrom=01+Jul+2023&dateTo=31+Dec+2023
# Air Quality Levels at Blanchardstown, Dublin 15'
# https://airquality.ie/readings?station=EPA-30&dateFrom=01+Jul+2023&dateTo=31+Dec+2023
# [<p class="m-0">
#                     No data found for this station and date range.
#                                     </p>]
# https://airquality.ie/readings?station=EPA-31&dateFrom=01+Jul+2023&dateTo=31+Dec+2023
# [<p class="m-0">
#                     No data found for this station and date range.
#                                     </p>]
# https://airquality.ie/readings?station=EPA-32&dateFrom=01+Jul+2023&dateTo=31+Dec+2023
# [<p class="m-0">
#                     No data found for this station and date range.
#                                     </p>]
# https://airquality.ie/readings?station=EPA-33&dateFrom=01+Jul+2023&dateTo=31+Dec+2023
# Air Quality Levels at Clonskeagh, Dublin 14'
# https://airquality.ie/readings?station=EPA-34&dateFrom=01+Jul+2023&dateTo=31+Dec+2023
# Air Quality Levels at Dún Laoghaire, Co. Dublin'
# https://airquality.ie/readings?station=EPA-35&dateFrom=01+Jul+2023&dateTo=31+Dec+2023
# [<p class="m-0">
#                     No data found for this station and date range.
#                                     </p>]
# https://airquality.ie/readings?station=EPA-36&dateFrom=01+Jul+2023&dateTo=31+Dec+2023
# Air Quality Levels at Callan Road, Kilkenny'
# https://airquality.ie/readings?station=EPA-37&dateFrom=01+Jul+2023&dateTo=31+Dec+2023
# [<p class="m-0">
#                     No data found for this station and date range.
#                                     </p>]
# https://airquality.ie/readings?station=EPA-38&dateFrom=01+Jul+2023&dateTo=31+Dec+2023
# [<p class="m-0">
#                     No data found for this station and date range.
#                                     </p>]
# https://airquality.ie/readings?station=EPA-39&dateFrom=01+Jul+2023&dateTo=31+Dec+2023
# Air Quality Levels at People\'
# https://airquality.ie/readings?station=EPA-40&dateFrom=01+Jul+2023&dateTo=31+Dec+2023
# [<p class="m-0">
#                     No data found for this station and date range.
#                                     </p>]
# https://airquality.ie/readings?station=EPA-41&dateFrom=01+Jul+2023&dateTo=31+Dec+2023
# [<p class="m-0">
#                     No data found for this station and date range.
#                                     </p>]
# https://airquality.ie/readings?station=EPA-42&dateFrom=01+Jul+2023&dateTo=31+Dec+2023
# [<p class="m-0">
#                     No data found for this station and date range.
#                                     </p>]
# https://airquality.ie/readings?station=EPA-43&dateFrom=01+Jul+2023&dateTo=31+Dec+2023
# Air Quality Levels at Longford Town'
# https://airquality.ie/readings?station=EPA-44&dateFrom=01+Jul+2023&dateTo=31+Dec+2023
# Air Quality Levels at Tallaght, Dublin 24'
# https://airquality.ie/readings?station=EPA-45&dateFrom=01+Jul+2023&dateTo=31+Dec+2023
# Air Quality Levels at Valentia Observatory, Caherciveen, Co. Kerry'
# https://airquality.ie/readings?station=EPA-46&dateFrom=01+Jul+2023&dateTo=31+Dec+2023
# Air Quality Levels at Finglas, Dublin 11'
# https://airquality.ie/readings?station=EPA-47&dateFrom=01+Jul+2023&dateTo=31+Dec+2023
# Air Quality Levels at Marino, Dublin 3'
# https://airquality.ie/readings?station=EPA-48&dateFrom=01+Jul+2023&dateTo=31+Dec+2023
# Air Quality Levels at Phoenix Park, Dublin 8'
# https://airquality.ie/readings?station=EPA-49&dateFrom=01+Jul+2023&dateTo=31+Dec+2023
# Air Quality Levels at Davitt Road, Inchicore, Dublin 12'
# https://airquality.ie/readings?station=EPA-50&dateFrom=01+Jul+2023&dateTo=31+Dec+2023
# Air Quality Levels at Ballyfermot, Dublin 10'
# https://airquality.ie/readings?station=EPA-51&dateFrom=01+Jul+2023&dateTo=31+Dec+2023
# Air Quality Levels at Mace Head, Carna, Co. Galway'
# https://airquality.ie/readings?station=EPA-52&dateFrom=01+Jul+2023&dateTo=31+Dec+2023
# Air Quality Levels at St. Anne\'
# https://airquality.ie/readings?station=EPA-53&dateFrom=01+Jul+2023&dateTo=31+Dec+2023
# Air Quality Levels at Roscommon Town'
# https://airquality.ie/readings?station=EPA-54&dateFrom=01+Jul+2023&dateTo=31+Dec+2023
# Air Quality Levels at Carlow Town'
# https://airquality.ie/readings?station=EPA-55&dateFrom=01+Jul+2023&dateTo=31+Dec+2023
# Air Quality Levels at Dublin Airport, Swords, Co. Dublin'
# https://airquality.ie/readings?station=EPA-56&dateFrom=01+Jul+2023&dateTo=31+Dec+2023
# Air Quality Levels at South Link Road, Cork'
# https://airquality.ie/readings?station=EPA-57&dateFrom=01+Jul+2023&dateTo=31+Dec+2023
# Air Quality Levels at St. John’s Road, Kilmainham, Dublin 8'
# https://airquality.ie/readings?station=EPA-58&dateFrom=01+Jul+2023&dateTo=31+Dec+2023
# Air Quality Levels at Kilkitt, Co. Monaghan'
# https://airquality.ie/readings?station=EPA-59&dateFrom=01+Jul+2023&dateTo=31+Dec+2023
# Air Quality Levels at Paddy Browne\'
# https://airquality.ie/readings?station=EPA-60&dateFrom=01+Jul+2023&dateTo=31+Dec+2023
# Air Quality Levels at Cobh Carrignafoy, Co. Cork'
# https://airquality.ie/readings?station=EPA-61&dateFrom=01+Jul+2023&dateTo=31+Dec+2023
# Air Quality Levels at Swords Council Depot, Co. Dublin'
# https://airquality.ie/readings?station=EPA-62&dateFrom=01+Jul+2023&dateTo=31+Dec+2023
# Air Quality Levels at Emo, Co. Laois'
# https://airquality.ie/readings?station=EPA-63&dateFrom=01+Jul+2023&dateTo=31+Dec+2023
# Air Quality Levels at Wexford Opera House'
# https://airquality.ie/readings?station=EPA-64&dateFrom=01+Jul+2023&dateTo=31+Dec+2023
# Air Quality Levels at Letterkenny, Co. Donegal'
# https://airquality.ie/readings?station=EPA-65&dateFrom=01+Jul+2023&dateTo=31+Dec+2023
# [<p class="m-0">
#                     No data found for this station and date range.
#                                     </p>]
# https://airquality.ie/readings?station=EPA-66&dateFrom=01+Jul+2023&dateTo=31+Dec+2023
# Air Quality Levels at Tipperary Town'
# https://airquality.ie/readings?station=EPA-67&dateFrom=01+Jul+2023&dateTo=31+Dec+2023
# Air Quality Levels at Macroom, Co. Cork'
# https://airquality.ie/readings?station=EPA-68&dateFrom=01+Jul+2023&dateTo=31+Dec+2023
# Air Quality Levels at Navan, Co. Meath'
# https://airquality.ie/readings?station=EPA-69&dateFrom=01+Jul+2023&dateTo=31+Dec+2023
# Air Quality Levels at Pearse Street, Dublin 2'
# https://airquality.ie/readings?station=EPA-70&dateFrom=01+Jul+2023&dateTo=31+Dec+2023
# Air Quality Levels at Athlone Civic Centre & Library, Co. Westmeath'
# https://airquality.ie/readings?station=EPA-71&dateFrom=01+Jul+2023&dateTo=31+Dec+2023
# Air Quality Levels at Tralee Library, Co. Kerry'
# https://airquality.ie/readings?station=EPA-72&dateFrom=01+Jul+2023&dateTo=31+Dec+2023
# Air Quality Levels at Cork Harbour'
# https://airquality.ie/readings?station=EPA-73&dateFrom=01+Jul+2023&dateTo=31+Dec+2023
# [<p class="m-0">
#                     No data found for this station and date range.
#                                     </p>]
# https://airquality.ie/readings?station=EPA-74&dateFrom=01+Jul+2023&dateTo=31+Dec+2023
# Air Quality Levels at Askeaton, Co. Limerick'
# https://airquality.ie/readings?station=EPA-75&dateFrom=01+Jul+2023&dateTo=31+Dec+2023
# Air Quality Levels at Clonmel, Co. Tipperary'
# https://airquality.ie/readings?station=EPA-76&dateFrom=01+Jul+2023&dateTo=31+Dec+2023
# Air Quality Levels at Dublin Port, Dublin 1'
# https://airquality.ie/readings?station=EPA-77&dateFrom=01+Jul+2023&dateTo=31+Dec+2023
# [<p class="m-0">
#                     No data found for this station and date range.
#
#                     <a class="alert-link" href="/readings?station=EPA-77&amp;dateFrom=23+Feb+2025&amp;dateTo=23+Feb+2025">View most recent readings</a>
# </p>]
# https://airquality.ie/readings?station=EPA-78&dateFrom=01+Jul+2023&dateTo=31+Dec+2023
# Air Quality Levels at Cavan Town'
# https://airquality.ie/readings?station=EPA-79&dateFrom=01+Jul+2023&dateTo=31+Dec+2023
# Air Quality Levels at Birr, Co. Offaly'
# https://airquality.ie/readings?station=EPA-80&dateFrom=01+Jul+2023&dateTo=31+Dec+2023
# Air Quality Levels at Carrick-on-Shannon, Co. Leitrim'
# https://airquality.ie/readings?station=EPA-81&dateFrom=01+Jul+2023&dateTo=31+Dec+2023
# [<p class="m-0">
#                     No data found for this station and date range.
#                                     </p>]
# https://airquality.ie/readings?station=EPA-82&dateFrom=01+Jul+2023&dateTo=31+Dec+2023
# Air Quality Levels at Mallow, Co. Cork'
# https://airquality.ie/readings?station=EPA-83&dateFrom=01+Jul+2023&dateTo=31+Dec+2023
# Air Quality Levels at Naas, Co. Kildare'
# https://airquality.ie/readings?station=EPA-84&dateFrom=01+Jul+2023&dateTo=31+Dec+2023
# Air Quality Levels at Drogheda, Co. Louth'
# https://airquality.ie/readings?station=EPA-85&dateFrom=01+Jul+2023&dateTo=31+Dec+2023
# Air Quality Levels at Henry Street, Limerick'
# https://airquality.ie/readings?station=EPA-86&dateFrom=01+Jul+2023&dateTo=31+Dec+2023
# [<p class="m-0">
#                     No data found for this station and date range.
#                                     </p>]
# https://airquality.ie/readings?station=EPA-87&dateFrom=01+Jul+2023&dateTo=31+Dec+2023
# Air Quality Levels at Merchants Quay, Waterford City'
# https://airquality.ie/readings?station=EPA-88&dateFrom=01+Jul+2023&dateTo=31+Dec+2023
# Air Quality Levels at Carrigaline, Co. Cork'
# https://airquality.ie/readings?station=EPA-89&dateFrom=01+Jul+2023&dateTo=31+Dec+2023
# Air Quality Levels at Clonakilty, Co. Cork'
# https://airquality.ie/readings?station=EPA-90&dateFrom=01+Jul+2023&dateTo=31+Dec+2023
# Air Quality Levels at Cork Airport'
# https://airquality.ie/readings?station=EPA-91&dateFrom=01+Jul+2023&dateTo=31+Dec+2023
# Air Quality Levels at Amiens Street, Dublin 1'
# https://airquality.ie/readings?station=EPA-92&dateFrom=01+Jul+2023&dateTo=31+Dec+2023
# Air Quality Levels at Ballinasloe, Co. Galway'
# https://airquality.ie/readings?station=EPA-93&dateFrom=01+Jul+2023&dateTo=31+Dec+2023
# [<p class="m-0">
#                     No data found for this station and date range.
#                                     </p>]
# https://airquality.ie/readings?station=EPA-94&dateFrom=01+Jul+2023&dateTo=31+Dec+2023
# [<p class="m-0">
#                     No data found for this station and date range.
#                                     </p>]
# https://airquality.ie/readings?station=EPA-95&dateFrom=01+Jul+2023&dateTo=31+Dec+2023
# [<p class="m-0">
#                     No data found for this station and date range.
#                                     </p>]
# https://airquality.ie/readings?station=EPA-96&dateFrom=01+Jul+2023&dateTo=31+Dec+2023
# [<p class="m-0">
#                     No data found for this station and date range.
#                                     </p>]
# https://airquality.ie/readings?station=EPA-97&dateFrom=01+Jul+2023&dateTo=31+Dec+2023
# [<p class="m-0">
#                     No data found for this station and date range.
#                                     </p>]
# https://airquality.ie/readings?station=EPA-98&dateFrom=01+Jul+2023&dateTo=31+Dec+2023
# [<p class="m-0">
#                     No data found for this station and date range.
#                                     </p>]
# https://airquality.ie/readings?station=EPA-99&dateFrom=01+Jul+2023&dateTo=31+Dec+2023
# [<p class="m-0">
#                     No data found for this station and date range.
#                                     </p>]
# https://airquality.ie/readings?station=EPA-100&dateFrom=01+Jul+2023&dateTo=31+Dec+2023
# [<p class="m-0">
#                     No data found for this station and date range.
#                                     </p>]
# https://airquality.ie/readings?station=EPA-101&dateFrom=01+Jul+2023&dateTo=31+Dec+2023
# Air Quality Levels at Greystones Fire Station'
# https://airquality.ie/readings?station=EPA-102&dateFrom=01+Jul+2023&dateTo=31+Dec+2023
# Air Quality Levels at Edenderry Library, Co. Offaly'
# https://airquality.ie/readings?station=EPA-103&dateFrom=01+Jul+2023&dateTo=31+Dec+2023
# Air Quality Levels at Claremorris, Co. Mayo'
# https://airquality.ie/readings?station=EPA-104&dateFrom=01+Jul+2023&dateTo=31+Dec+2023
# Air Quality Levels at Cork Lower Glanmire Road'
# https://airquality.ie/readings?station=EPA-105&dateFrom=01+Jul+2023&dateTo=31+Dec+2023
# Air Quality Levels at Eyre Square, Galway'
# https://airquality.ie/readings?station=EPA-106&dateFrom=01+Jul+2023&dateTo=31+Dec+2023
# Air Quality Levels at Leixlip Library, Co. Kildare'
# https://airquality.ie/readings?station=EPA-107&dateFrom=01+Jul+2023&dateTo=31+Dec+2023
# Air Quality Levels at Killarney Anam Arts and Cultural Centre, Co. Kerry'
# https://airquality.ie/readings?station=EPA-108&dateFrom=01+Jul+2023&dateTo=31+Dec+2023
# Air Quality Levels at Lucan, Co. Dublin'
# https://airquality.ie/readings?station=EPA-109&dateFrom=01+Jul+2023&dateTo=31+Dec+2023
# Air Quality Levels at Briarhill, Co. Galway'

# %%
#put it together with more variables and date ranges so it can pull all locations, all months for all specified years.
#starting date point
dateFrom = '01+Jan+'
#dateFrom = '01+Jul+'
#end date point
#dateTo = '30+Jun+'
dateTo = '31+Dec+'
#years to capture
year = {2022}

dataset = pd.DataFrame(columns=["Timestamp", "Value", "PM", "Location"])
#all_dataset = pd.DataFrame(columns=["Timestamp", "Value", "PM", "Location"])

for y in year:
    for i in range(10,110):#range should go to 110
        
        #break the url up into the string and variables
        url='https://airquality.ie/readings?station=EPA-'+str(i)+'&dateFrom='+dateFrom+str(y)+'&dateTo='+dateTo+str(y)
        #print it to keep track of which location and date is being processes as the script is running
        print(url)
        #create content to scrape
        r = requests.get(url)
        soup = BeautifulSoup(r.content, 'html.parser')
        #print(soup)
        #if there is no data the m-0 class is called with a no data message..
        no_data = soup.select(".m-0")
        if no_data:
            #print to track what locations exist/don't exist
            print(no_data)
        else:
            # find the date and values within the data tag..
            get_data = soup.find_all('script')#, string=re.compile('Date.UTC')).string
            #print("get_data")
            #print(get_data)
         #   print("get_data.string")
        #    print(get_data.string)
            #look for the same message to get the location of the air quality monitor, begins with Air Quality Levels at then has a comma and ends with a single quote.
            location = re.search(r"Air Quality Levels at.*?,*?'", str(get_data))

            #if location exists assign it.. otherwise mark it as unknown
            if location:
                loc = location.group(0)
                print(loc)
            else:
                loc = "Unknown Location"

            #look for PM2.5 data
            pm2_5 = re.search(r'"PM2.5",', str(get_data))
            pm2_5_values = []

            #if it exists pull the full block from pm2.5 to //endforeach to get all timestamp and pm values data
            if pm2_5:
                pattern = r'"PM2.5".*?//endforeach'
                
                #search for the entire block from 'pm2_5' to '//endforeach'
                pm2_5_data_block = re.search(pattern, str(get_data), re.DOTALL)
              #  print(pm2_5_data_block.group(0))
                if pm2_5_data_block:
                    #print(pm2_5_data_block)
                    #asked chatgpt to 'give me the regex to parse this date and value, [ Date.UTC(2023,0,9,4,0,0), 2.86]'
                    #match the timestamp and value portion only
                    pattern = r'Date\.UTC\((\d+),(\d+),(\d+),(\d+),(\d+),(\d+)\),\s*([\d.]+)'
      
                   #get all matches in the pm2.5 block only
                    pm2_5_values = re.findall(pattern, pm2_5_data_block.group(0))
                else:
                    print("No match found")

            #print(pm2_5_values)
            
            #do the same again for pm10
            pm10 = re.search(r'"PM10",', str(get_data))
            pm10_values = []
            if pm10:
                pattern = r'"PM10".*?//endforeach'
                
                #search for the entire block from 'pm10' to '//endforeach'
                pm10_data_block = re.search(pattern,str(get_data), re.DOTALL)

                #get all matches in the pm10 block only
                if pm10_data_block:
                    pattern = r'Date\.UTC\((\d+),(\d+),(\d+),(\d+),(\d+),(\d+)\),\s*([\d.]+)'
                    pm10_values = re.findall(pattern, pm10_data_block.group(0))
                else:
                    print("No match found")

            #print(pm10_values)
            pm_val = float
        
            #assign the values to the name of the pm type for easier adding to the dataset
            records = {'pm_2.5':pm2_5_values,'pm_10':pm10_values}
            # print(records)
            mydata = []
            if records:
                #get the key value pairs
                for key, vals in records.items():
                    #define the pm_val based on the key
                    if key == 'pm_2.5':
                        pm_val = 2.5
                    elif key == 'pm_10':
                        pm_val = 10
                    else:
                        pm_val = 0  #0 can be used for unknown so it doesn't break the parser

                    #parse out the values into the timestamps and pm vals
                    for val in vals:
                     #   print(val)
                        year, month, day, hour, minute, second, value = map(float, val)
                        #add 1 to the month as it looks like January = month 0 (days not affected)
                        timestamp = datetime(int(year), int(month)+1, int(day), int(hour), int(minute), int(second))
                    
                        #put it together in a data frame
                        mydata.append({"Timestamp": timestamp, "Value": float(value), "PM":pm_val, "Location": loc})

        newdata = pd.DataFrame(mydata)      
        dataset = pd.concat([newdata,dataset])
#save to a csv file so it's available to read in (but don't open and save as it will have millions of rows and they will be lost by Excel!       
dataset.to_csv('air_quality_data_Jan_Dec_2022.csv', index=False)
# Out:
# https://airquality.ie/readings?station=EPA-10&dateFrom=01+Jan+2022&dateTo=31+Dec+2022
# Air Quality Levels at Heatherton Park, Cork'
# https://airquality.ie/readings?station=EPA-11&dateFrom=01+Jan+2022&dateTo=31+Dec+2022
# C:\Users\lsmyth\AppData\Local\Temp\ipykernel_24844\3491157687.py:116: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   dataset = pd.concat([newdata,dataset])
# Air Quality Levels at Winetavern Street, Dublin 8'
# https://airquality.ie/readings?station=EPA-12&dateFrom=01+Jan+2022&dateTo=31+Dec+2022
# [<p class="m-0">
#                     No data found for this station and date range.
#                                     </p>]
# https://airquality.ie/readings?station=EPA-13&dateFrom=01+Jan+2022&dateTo=31+Dec+2022
# Air Quality Levels at Bray, Co. Wicklow'
# https://airquality.ie/readings?station=EPA-14&dateFrom=01+Jan+2022&dateTo=31+Dec+2022
# [<p class="m-0">
#                     No data found for this station and date range.
#                                     </p>]
# https://airquality.ie/readings?station=EPA-15&dateFrom=01+Jan+2022&dateTo=31+Dec+2022
# [<p class="m-0">
#                     No data found for this station and date range.
#                                     </p>]
# https://airquality.ie/readings?station=EPA-16&dateFrom=01+Jan+2022&dateTo=31+Dec+2022
# Air Quality Levels at Portlaoise, Co. Laois'
# https://airquality.ie/readings?station=EPA-17&dateFrom=01+Jan+2022&dateTo=31+Dec+2022
# Air Quality Levels at Ringsend, Dublin 4'
# https://airquality.ie/readings?station=EPA-18&dateFrom=01+Jan+2022&dateTo=31+Dec+2022
# [<p class="m-0">
#                     No data found for this station and date range.
#                                     </p>]
# https://airquality.ie/readings?station=EPA-19&dateFrom=01+Jan+2022&dateTo=31+Dec+2022
# [<p class="m-0">
#                     No data found for this station and date range.
#                                     </p>]
# https://airquality.ie/readings?station=EPA-20&dateFrom=01+Jan+2022&dateTo=31+Dec+2022
# [<p class="m-0">
#                     No data found for this station and date range.
#                                     </p>]
# https://airquality.ie/readings?station=EPA-21&dateFrom=01+Jan+2022&dateTo=31+Dec+2022
# Air Quality Levels at University College Cork'
# https://airquality.ie/readings?station=EPA-22&dateFrom=01+Jan+2022&dateTo=31+Dec+2022
# Air Quality Levels at Rathmines, Dublin 6'
# https://airquality.ie/readings?station=EPA-23&dateFrom=01+Jan+2022&dateTo=31+Dec+2022
# Air Quality Levels at Dundalk, Co. Louth'
# https://airquality.ie/readings?station=EPA-24&dateFrom=01+Jan+2022&dateTo=31+Dec+2022
# Air Quality Levels at Enniscorthy, Co. Wexford'
# https://airquality.ie/readings?station=EPA-25&dateFrom=01+Jan+2022&dateTo=31+Dec+2022
# Air Quality Levels at Ennis, Co. Clare'
# https://airquality.ie/readings?station=EPA-26&dateFrom=01+Jan+2022&dateTo=31+Dec+2022
# Air Quality Levels at Castlebar, Co. Mayo'
# https://airquality.ie/readings?station=EPA-27&dateFrom=01+Jan+2022&dateTo=31+Dec+2022
# Air Quality Levels at Malin Head, Co. Donegal'
# https://airquality.ie/readings?station=EPA-28&dateFrom=01+Jan+2022&dateTo=31+Dec+2022
# Air Quality Levels at Carnsore Point, Co. Wexford'
# https://airquality.ie/readings?station=EPA-29&dateFrom=01+Jan+2022&dateTo=31+Dec+2022
# Air Quality Levels at Blanchardstown, Dublin 15'
# https://airquality.ie/readings?station=EPA-30&dateFrom=01+Jan+2022&dateTo=31+Dec+2022
# [<p class="m-0">
#                     No data found for this station and date range.
#                                     </p>]
# https://airquality.ie/readings?station=EPA-31&dateFrom=01+Jan+2022&dateTo=31+Dec+2022
# [<p class="m-0">
#                     No data found for this station and date range.
#                                     </p>]
# https://airquality.ie/readings?station=EPA-32&dateFrom=01+Jan+2022&dateTo=31+Dec+2022
# [<p class="m-0">
#                     No data found for this station and date range.
#                                     </p>]
# https://airquality.ie/readings?station=EPA-33&dateFrom=01+Jan+2022&dateTo=31+Dec+2022
# Air Quality Levels at Clonskeagh, Dublin 14'
# https://airquality.ie/readings?station=EPA-34&dateFrom=01+Jan+2022&dateTo=31+Dec+2022
# Air Quality Levels at Dún Laoghaire, Co. Dublin'
# https://airquality.ie/readings?station=EPA-35&dateFrom=01+Jan+2022&dateTo=31+Dec+2022
# [<p class="m-0">
#                     No data found for this station and date range.
#                                     </p>]
# https://airquality.ie/readings?station=EPA-36&dateFrom=01+Jan+2022&dateTo=31+Dec+2022
# Air Quality Levels at Callan Road, Kilkenny'
# https://airquality.ie/readings?station=EPA-37&dateFrom=01+Jan+2022&dateTo=31+Dec+2022
# [<p class="m-0">
#                     No data found for this station and date range.
#                                     </p>]
# https://airquality.ie/readings?station=EPA-38&dateFrom=01+Jan+2022&dateTo=31+Dec+2022
# [<p class="m-0">
#                     No data found for this station and date range.
#                                     </p>]
# https://airquality.ie/readings?station=EPA-39&dateFrom=01+Jan+2022&dateTo=31+Dec+2022
# https://airquality.ie/readings?station=EPA-40&dateFrom=01+Jan+2022&dateTo=31+Dec+2022
# [<p class="m-0">
#                     No data found for this station and date range.
#                                     </p>]
# https://airquality.ie/readings?station=EPA-41&dateFrom=01+Jan+2022&dateTo=31+Dec+2022
# [<p class="m-0">
#                     No data found for this station and date range.
#                                     </p>]
# https://airquality.ie/readings?station=EPA-42&dateFrom=01+Jan+2022&dateTo=31+Dec+2022
# [<p class="m-0">
#                     No data found for this station and date range.
#                                     </p>]
# https://airquality.ie/readings?station=EPA-43&dateFrom=01+Jan+2022&dateTo=31+Dec+2022
# Air Quality Levels at Longford Town'
# https://airquality.ie/readings?station=EPA-44&dateFrom=01+Jan+2022&dateTo=31+Dec+2022
# Air Quality Levels at Tallaght, Dublin 24'
# https://airquality.ie/readings?station=EPA-45&dateFrom=01+Jan+2022&dateTo=31+Dec+2022
# Air Quality Levels at Valentia Observatory, Caherciveen, Co. Kerry'
# https://airquality.ie/readings?station=EPA-46&dateFrom=01+Jan+2022&dateTo=31+Dec+2022
# Air Quality Levels at Finglas, Dublin 11'
# https://airquality.ie/readings?station=EPA-47&dateFrom=01+Jan+2022&dateTo=31+Dec+2022
# Air Quality Levels at Marino, Dublin 3'
# https://airquality.ie/readings?station=EPA-48&dateFrom=01+Jan+2022&dateTo=31+Dec+2022
# Air Quality Levels at Phoenix Park, Dublin 8'
# https://airquality.ie/readings?station=EPA-49&dateFrom=01+Jan+2022&dateTo=31+Dec+2022
# Air Quality Levels at Davitt Road, Inchicore, Dublin 12'
# https://airquality.ie/readings?station=EPA-50&dateFrom=01+Jan+2022&dateTo=31+Dec+2022
# Air Quality Levels at Ballyfermot, Dublin 10'
# https://airquality.ie/readings?station=EPA-51&dateFrom=01+Jan+2022&dateTo=31+Dec+2022
# Air Quality Levels at Mace Head, Carna, Co. Galway'
# https://airquality.ie/readings?station=EPA-52&dateFrom=01+Jan+2022&dateTo=31+Dec+2022
# Air Quality Levels at St. Anne\'
# https://airquality.ie/readings?station=EPA-53&dateFrom=01+Jan+2022&dateTo=31+Dec+2022
# Air Quality Levels at Roscommon Town'
# https://airquality.ie/readings?station=EPA-54&dateFrom=01+Jan+2022&dateTo=31+Dec+2022
# Air Quality Levels at Carlow Town'
# https://airquality.ie/readings?station=EPA-55&dateFrom=01+Jan+2022&dateTo=31+Dec+2022
# [<p class="m-0">
#                     No data found for this station and date range.
#
#                     <a class="alert-link" href="/readings?station=EPA-55&amp;dateFrom=08+Feb+2025&amp;dateTo=08+Feb+2025">View most recent readings</a>
# </p>]
# https://airquality.ie/readings?station=EPA-56&dateFrom=01+Jan+2022&dateTo=31+Dec+2022
# Air Quality Levels at South Link Road, Cork'
# https://airquality.ie/readings?station=EPA-57&dateFrom=01+Jan+2022&dateTo=31+Dec+2022
# Air Quality Levels at St. John’s Road, Kilmainham, Dublin 8'
# https://airquality.ie/readings?station=EPA-58&dateFrom=01+Jan+2022&dateTo=31+Dec+2022
# Air Quality Levels at Kilkitt, Co. Monaghan'
# https://airquality.ie/readings?station=EPA-59&dateFrom=01+Jan+2022&dateTo=31+Dec+2022
# Air Quality Levels at Paddy Browne\'
# https://airquality.ie/readings?station=EPA-60&dateFrom=01+Jan+2022&dateTo=31+Dec+2022
# Air Quality Levels at Cobh Carrignafoy, Co. Cork'
# https://airquality.ie/readings?station=EPA-61&dateFrom=01+Jan+2022&dateTo=31+Dec+2022
# Air Quality Levels at Swords Council Depot, Co. Dublin'
# https://airquality.ie/readings?station=EPA-62&dateFrom=01+Jan+2022&dateTo=31+Dec+2022
# Air Quality Levels at Emo, Co. Laois'
# https://airquality.ie/readings?station=EPA-63&dateFrom=01+Jan+2022&dateTo=31+Dec+2022
# Air Quality Levels at Wexford Opera House'
# https://airquality.ie/readings?station=EPA-64&dateFrom=01+Jan+2022&dateTo=31+Dec+2022
# https://airquality.ie/readings?station=EPA-65&dateFrom=01+Jan+2022&dateTo=31+Dec+2022
# [<p class="m-0">
#                     No data found for this station and date range.
#                                     </p>]
# https://airquality.ie/readings?station=EPA-66&dateFrom=01+Jan+2022&dateTo=31+Dec+2022
# Air Quality Levels at Tipperary Town'
# https://airquality.ie/readings?station=EPA-67&dateFrom=01+Jan+2022&dateTo=31+Dec+2022
# Air Quality Levels at Macroom, Co. Cork'
# https://airquality.ie/readings?station=EPA-68&dateFrom=01+Jan+2022&dateTo=31+Dec+2022
# Air Quality Levels at Navan, Co. Meath'
# https://airquality.ie/readings?station=EPA-69&dateFrom=01+Jan+2022&dateTo=31+Dec+2022
# Air Quality Levels at Pearse Street, Dublin 2'
# https://airquality.ie/readings?station=EPA-70&dateFrom=01+Jan+2022&dateTo=31+Dec+2022
# Air Quality Levels at Athlone Civic Centre & Library, Co. Westmeath'
# https://airquality.ie/readings?station=EPA-71&dateFrom=01+Jan+2022&dateTo=31+Dec+2022
# Air Quality Levels at Tralee Library, Co. Kerry'
# https://airquality.ie/readings?station=EPA-72&dateFrom=01+Jan+2022&dateTo=31+Dec+2022
# Air Quality Levels at Cork Harbour'
# https://airquality.ie/readings?station=EPA-73&dateFrom=01+Jan+2022&dateTo=31+Dec+2022
# [<p class="m-0">
#                     No data found for this station and date range.
#                                     </p>]
# https://airquality.ie/readings?station=EPA-74&dateFrom=01+Jan+2022&dateTo=31+Dec+2022
# Air Quality Levels at Askeaton, Co. Limerick'
# https://airquality.ie/readings?station=EPA-75&dateFrom=01+Jan+2022&dateTo=31+Dec+2022
# Air Quality Levels at Clonmel, Co. Tipperary'
# https://airquality.ie/readings?station=EPA-76&dateFrom=01+Jan+2022&dateTo=31+Dec+2022
# Air Quality Levels at Dublin Port, Dublin 1'
# https://airquality.ie/readings?station=EPA-77&dateFrom=01+Jan+2022&dateTo=31+Dec+2022
# [<p class="m-0">
#                     No data found for this station and date range.
#
#                     <a class="alert-link" href="/readings?station=EPA-77&amp;dateFrom=23+Feb+2025&amp;dateTo=23+Feb+2025">View most recent readings</a>
# </p>]
# https://airquality.ie/readings?station=EPA-78&dateFrom=01+Jan+2022&dateTo=31+Dec+2022
# Air Quality Levels at Cavan Town'
# https://airquality.ie/readings?station=EPA-79&dateFrom=01+Jan+2022&dateTo=31+Dec+2022
# Air Quality Levels at Birr, Co. Offaly'
# https://airquality.ie/readings?station=EPA-80&dateFrom=01+Jan+2022&dateTo=31+Dec+2022
# Air Quality Levels at Carrick-on-Shannon, Co. Leitrim'
# https://airquality.ie/readings?station=EPA-81&dateFrom=01+Jan+2022&dateTo=31+Dec+2022
# [<p class="m-0">
#                     No data found for this station and date range.
#                                     </p>]
# https://airquality.ie/readings?station=EPA-82&dateFrom=01+Jan+2022&dateTo=31+Dec+2022
# Air Quality Levels at Mallow, Co. Cork'
# https://airquality.ie/readings?station=EPA-83&dateFrom=01+Jan+2022&dateTo=31+Dec+2022
# Air Quality Levels at Naas, Co. Kildare'
# https://airquality.ie/readings?station=EPA-84&dateFrom=01+Jan+2022&dateTo=31+Dec+2022
# Air Quality Levels at Drogheda, Co. Louth'
# https://airquality.ie/readings?station=EPA-85&dateFrom=01+Jan+2022&dateTo=31+Dec+2022
# Air Quality Levels at Henry Street, Limerick'
# https://airquality.ie/readings?station=EPA-86&dateFrom=01+Jan+2022&dateTo=31+Dec+2022
# [<p class="m-0">
#                     No data found for this station and date range.
#                                     </p>]
# https://airquality.ie/readings?station=EPA-87&dateFrom=01+Jan+2022&dateTo=31+Dec+2022
# [<p class="m-0">
#                     No data found for this station and date range.
#
#                     <a class="alert-link" href="/readings?station=EPA-87&amp;dateFrom=23+Feb+2025&amp;dateTo=23+Feb+2025">View most recent readings</a>
# </p>]
# https://airquality.ie/readings?station=EPA-88&dateFrom=01+Jan+2022&dateTo=31+Dec+2022
# [<p class="m-0">
#                     No data found for this station and date range.
#
#                     <a class="alert-link" href="/readings?station=EPA-88&amp;dateFrom=05+Oct+2023&amp;dateTo=05+Oct+2023">View most recent readings</a>
# </p>]
# https://airquality.ie/readings?station=EPA-89&dateFrom=01+Jan+2022&dateTo=31+Dec+2022
# [<p class="m-0">
#                     No data found for this station and date range.
#
#                     <a class="alert-link" href="/readings?station=EPA-89&amp;dateFrom=04+Dec+2023&amp;dateTo=04+Dec+2023">View most recent readings</a>
# </p>]
# https://airquality.ie/readings?station=EPA-90&dateFrom=01+Jan+2022&dateTo=31+Dec+2022
# [<p class="m-0">
#                     No data found for this station and date range.
#
#                     <a class="alert-link" href="/readings?station=EPA-90&amp;dateFrom=23+Feb+2025&amp;dateTo=23+Feb+2025">View most recent readings</a>
# </p>]
# https://airquality.ie/readings?station=EPA-91&dateFrom=01+Jan+2022&dateTo=31+Dec+2022
# [<p class="m-0">
#                     No data found for this station and date range.
#
#                     <a class="alert-link" href="/readings?station=EPA-91&amp;dateFrom=23+Feb+2025&amp;dateTo=23+Feb+2025">View most recent readings</a>
# </p>]
# https://airquality.ie/readings?station=EPA-92&dateFrom=01+Jan+2022&dateTo=31+Dec+2022
# [<p class="m-0">
#                     No data found for this station and date range.
#
#                     <a class="alert-link" href="/readings?station=EPA-92&amp;dateFrom=23+Feb+2025&amp;dateTo=23+Feb+2025">View most recent readings</a>
# </p>]
# https://airquality.ie/readings?station=EPA-93&dateFrom=01+Jan+2022&dateTo=31+Dec+2022
# [<p class="m-0">
#                     No data found for this station and date range.
#                                     </p>]
# https://airquality.ie/readings?station=EPA-94&dateFrom=01+Jan+2022&dateTo=31+Dec+2022
# [<p class="m-0">
#                     No data found for this station and date range.
#                                     </p>]
# https://airquality.ie/readings?station=EPA-95&dateFrom=01+Jan+2022&dateTo=31+Dec+2022
# [<p class="m-0">
#                     No data found for this station and date range.
#                                     </p>]
# https://airquality.ie/readings?station=EPA-96&dateFrom=01+Jan+2022&dateTo=31+Dec+2022
# [<p class="m-0">
#                     No data found for this station and date range.
#                                     </p>]
# https://airquality.ie/readings?station=EPA-97&dateFrom=01+Jan+2022&dateTo=31+Dec+2022
# [<p class="m-0">
#                     No data found for this station and date range.
#                                     </p>]
# https://airquality.ie/readings?station=EPA-98&dateFrom=01+Jan+2022&dateTo=31+Dec+2022
# [<p class="m-0">
#                     No data found for this station and date range.
#                                     </p>]
# https://airquality.ie/readings?station=EPA-99&dateFrom=01+Jan+2022&dateTo=31+Dec+2022
# [<p class="m-0">
#                     No data found for this station and date range.
#                                     </p>]
# https://airquality.ie/readings?station=EPA-100&dateFrom=01+Jan+2022&dateTo=31+Dec+2022
# [<p class="m-0">
#                     No data found for this station and date range.
#                                     </p>]
# https://airquality.ie/readings?station=EPA-101&dateFrom=01+Jan+2022&dateTo=31+Dec+2022
# Air Quality Levels at Greystones Fire Station'
# https://airquality.ie/readings?station=EPA-102&dateFrom=01+Jan+2022&dateTo=31+Dec+2022
# Air Quality Levels at Edenderry Library, Co. Offaly'
# https://airquality.ie/readings?station=EPA-103&dateFrom=01+Jan+2022&dateTo=31+Dec+2022
# Air Quality Levels at Claremorris, Co. Mayo'
# https://airquality.ie/readings?station=EPA-104&dateFrom=01+Jan+2022&dateTo=31+Dec+2022
# Air Quality Levels at Cork Lower Glanmire Road'
# https://airquality.ie/readings?station=EPA-105&dateFrom=01+Jan+2022&dateTo=31+Dec+2022
# Air Quality Levels at Eyre Square, Galway'
# https://airquality.ie/readings?station=EPA-106&dateFrom=01+Jan+2022&dateTo=31+Dec+2022
# Air Quality Levels at Leixlip Library, Co. Kildare'
# https://airquality.ie/readings?station=EPA-107&dateFrom=01+Jan+2022&dateTo=31+Dec+2022
# Air Quality Levels at Killarney Anam Arts and Cultural Centre, Co. Kerry'
# https://airquality.ie/readings?station=EPA-108&dateFrom=01+Jan+2022&dateTo=31+Dec+2022
# Air Quality Levels at Lucan, Co. Dublin'
# https://airquality.ie/readings?station=EPA-109&dateFrom=01+Jan+2022&dateTo=31+Dec+2022
# Air Quality Levels at Briarhill, Co. Galway'

# %%
#put it together with more variables and date ranges so it can pull all locations, all months for all specified years.
#starting date point
dateFrom = '01+Jan+'
#dateFrom = '01+Jul+'
#end date point
#dateTo = '30+Jun+'
dateTo = '31+Dec+'
#years to capture
year = {2021}

dataset = pd.DataFrame(columns=["Timestamp", "Value", "PM", "Location"])
#all_dataset = pd.DataFrame(columns=["Timestamp", "Value", "PM", "Location"])

for y in year:
    for i in range(10,110):#range should go to 110
        
        #break the url up into the string and variables
        url='https://airquality.ie/readings?station=EPA-'+str(i)+'&dateFrom='+dateFrom+str(y)+'&dateTo='+dateTo+str(y)
        #print it to keep track of which location and date is being processes as the script is running
        print(url)
        #create content to scrape
        r = requests.get(url)
        soup = BeautifulSoup(r.content, 'html.parser')
        #print(soup)
        #if there is no data the m-0 class is called with a no data message..
        no_data = soup.select(".m-0")
        if no_data:
            #print to track what locations exist/don't exist
            print(no_data)
        else:
            # find the date and values within the data tag..
            get_data = soup.find_all('script')#, string=re.compile('Date.UTC')).string
            #print("get_data")
            #print(get_data)
         #   print("get_data.string")
        #    print(get_data.string)
            #look for the same message to get the location of the air quality monitor, begins with Air Quality Levels at then has a comma and ends with a single quote.
            location = re.search(r"Air Quality Levels at.*?,*?'", str(get_data))

            #if location exists assign it.. otherwise mark it as unknown
            if location:
                loc = location.group(0)
                print(loc)
            else:
                loc = "Unknown Location"

            #look for PM2.5 data
            pm2_5 = re.search(r'"PM2.5",', str(get_data))
            pm2_5_values = []

            #if it exists pull the full block from pm2.5 to //endforeach to get all timestamp and pm values data
            if pm2_5:
                pattern = r'"PM2.5".*?//endforeach'
                
                #search for the entire block from 'pm2_5' to '//endforeach'
                pm2_5_data_block = re.search(pattern, str(get_data), re.DOTALL)
              #  print(pm2_5_data_block.group(0))
                if pm2_5_data_block:
                    #print(pm2_5_data_block)
                    #asked chatgpt to 'give me the regex to parse this date and value, [ Date.UTC(2023,0,9,4,0,0), 2.86]'
                    #match the timestamp and value portion only
                    pattern = r'Date\.UTC\((\d+),(\d+),(\d+),(\d+),(\d+),(\d+)\),\s*([\d.]+)'
      
                   #get all matches in the pm2.5 block only
                    pm2_5_values = re.findall(pattern, pm2_5_data_block.group(0))
                else:
                    print("No match found")

            #print(pm2_5_values)
            
            #do the same again for pm10
            pm10 = re.search(r'"PM10",', str(get_data))
            pm10_values = []
            if pm10:
                pattern = r'"PM10".*?//endforeach'
                
                #search for the entire block from 'pm10' to '//endforeach'
                pm10_data_block = re.search(pattern,str(get_data), re.DOTALL)

                #get all matches in the pm10 block only
                if pm10_data_block:
                    pattern = r'Date\.UTC\((\d+),(\d+),(\d+),(\d+),(\d+),(\d+)\),\s*([\d.]+)'
                    pm10_values = re.findall(pattern, pm10_data_block.group(0))
                else:
                    print("No match found")

            #print(pm10_values)
            pm_val = float
        
            #assign the values to the name of the pm type for easier adding to the dataset
            records = {'pm_2.5':pm2_5_values,'pm_10':pm10_values}
            # print(records)
            mydata = []
            if records:
                #get the key value pairs
                for key, vals in records.items():
                    #define the pm_val based on the key
                    if key == 'pm_2.5':
                        pm_val = 2.5
                    elif key == 'pm_10':
                        pm_val = 10
                    else:
                        pm_val = 0  #0 can be used for unknown so it doesn't break the parser

                    #parse out the values into the timestamps and pm vals
                    for val in vals:
                     #   print(val)
                        year, month, day, hour, minute, second, value = map(float, val)
                        #add 1 to the month as it looks like January = month 0 (days not affected)
                        timestamp = datetime(int(year), int(month)+1, int(day), int(hour), int(minute), int(second))
                    
                        #put it together in a data frame
                        mydata.append({"Timestamp": timestamp, "Value": float(value), "PM":pm_val, "Location": loc})

        newdata = pd.DataFrame(mydata)      
        dataset = pd.concat([newdata,dataset])
#save to a csv file so it's available to read in (but don't open and save as it will have millions of rows and they will be lost by Excel!  
dataset.to_csv('air_quality_data_Jan_Dec_2021.csv', index=False)
# Out:
# https://airquality.ie/readings?station=EPA-10&dateFrom=01+Jan+2021&dateTo=31+Dec+2021
# Air Quality Levels at Heatherton Park, Cork'
# https://airquality.ie/readings?station=EPA-11&dateFrom=01+Jan+2021&dateTo=31+Dec+2021
# C:\Users\lsmyth\AppData\Local\Temp\ipykernel_24844\146781576.py:116: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   dataset = pd.concat([newdata,dataset])
# Air Quality Levels at Winetavern Street, Dublin 8'
# https://airquality.ie/readings?station=EPA-12&dateFrom=01+Jan+2021&dateTo=31+Dec+2021
# [<p class="m-0">
#                     No data found for this station and date range.
#                                     </p>]
# https://airquality.ie/readings?station=EPA-13&dateFrom=01+Jan+2021&dateTo=31+Dec+2021
# Air Quality Levels at Bray, Co. Wicklow'
# https://airquality.ie/readings?station=EPA-14&dateFrom=01+Jan+2021&dateTo=31+Dec+2021
# [<p class="m-0">
#                     No data found for this station and date range.
#                                     </p>]
# https://airquality.ie/readings?station=EPA-15&dateFrom=01+Jan+2021&dateTo=31+Dec+2021
# [<p class="m-0">
#                     No data found for this station and date range.
#                                     </p>]
# https://airquality.ie/readings?station=EPA-16&dateFrom=01+Jan+2021&dateTo=31+Dec+2021
# Air Quality Levels at Portlaoise, Co. Laois'
# https://airquality.ie/readings?station=EPA-17&dateFrom=01+Jan+2021&dateTo=31+Dec+2021
# Air Quality Levels at Ringsend, Dublin 4'
# https://airquality.ie/readings?station=EPA-18&dateFrom=01+Jan+2021&dateTo=31+Dec+2021
# [<p class="m-0">
#                     No data found for this station and date range.
#                                     </p>]
# https://airquality.ie/readings?station=EPA-19&dateFrom=01+Jan+2021&dateTo=31+Dec+2021
# [<p class="m-0">
#                     No data found for this station and date range.
#                                     </p>]
# https://airquality.ie/readings?station=EPA-20&dateFrom=01+Jan+2021&dateTo=31+Dec+2021
# [<p class="m-0">
#                     No data found for this station and date range.
#                                     </p>]
# https://airquality.ie/readings?station=EPA-21&dateFrom=01+Jan+2021&dateTo=31+Dec+2021
# Air Quality Levels at University College Cork'
# https://airquality.ie/readings?station=EPA-22&dateFrom=01+Jan+2021&dateTo=31+Dec+2021
# Air Quality Levels at Rathmines, Dublin 6'
# https://airquality.ie/readings?station=EPA-23&dateFrom=01+Jan+2021&dateTo=31+Dec+2021
# Air Quality Levels at Dundalk, Co. Louth'
# https://airquality.ie/readings?station=EPA-24&dateFrom=01+Jan+2021&dateTo=31+Dec+2021
# Air Quality Levels at Enniscorthy, Co. Wexford'
# https://airquality.ie/readings?station=EPA-25&dateFrom=01+Jan+2021&dateTo=31+Dec+2021
# Air Quality Levels at Ennis, Co. Clare'
# https://airquality.ie/readings?station=EPA-26&dateFrom=01+Jan+2021&dateTo=31+Dec+2021
# Air Quality Levels at Castlebar, Co. Mayo'
# https://airquality.ie/readings?station=EPA-27&dateFrom=01+Jan+2021&dateTo=31+Dec+2021
# Air Quality Levels at Malin Head, Co. Donegal'
# https://airquality.ie/readings?station=EPA-28&dateFrom=01+Jan+2021&dateTo=31+Dec+2021
# Air Quality Levels at Carnsore Point, Co. Wexford'
# https://airquality.ie/readings?station=EPA-29&dateFrom=01+Jan+2021&dateTo=31+Dec+2021
# Air Quality Levels at Blanchardstown, Dublin 15'
# https://airquality.ie/readings?station=EPA-30&dateFrom=01+Jan+2021&dateTo=31+Dec+2021
# [<p class="m-0">
#                     No data found for this station and date range.
#                                     </p>]
# https://airquality.ie/readings?station=EPA-31&dateFrom=01+Jan+2021&dateTo=31+Dec+2021
# [<p class="m-0">
#                     No data found for this station and date range.
#                                     </p>]
# https://airquality.ie/readings?station=EPA-32&dateFrom=01+Jan+2021&dateTo=31+Dec+2021
# [<p class="m-0">
#                     No data found for this station and date range.
#                                     </p>]
# https://airquality.ie/readings?station=EPA-33&dateFrom=01+Jan+2021&dateTo=31+Dec+2021
# Air Quality Levels at Clonskeagh, Dublin 14'
# https://airquality.ie/readings?station=EPA-34&dateFrom=01+Jan+2021&dateTo=31+Dec+2021
# Air Quality Levels at Dún Laoghaire, Co. Dublin'
# https://airquality.ie/readings?station=EPA-35&dateFrom=01+Jan+2021&dateTo=31+Dec+2021
# [<p class="m-0">
#                     No data found for this station and date range.
#                                     </p>]
# https://airquality.ie/readings?station=EPA-36&dateFrom=01+Jan+2021&dateTo=31+Dec+2021
# Air Quality Levels at Callan Road, Kilkenny'
# https://airquality.ie/readings?station=EPA-37&dateFrom=01+Jan+2021&dateTo=31+Dec+2021
# [<p class="m-0">
#                     No data found for this station and date range.
#                                     </p>]
# https://airquality.ie/readings?station=EPA-38&dateFrom=01+Jan+2021&dateTo=31+Dec+2021
# [<p class="m-0">
#                     No data found for this station and date range.
#                                     </p>]
# https://airquality.ie/readings?station=EPA-39&dateFrom=01+Jan+2021&dateTo=31+Dec+2021
# Air Quality Levels at People\'
# https://airquality.ie/readings?station=EPA-40&dateFrom=01+Jan+2021&dateTo=31+Dec+2021
# [<p class="m-0">
#                     No data found for this station and date range.
#                                     </p>]
# https://airquality.ie/readings?station=EPA-41&dateFrom=01+Jan+2021&dateTo=31+Dec+2021
# [<p class="m-0">
#                     No data found for this station and date range.
#                                     </p>]
# https://airquality.ie/readings?station=EPA-42&dateFrom=01+Jan+2021&dateTo=31+Dec+2021
# [<p class="m-0">
#                     No data found for this station and date range.
#                                     </p>]
# https://airquality.ie/readings?station=EPA-43&dateFrom=01+Jan+2021&dateTo=31+Dec+2021
# Air Quality Levels at Longford Town'
# https://airquality.ie/readings?station=EPA-44&dateFrom=01+Jan+2021&dateTo=31+Dec+2021
# Air Quality Levels at Tallaght, Dublin 24'
# https://airquality.ie/readings?station=EPA-45&dateFrom=01+Jan+2021&dateTo=31+Dec+2021
# Air Quality Levels at Valentia Observatory, Caherciveen, Co. Kerry'
# https://airquality.ie/readings?station=EPA-46&dateFrom=01+Jan+2021&dateTo=31+Dec+2021
# Air Quality Levels at Finglas, Dublin 11'
# https://airquality.ie/readings?station=EPA-47&dateFrom=01+Jan+2021&dateTo=31+Dec+2021
# Air Quality Levels at Marino, Dublin 3'
# https://airquality.ie/readings?station=EPA-48&dateFrom=01+Jan+2021&dateTo=31+Dec+2021
# Air Quality Levels at Phoenix Park, Dublin 8'
# https://airquality.ie/readings?station=EPA-49&dateFrom=01+Jan+2021&dateTo=31+Dec+2021
# Air Quality Levels at Davitt Road, Inchicore, Dublin 12'
# https://airquality.ie/readings?station=EPA-50&dateFrom=01+Jan+2021&dateTo=31+Dec+2021
# Air Quality Levels at Ballyfermot, Dublin 10'
# https://airquality.ie/readings?station=EPA-51&dateFrom=01+Jan+2021&dateTo=31+Dec+2021
# Air Quality Levels at Mace Head, Carna, Co. Galway'
# https://airquality.ie/readings?station=EPA-52&dateFrom=01+Jan+2021&dateTo=31+Dec+2021
# Air Quality Levels at St. Anne\'
# https://airquality.ie/readings?station=EPA-53&dateFrom=01+Jan+2021&dateTo=31+Dec+2021
# Air Quality Levels at Roscommon Town'
# https://airquality.ie/readings?station=EPA-54&dateFrom=01+Jan+2021&dateTo=31+Dec+2021
# Air Quality Levels at Carlow Town'
# https://airquality.ie/readings?station=EPA-55&dateFrom=01+Jan+2021&dateTo=31+Dec+2021
# [<p class="m-0">
#                     No data found for this station and date range.
#
#                     <a class="alert-link" href="/readings?station=EPA-55&amp;dateFrom=08+Feb+2025&amp;dateTo=08+Feb+2025">View most recent readings</a>
# </p>]
# https://airquality.ie/readings?station=EPA-56&dateFrom=01+Jan+2021&dateTo=31+Dec+2021
# Air Quality Levels at South Link Road, Cork'
# https://airquality.ie/readings?station=EPA-57&dateFrom=01+Jan+2021&dateTo=31+Dec+2021
# Air Quality Levels at St. John’s Road, Kilmainham, Dublin 8'
# https://airquality.ie/readings?station=EPA-58&dateFrom=01+Jan+2021&dateTo=31+Dec+2021
# Air Quality Levels at Kilkitt, Co. Monaghan'
# https://airquality.ie/readings?station=EPA-59&dateFrom=01+Jan+2021&dateTo=31+Dec+2021
# Air Quality Levels at Paddy Browne\'
# https://airquality.ie/readings?station=EPA-60&dateFrom=01+Jan+2021&dateTo=31+Dec+2021
# Air Quality Levels at Cobh Carrignafoy, Co. Cork'
# https://airquality.ie/readings?station=EPA-61&dateFrom=01+Jan+2021&dateTo=31+Dec+2021
# Air Quality Levels at Swords Council Depot, Co. Dublin'
# https://airquality.ie/readings?station=EPA-62&dateFrom=01+Jan+2021&dateTo=31+Dec+2021
# Air Quality Levels at Emo, Co. Laois'
# https://airquality.ie/readings?station=EPA-63&dateFrom=01+Jan+2021&dateTo=31+Dec+2021
# Air Quality Levels at Wexford Opera House'
# https://airquality.ie/readings?station=EPA-64&dateFrom=01+Jan+2021&dateTo=31+Dec+2021
# Air Quality Levels at Letterkenny, Co. Donegal'
# https://airquality.ie/readings?station=EPA-65&dateFrom=01+Jan+2021&dateTo=31+Dec+2021
# [<p class="m-0">
#                     No data found for this station and date range.
#                                     </p>]
# https://airquality.ie/readings?station=EPA-66&dateFrom=01+Jan+2021&dateTo=31+Dec+2021
# Air Quality Levels at Tipperary Town'
# https://airquality.ie/readings?station=EPA-67&dateFrom=01+Jan+2021&dateTo=31+Dec+2021
# Air Quality Levels at Macroom, Co. Cork'
# https://airquality.ie/readings?station=EPA-68&dateFrom=01+Jan+2021&dateTo=31+Dec+2021
# Air Quality Levels at Navan, Co. Meath'
# https://airquality.ie/readings?station=EPA-69&dateFrom=01+Jan+2021&dateTo=31+Dec+2021
# Air Quality Levels at Pearse Street, Dublin 2'
# https://airquality.ie/readings?station=EPA-70&dateFrom=01+Jan+2021&dateTo=31+Dec+2021
# Air Quality Levels at Athlone Civic Centre & Library, Co. Westmeath'
# https://airquality.ie/readings?station=EPA-71&dateFrom=01+Jan+2021&dateTo=31+Dec+2021
# Air Quality Levels at Tralee Library, Co. Kerry'
# https://airquality.ie/readings?station=EPA-72&dateFrom=01+Jan+2021&dateTo=31+Dec+2021
# Air Quality Levels at Cork Harbour'
# https://airquality.ie/readings?station=EPA-73&dateFrom=01+Jan+2021&dateTo=31+Dec+2021
# [<p class="m-0">
#                     No data found for this station and date range.
#                                     </p>]
# https://airquality.ie/readings?station=EPA-74&dateFrom=01+Jan+2021&dateTo=31+Dec+2021
# Air Quality Levels at Askeaton, Co. Limerick'
# https://airquality.ie/readings?station=EPA-75&dateFrom=01+Jan+2021&dateTo=31+Dec+2021
# Air Quality Levels at Clonmel, Co. Tipperary'
# https://airquality.ie/readings?station=EPA-76&dateFrom=01+Jan+2021&dateTo=31+Dec+2021
# Air Quality Levels at Dublin Port, Dublin 1'
# https://airquality.ie/readings?station=EPA-77&dateFrom=01+Jan+2021&dateTo=31+Dec+2021
# https://airquality.ie/readings?station=EPA-78&dateFrom=01+Jan+2021&dateTo=31+Dec+2021
# Air Quality Levels at Cavan Town'
# https://airquality.ie/readings?station=EPA-79&dateFrom=01+Jan+2021&dateTo=31+Dec+2021
# Air Quality Levels at Birr, Co. Offaly'
# https://airquality.ie/readings?station=EPA-80&dateFrom=01+Jan+2021&dateTo=31+Dec+2021
# Air Quality Levels at Carrick-on-Shannon, Co. Leitrim'
# https://airquality.ie/readings?station=EPA-81&dateFrom=01+Jan+2021&dateTo=31+Dec+2021
# Air Quality Levels at '
# https://airquality.ie/readings?station=EPA-82&dateFrom=01+Jan+2021&dateTo=31+Dec+2021
# Air Quality Levels at Mallow, Co. Cork'
# https://airquality.ie/readings?station=EPA-83&dateFrom=01+Jan+2021&dateTo=31+Dec+2021
# Air Quality Levels at Naas, Co. Kildare'
# https://airquality.ie/readings?station=EPA-84&dateFrom=01+Jan+2021&dateTo=31+Dec+2021
# Air Quality Levels at Drogheda, Co. Louth'
# https://airquality.ie/readings?station=EPA-85&dateFrom=01+Jan+2021&dateTo=31+Dec+2021
# Air Quality Levels at Henry Street, Limerick'
# https://airquality.ie/readings?station=EPA-86&dateFrom=01+Jan+2021&dateTo=31+Dec+2021
# [<p class="m-0">
#                     No data found for this station and date range.
#                                     </p>]
# https://airquality.ie/readings?station=EPA-87&dateFrom=01+Jan+2021&dateTo=31+Dec+2021
# [<p class="m-0">
#                     No data found for this station and date range.
#
#                     <a class="alert-link" href="/readings?station=EPA-87&amp;dateFrom=23+Feb+2025&amp;dateTo=23+Feb+2025">View most recent readings</a>
# </p>]
# https://airquality.ie/readings?station=EPA-88&dateFrom=01+Jan+2021&dateTo=31+Dec+2021
# [<p class="m-0">
#                     No data found for this station and date range.
#
#                     <a class="alert-link" href="/readings?station=EPA-88&amp;dateFrom=05+Oct+2023&amp;dateTo=05+Oct+2023">View most recent readings</a>
# </p>]
# https://airquality.ie/readings?station=EPA-89&dateFrom=01+Jan+2021&dateTo=31+Dec+2021
# [<p class="m-0">
#                     No data found for this station and date range.
#
#                     <a class="alert-link" href="/readings?station=EPA-89&amp;dateFrom=04+Dec+2023&amp;dateTo=04+Dec+2023">View most recent readings</a>
# </p>]
# https://airquality.ie/readings?station=EPA-90&dateFrom=01+Jan+2021&dateTo=31+Dec+2021
# [<p class="m-0">
#                     No data found for this station and date range.
#
#                     <a class="alert-link" href="/readings?station=EPA-90&amp;dateFrom=23+Feb+2025&amp;dateTo=23+Feb+2025">View most recent readings</a>
# </p>]
# https://airquality.ie/readings?station=EPA-91&dateFrom=01+Jan+2021&dateTo=31+Dec+2021
# [<p class="m-0">
#                     No data found for this station and date range.
#
#                     <a class="alert-link" href="/readings?station=EPA-91&amp;dateFrom=23+Feb+2025&amp;dateTo=23+Feb+2025">View most recent readings</a>
# </p>]
# https://airquality.ie/readings?station=EPA-92&dateFrom=01+Jan+2021&dateTo=31+Dec+2021
# [<p class="m-0">
#                     No data found for this station and date range.
#
#                     <a class="alert-link" href="/readings?station=EPA-92&amp;dateFrom=23+Feb+2025&amp;dateTo=23+Feb+2025">View most recent readings</a>
# </p>]
# https://airquality.ie/readings?station=EPA-93&dateFrom=01+Jan+2021&dateTo=31+Dec+2021
# [<p class="m-0">
#                     No data found for this station and date range.
#                                     </p>]
# https://airquality.ie/readings?station=EPA-94&dateFrom=01+Jan+2021&dateTo=31+Dec+2021
# [<p class="m-0">
#                     No data found for this station and date range.
#                                     </p>]
# https://airquality.ie/readings?station=EPA-95&dateFrom=01+Jan+2021&dateTo=31+Dec+2021
# [<p class="m-0">
#                     No data found for this station and date range.
#                                     </p>]
# https://airquality.ie/readings?station=EPA-96&dateFrom=01+Jan+2021&dateTo=31+Dec+2021
# [<p class="m-0">
#                     No data found for this station and date range.
#                                     </p>]
# https://airquality.ie/readings?station=EPA-97&dateFrom=01+Jan+2021&dateTo=31+Dec+2021
# [<p class="m-0">
#                     No data found for this station and date range.
#                                     </p>]
# https://airquality.ie/readings?station=EPA-98&dateFrom=01+Jan+2021&dateTo=31+Dec+2021
# [<p class="m-0">
#                     No data found for this station and date range.
#                                     </p>]
# https://airquality.ie/readings?station=EPA-99&dateFrom=01+Jan+2021&dateTo=31+Dec+2021
# [<p class="m-0">
#                     No data found for this station and date range.
#                                     </p>]
# https://airquality.ie/readings?station=EPA-100&dateFrom=01+Jan+2021&dateTo=31+Dec+2021
# [<p class="m-0">
#                     No data found for this station and date range.
#                                     </p>]
# https://airquality.ie/readings?station=EPA-101&dateFrom=01+Jan+2021&dateTo=31+Dec+2021
# Air Quality Levels at Greystones Fire Station'
# https://airquality.ie/readings?station=EPA-102&dateFrom=01+Jan+2021&dateTo=31+Dec+2021
# Air Quality Levels at Edenderry Library, Co. Offaly'
# https://airquality.ie/readings?station=EPA-103&dateFrom=01+Jan+2021&dateTo=31+Dec+2021
# Air Quality Levels at Claremorris, Co. Mayo'
# https://airquality.ie/readings?station=EPA-104&dateFrom=01+Jan+2021&dateTo=31+Dec+2021
# [<p class="m-0">
#                     No data found for this station and date range.
#
#                     <a class="alert-link" href="/readings?station=EPA-104&amp;dateFrom=23+Feb+2025&amp;dateTo=23+Feb+2025">View most recent readings</a>
# </p>]
# https://airquality.ie/readings?station=EPA-105&dateFrom=01+Jan+2021&dateTo=31+Dec+2021
# [<p class="m-0">
#                     No data found for this station and date range.
#
#                     <a class="alert-link" href="/readings?station=EPA-105&amp;dateFrom=23+Feb+2025&amp;dateTo=23+Feb+2025">View most recent readings</a>
# </p>]
# https://airquality.ie/readings?station=EPA-106&dateFrom=01+Jan+2021&dateTo=31+Dec+2021
# [<p class="m-0">
#                     No data found for this station and date range.
#
#                     <a class="alert-link" href="/readings?station=EPA-106&amp;dateFrom=23+Feb+2025&amp;dateTo=23+Feb+2025">View most recent readings</a>
# </p>]
# https://airquality.ie/readings?station=EPA-107&dateFrom=01+Jan+2021&dateTo=31+Dec+2021
# [<p class="m-0">
#                     No data found for this station and date range.
#
#                     <a class="alert-link" href="/readings?station=EPA-107&amp;dateFrom=23+Feb+2025&amp;dateTo=23+Feb+2025">View most recent readings</a>
# </p>]
# https://airquality.ie/readings?station=EPA-108&dateFrom=01+Jan+2021&dateTo=31+Dec+2021
# [<p class="m-0">
#                     No data found for this station and date range.
#
#                     <a class="alert-link" href="/readings?station=EPA-108&amp;dateFrom=23+Feb+2025&amp;dateTo=23+Feb+2025">View most recent readings</a>
# </p>]
# https://airquality.ie/readings?station=EPA-109&dateFrom=01+Jan+2021&dateTo=31+Dec+2021
# [<p class="m-0">
#                     No data found for this station and date range.
#
#                     <a class="alert-link" href="/readings?station=EPA-109&amp;dateFrom=23+Feb+2025&amp;dateTo=23+Feb+2025">View most recent readings</a>
# </p>]
