# %%
#import libraries
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score
import statsmodels.api as sm
from sklearn.model_selection import cross_val_score
from sklearn.dummy import DummyRegressor

# %%
#expland the display to show all columns
pd.set_option('display.width', 1000)
pd.set_option('display.max_columns', None)

# %%
#load data
mydata = pd.read_csv('merged_data.csv')

# %%
#look at data
mydata
# Out:
#      Unnamed: 0  Year  Month                                              ISHMT  discharge_rate        date  County     PM2.5       PM10
# 0             0  2020      6  Acute upper respiratory infections & influenza...        0.020226  2020-06-01    Cork  2.449595   4.925600
# 1             1  2020      7  Acute upper respiratory infections & influenza...        0.023597  2020-07-01    Cork  2.918698   8.976464
# 2             2  2020      8  Acute upper respiratory infections & influenza...        0.038767  2020-08-01    Cork  5.503203  11.047632
# 3             3  2020      9  Acute upper respiratory infections & influenza...        0.062364  2020-09-01    Cork  5.348747  11.373366
# 4             4  2020     10  Acute upper respiratory infections & influenza...        0.038767  2020-10-01    Cork  6.587163  12.050000
# ..          ...   ...    ...                                                ...             ...         ...     ...       ...        ...
# 597         597  2023      8                                Pneumonia (J12-J18)        0.190482  2023-08-01  Dublin  4.065971   8.849873
# 598         598  2023      9                                Pneumonia (J12-J18)        0.179160  2023-09-01  Dublin  7.197300  13.106326
# 599         599  2023     10                                Pneumonia (J12-J18)        0.238436  2023-10-01  Dublin  6.902304  13.438059
# 600         600  2023     11                                Pneumonia (J12-J18)        0.265743  2023-11-01  Dublin  7.755754  13.776940
# 601         601  2023     12                                Pneumonia (J12-J18)        0.350328  2023-12-01  Dublin  6.790422  10.640430
#
# [602 rows x 9 columns]

# %%
#look at structure
mydata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 602 entries, 0 to 601
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      602 non-null    int64
#  1   Year            602 non-null    int64
#  2   Month           602 non-null    int64
#  3   ISHMT           602 non-null    object
#  4   discharge_rate  602 non-null    float64
#  5   date            602 non-null    object
#  6   County          602 non-null    object
#  7   PM2.5           602 non-null    float64
#  8   PM10            602 non-null    float64
# dtypes: float64(3), int64(3), object(3)
# memory usage: 42.5+ KB

# %%
#drop first col not needed
mydata.drop(mydata.columns[0], axis=1, inplace=True)

# %%
mydata
# Out:
#      Year  Month                                              ISHMT  discharge_rate        date  County     PM2.5       PM10
# 0    2020      6  Acute upper respiratory infections & influenza...        0.020226  2020-06-01    Cork  2.449595   4.925600
# 1    2020      7  Acute upper respiratory infections & influenza...        0.023597  2020-07-01    Cork  2.918698   8.976464
# 2    2020      8  Acute upper respiratory infections & influenza...        0.038767  2020-08-01    Cork  5.503203  11.047632
# 3    2020      9  Acute upper respiratory infections & influenza...        0.062364  2020-09-01    Cork  5.348747  11.373366
# 4    2020     10  Acute upper respiratory infections & influenza...        0.038767  2020-10-01    Cork  6.587163  12.050000
# ..    ...    ...                                                ...             ...         ...     ...       ...        ...
# 597  2023      8                                Pneumonia (J12-J18)        0.190482  2023-08-01  Dublin  4.065971   8.849873
# 598  2023      9                                Pneumonia (J12-J18)        0.179160  2023-09-01  Dublin  7.197300  13.106326
# 599  2023     10                                Pneumonia (J12-J18)        0.238436  2023-10-01  Dublin  6.902304  13.438059
# 600  2023     11                                Pneumonia (J12-J18)        0.265743  2023-11-01  Dublin  7.755754  13.776940
# 601  2023     12                                Pneumonia (J12-J18)        0.350328  2023-12-01  Dublin  6.790422  10.640430
#
# [602 rows x 8 columns]

# %% [markdown]
# ## Linear Regression
# #### Build for mydata_pre_feb2022 (up to the end of the COVID restrictions)

# %%
#convert categorical variables and drop PM10 for this analysis as its corelated to PM2.5
mydata_2022_encoded = pd.get_dummies(mydata, columns=['ISHMT', 'County',], drop_first=True)
mydata_2022_encoded = mydata_2022_encoded.drop(columns=['PM10'])
#split data into covid and post-covid
mydata_pre_feb2022 = mydata_2022_encoded[mydata_2022_encoded['date']<'2022-02-01']
mydata_post_feb2022 = mydata_2022_encoded[mydata_2022_encoded['date']>='2022-02-01']

# %%
#get rid of date and PM10 as corelated with PM2.5 - it is not needed
mydata = mydata_pre_feb2022.drop(columns=['date'])

#sort X (features) and y (target)
X = mydata.drop(columns=['discharge_rate'])
y = mydata['discharge_rate']

#split the data into train and test 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

#normalise the data - and fit to train and test data
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

#train the model
model_pre = LinearRegression()
model_pre.fit(X_train_scaled, y_train)

#predict on the test set
y_pred = model_pre.predict(X_test_scaled)

#evaluate the model using 'mean squared error' (mse)
mse = mean_squared_error(y_test, y_pred)

#outputs
print(f"Mean Squared Error: {mse:.5f}")
print(f"Intercept: {model_pre.intercept_}")
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test, y_pred)
print(f"Root Mean Squared Error (RMSE): {rmse}")
print(f"Mean Absolute Error (MAE): {mae}")

#keep original feature names
X_train_scaled_df = pd.DataFrame(X_train_scaled, columns=X_train.columns, index=X_train.index)

#add intercept
X_train_sm = sm.add_constant(X_train_scaled_df)

#fit the model and print summary
ols_model_pre = sm.OLS(y_train, X_train_sm).fit()
print(ols_model_pre.summary())
# Out:
# Mean Squared Error: 0.00282
# Intercept: 0.11795524534183355
# Root Mean Squared Error (RMSE): 0.05312314674007114
# Mean Absolute Error (MAE): 0.030635736009804616
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         discharge_rate   R-squared:                       0.583
# Model:                            OLS   Adj. R-squared:                  0.560
# Method:                 Least Squares   F-statistic:                     25.86
# Date:                Sat, 17 May 2025   Prob (F-statistic):           2.94e-30
# Time:                        20:51:38   Log-Likelihood:                 330.07
# No. Observations:                 196   AIC:                            -638.1
# Df Residuals:                     185   BIC:                            -602.1
# Df Model:                          10
# Covariance Type:            nonrobust
# ===============================================================================================================================================
#                                                                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------------------------------------------
# const                                                                           0.1180      0.003     35.720      0.000       0.111       0.124
# Year                                                                            0.0170      0.004      4.249      0.000       0.009       0.025
# Month                                                                           0.0148      0.004      3.871      0.000       0.007       0.022
# PM2.5                                                                          -0.0016      0.004     -0.417      0.677      -0.009       0.006
# ISHMT_Asthma (J45-J46)                                                          0.0160      0.004      3.613      0.000       0.007       0.025
# ISHMT_Chronic obstructive pulmonary disease & bronchiectasis (J40-J44, J47)     0.0476      0.004     10.659      0.000       0.039       0.056
# ISHMT_Other acute lower respiratory infections (J20-J22)                        0.0237      0.004      5.435      0.000       0.015       0.032
# ISHMT_Other diseases of the respiratory system (J60-J99)                        0.0357      0.005      7.836      0.000       0.027       0.045
# ISHMT_Other diseases of upper respiratory tract (J30-J34, J36-J39)              0.0198      0.004      4.561      0.000       0.011       0.028
# ISHMT_Pneumonia (J12-J18)                                                       0.0547      0.004     12.194      0.000       0.046       0.064
# County_Dublin                                                                   0.0123      0.003      3.704      0.000       0.006       0.019
# ==============================================================================
# Omnibus:                      182.301   Durbin-Watson:                   1.988
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             5527.152
# Skew:                           3.320   Prob(JB):                         0.00
# Kurtosis:                      28.154   Cond. No.                         3.48
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
#feature importance from linear regression
feature_names = X.columns
coefficients = model_pre.coef_

#show it on a plot
plt.figure(figsize=(10, 6))
plt.barh(feature_names, coefficients)
plt.title("Feature Importance (Linear Regression Coefficients)")
plt.xlabel("Coefficient Value")
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### drop the non-significant features

# %%
#get rid of pm2.5 and pm10 for the COVID version
mydata_pre_feb2022 = mydata_pre_feb2022.drop(columns=['PM2.5'])

mydata = mydata_pre_feb2022

#get rid of date it is not needed
mydata = mydata.drop(columns=['date'])

#sort X (features) and y (target)
X = mydata.drop(columns=['discharge_rate'])
y = mydata['discharge_rate']

#split the data into train and test 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

#normalise the data - and fit to train and test data
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

#train the model
model_pre_drop = LinearRegression()
model_pre_drop.fit(X_train_scaled, y_train)

#predict on the test set
y_pred = model_pre_drop.predict(X_test_scaled)

#evaluate the model using 'mean squared error' (mse)
mse = mean_squared_error(y_test, y_pred)

#outputs
print(f"Mean Squared Error: {mse:.5f}")
print(f"Intercept: {model_pre_drop.intercept_}")
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test, y_pred)
print(f"Root Mean Squared Error (RMSE): {rmse}")
print(f"Mean Absolute Error (MAE): {mae}")

#keep original feature names
X_train_scaled_df = pd.DataFrame(X_train_scaled, columns=X_train.columns, index=X_train.index)

#add intercept
X_train_sm = sm.add_constant(X_train_scaled_df)

#fit the model and print summary
ols_model_pre_drop = sm.OLS(y_train, X_train_sm).fit()
print(ols_model_pre_drop.summary())
# Out:
# Mean Squared Error: 0.00280
# Intercept: 0.11795524534183364
# Root Mean Squared Error (RMSE): 0.05291945792159974
# Mean Absolute Error (MAE): 0.03050937439658329
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         discharge_rate   R-squared:                       0.583
# Model:                            OLS   Adj. R-squared:                  0.562
# Method:                 Least Squares   F-statistic:                     28.85
# Date:                Sat, 17 May 2025   Prob (F-statistic):           5.77e-31
# Time:                        20:51:41   Log-Likelihood:                 329.98
# No. Observations:                 196   AIC:                            -640.0
# Df Residuals:                     186   BIC:                            -607.2
# Df Model:                           9
# Covariance Type:            nonrobust
# ===============================================================================================================================================
#                                                                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------------------------------------------
# const                                                                           0.1180      0.003     35.800      0.000       0.111       0.124
# Year                                                                            0.0164      0.004      4.371      0.000       0.009       0.024
# Month                                                                           0.0151      0.004      4.003      0.000       0.008       0.023
# ISHMT_Asthma (J45-J46)                                                          0.0159      0.004      3.602      0.000       0.007       0.025
# ISHMT_Chronic obstructive pulmonary disease & bronchiectasis (J40-J44, J47)     0.0474      0.004     10.696      0.000       0.039       0.056
# ISHMT_Other acute lower respiratory infections (J20-J22)                        0.0236      0.004      5.433      0.000       0.015       0.032
# ISHMT_Other diseases of the respiratory system (J60-J99)                        0.0354      0.005      7.862      0.000       0.027       0.044
# ISHMT_Other diseases of upper respiratory tract (J30-J34, J36-J39)              0.0196      0.004      4.552      0.000       0.011       0.028
# ISHMT_Pneumonia (J12-J18)                                                       0.0546      0.004     12.215      0.000       0.046       0.063
# County_Dublin                                                                   0.0122      0.003      3.701      0.000       0.006       0.019
# ==============================================================================
# Omnibus:                      182.056   Durbin-Watson:                   1.988
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             5480.573
# Skew:                           3.316   Prob(JB):                         0.00
# Kurtosis:                      28.042   Cond. No.                         3.12
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
#feature importance from linear regression
feature_names = X.columns
coefficients = model_pre_drop.coef_

#show it on a plot
plt.figure(figsize=(10, 6))
plt.barh(feature_names, coefficients)
plt.title("Feature Importance (Linear Regression Coefficients)")
plt.xlabel("Coefficient Value")
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Build for mydata_post_feb2022 (after end of the COVID restrictions)

# %%
mydata = mydata_post_feb2022

#get rid of date it is not needed
mydata = mydata.drop(columns=['date'])

#sort X (features) and y (target)
X = mydata.drop(columns=['discharge_rate'])
y = mydata['discharge_rate']

#split the data into train and test 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

#normalise the data - and fit to train and test data
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

#train the model
model_post = LinearRegression()
model_post.fit(X_train_scaled, y_train)

#predict on the test set
y_pred = model_post.predict(X_test_scaled)

#evaluate the model using 'mean squared error' (mse)
mse = mean_squared_error(y_test, y_pred)

#outputs
print(f"Mean Squared Error: {mse:.5f}")
print(f"Intercept: {model_post.intercept_}")
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test, y_pred)
print(f"Root Mean Squared Error (RMSE): {rmse}")
print(f"Mean Absolute Error (MAE): {mae}")

#keep original feature names
X_train_scaled_df = pd.DataFrame(X_train_scaled, columns=X_train.columns, index=X_train.index)

#add intercept
X_train_sm = sm.add_constant(X_train_scaled_df)

#fit the model and print summary
ols_model_post = sm.OLS(y_train, X_train_sm).fit()
print(ols_model_post.summary())
# Out:
# Mean Squared Error: 0.00180
# Intercept: 0.1531331907022218
# Root Mean Squared Error (RMSE): 0.04244313022210622
# Mean Absolute Error (MAE): 0.030136770799140823
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         discharge_rate   R-squared:                       0.557
# Model:                            OLS   Adj. R-squared:                  0.536
# Method:                 Least Squares   F-statistic:                     26.92
# Date:                Sat, 17 May 2025   Prob (F-statistic):           8.51e-33
# Time:                        20:51:43   Log-Likelihood:                 381.07
# No. Observations:                 225   AIC:                            -740.1
# Df Residuals:                     214   BIC:                            -702.6
# Df Model:                          10
# Covariance Type:            nonrobust
# ===============================================================================================================================================
#                                                                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------------------------------------------
# const                                                                           0.1531      0.003     50.355      0.000       0.147       0.159
# Year                                                                            0.0116      0.003      3.764      0.000       0.006       0.018
# Month                                                                           0.0095      0.003      3.100      0.002       0.003       0.016
# PM2.5                                                                           0.0119      0.003      3.871      0.000       0.006       0.018
# ISHMT_Asthma (J45-J46)                                                         -0.0015      0.004     -0.363      0.717      -0.009       0.006
# ISHMT_Chronic obstructive pulmonary disease & bronchiectasis (J40-J44, J47)     0.0379      0.004      9.394      0.000       0.030       0.046
# ISHMT_Other acute lower respiratory infections (J20-J22)                        0.0288      0.004      7.159      0.000       0.021       0.037
# ISHMT_Other diseases of the respiratory system (J60-J99)                        0.0142      0.004      3.480      0.001       0.006       0.022
# ISHMT_Other diseases of upper respiratory tract (J30-J34, J36-J39)              0.0073      0.004      1.787      0.075      -0.001       0.015
# ISHMT_Pneumonia (J12-J18)                                                       0.0367      0.004      9.036      0.000       0.029       0.045
# County_Dublin                                                                   0.0138      0.003      4.529      0.000       0.008       0.020
# ==============================================================================
# Omnibus:                      104.956   Durbin-Watson:                   1.844
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              490.369
# Skew:                           1.844   Prob(JB):                    3.29e-107
# Kurtosis:                       9.221   Cond. No.                         2.83
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
#feature importance from linear regression
feature_names = X.columns
coefficients = model_post.coef_

#show it on a plot
plt.figure(figsize=(10, 6))
plt.barh(feature_names, coefficients)
plt.title("Feature Importance (Linear Regression Coefficients)")
plt.xlabel("Coefficient Value")
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### Drop the non-significant features

# %%
#get rid of pm2.5 and pm10 for the COVID version
mydata = mydata_post_feb2022.drop(columns=['ISHMT_Asthma (J45-J46)'])

#get rid of date it is not needed
mydata = mydata.drop(columns=['date'])

#sort X (features) and y (target)
X = mydata.drop(columns=['discharge_rate'])
y = mydata['discharge_rate']

#split the data into train and test 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

#normalise the data - and fit to train and test data
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

#train the model
model_post_drop = LinearRegression()
model_post_drop.fit(X_train_scaled, y_train)

#predict on the test set
y_pred = model_post_drop.predict(X_test_scaled)

#evaluate the model using 'mean squared error' (mse)
mse = mean_squared_error(y_test, y_pred)

#outputs
print(f"Mean Squared Error: {mse:.5f}")
print(f"Intercept: {model_post_drop.intercept_}")
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test, y_pred)
print(f"Root Mean Squared Error (RMSE): {rmse}")
print(f"Mean Absolute Error (MAE): {mae}")

#keep original feature names
X_train_scaled_df = pd.DataFrame(X_train_scaled, columns=X_train.columns, index=X_train.index)

#add intercept
X_train_sm = sm.add_constant(X_train_scaled_df)

#fit the model and print summary
ols_model_post_drop = sm.OLS(y_train, X_train_sm).fit()
print(ols_model_post_drop.summary())
# Out:
# Mean Squared Error: 0.00180
# Intercept: 0.1531331907022218
# Root Mean Squared Error (RMSE): 0.04248180368921081
# Mean Absolute Error (MAE): 0.029957047061656063
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         discharge_rate   R-squared:                       0.557
# Model:                            OLS   Adj. R-squared:                  0.538
# Method:                 Least Squares   F-statistic:                     30.01
# Date:                Sat, 17 May 2025   Prob (F-statistic):           1.60e-33
# Time:                        20:52:04   Log-Likelihood:                 381.00
# No. Observations:                 225   AIC:                            -742.0
# Df Residuals:                     215   BIC:                            -707.8
# Df Model:                           9
# Covariance Type:            nonrobust
# ===============================================================================================================================================
#                                                                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------------------------------------------
# const                                                                           0.1531      0.003     50.457      0.000       0.147       0.159
# Year                                                                            0.0116      0.003      3.785      0.000       0.006       0.018
# Month                                                                           0.0095      0.003      3.091      0.002       0.003       0.016
# PM2.5                                                                           0.0119      0.003      3.883      0.000       0.006       0.018
# ISHMT_Chronic obstructive pulmonary disease & bronchiectasis (J40-J44, J47)     0.0386      0.003     11.129      0.000       0.032       0.045
# ISHMT_Other acute lower respiratory infections (J20-J22)                        0.0296      0.003      8.531      0.000       0.023       0.036
# ISHMT_Other diseases of the respiratory system (J60-J99)                        0.0149      0.004      4.257      0.000       0.008       0.022
# ISHMT_Other diseases of upper respiratory tract (J30-J34, J36-J39)              0.0081      0.003      2.305      0.022       0.001       0.015
# ISHMT_Pneumonia (J12-J18)                                                       0.0375      0.003     10.735      0.000       0.031       0.044
# County_Dublin                                                                   0.0138      0.003      4.545      0.000       0.008       0.020
# ==============================================================================
# Omnibus:                      107.544   Durbin-Watson:                   1.842
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              519.765
# Skew:                           1.884   Prob(JB):                    1.36e-113
# Kurtosis:                       9.422   Cond. No.                         2.00
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
#0.538 looks ok on OLS model on full data but on cross validation its not generalising properly..
#looks like this is not a linear model (and maybe too many dummy variables are the issue with the ISHMT categories)

# %%
#look at residuals  vs predicted (check for homoscedasity and patterns)
residuals = y_test - y_pred
plt.figure(figsize=(8, 5))
sns.scatterplot(x=y_pred, y=residuals)
plt.axhline(0, color='red', linestyle='--')
plt.xlabel("Predicted Values")
plt.ylabel("Residuals")
plt.title("Residuals vs Predicted")
plt.grid(True)
plt.show()

# %%
#plot qq plot of residuals
residuals = ols_model_post_drop.resid
sm.qqplot(residuals, line='45', fit=True)
plt.title('Q-Q Plot of Regression Residuals')
plt.show()

# %%
#plot histogram of residuals
plt.figure(figsize=(8, 5))
sns.histplot(residuals, kde=True, bins=30)
plt.title("Histogram of Residuals")
plt.xlabel("Residual")
plt.grid(True)
plt.show()

# %%
#add intercept
X_train_sm = sm.add_constant(X_train_scaled_df)

#fit the OLS model
ols_model_post_drop = sm.OLS(y_train, X_train_sm).fit()
influence = ols_model_post_drop.get_influence()
cooks_d = influence.cooks_distance[0]

#plot Cook's Distance
plt.figure(figsize=(8, 6))
plt.stem(np.arange(len(cooks_d)), cooks_d, markerfmt=",", basefmt=" ")
plt.title("Cook's Distance")
plt.xlabel("Data point index")
plt.ylabel("Cook's Distance")
plt.show()

# %%
#features and targets (going to predict on year and look at pm2.5 and discharge_rate
X = mydata[['Year']]
y_pm25 = mydata['PM2.5']
y_discharge = mydata['discharge_rate']

#train and test split
X_train, X_test, y_train_pm25, y_test_pm25 = train_test_split(X, y_pm25, test_size=0.3, random_state=42)
X_train, X_test, y_train_discharge, y_test_discharge = train_test_split(X, y_discharge, test_size=0.3, random_state=42)

#train the model for PM2.5
pm25_model = LinearRegression()
pm25_model.fit(X_train, y_train_pm25)

#train the model for discharge_rate
discharge_model = LinearRegression()
discharge_model.fit(X_train, y_train_discharge)

#predict for 2035
year_2035 = np.array([[2035]])
pm25_2035 = pm25_model.predict(year_2035)
discharge_2035 = discharge_model.predict(year_2035)

#print predictions
print(f"Predicted PM2.5 level in 2035: {pm25_2035[0]:.2f}")
print(f"Predicted Discharge Rate in 2035: {discharge_2035[0]:.2f}")

#plot
plt.figure(figsize=(10, 5))

#PM2.5 prediction plot
plt.subplot(1, 2, 1)
plt.scatter(mydata['Year'], mydata['PM2.5'], color='blue', label='Actual Data')
plt.plot(mydata['Year'], pm25_model.predict(mydata[['Year']]), color='red', label='Linear Regression Model')
plt.xlabel('Year')
plt.ylabel('PM2.5 Level')
plt.title('PM2.5 Level Over Time')
plt.xticks(rotation=45)
plt.legend()

#discharge_rate prediction plot
plt.subplot(1, 2, 2)
plt.scatter(mydata['Year'], mydata['discharge_rate'], color='green', label='Actual Data')
plt.plot(mydata['Year'], discharge_model.predict(mydata[['Year']]), color='orange', label='Linear Regression Model')
plt.xlabel('Year')
plt.ylabel('Discharge Rate')
plt.title('Discharge Rate Over Time')
plt.legend()
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()
# Out:
# C:\Users\lsmyth\AppData\Local\anaconda\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\lsmyth\AppData\Local\anaconda\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# Predicted PM2.5 level in 2035: 3.21
# Predicted Discharge Rate in 2035: 0.41

# %% [markdown]
# ### Don't separate for COVID

# %%
mydata_model_tog = mydata_2022_encoded

#get rid of date it is not needed
mydata_model_tog = mydata_model_tog.drop(columns=['date'])

#sort X (features) and y (target)
X = mydata_model_tog.drop(columns=['discharge_rate'])
y = mydata_model_tog['discharge_rate']

#split the data into train and test 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

#normalise the data - and fit to train and test data
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

#train the model
model_full = LinearRegression()
model_full.fit(X_train_scaled, y_train)

#predict on the test set
y_pred = model_full.predict(X_test_scaled)

#evaluate the model using 'mean squared error' (mse)
mse = mean_squared_error(y_test, y_pred)

#outputs
print(f"Mean Squared Error: {mse:.5f}")
print(f"Intercept: {model_full.intercept_}")
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test, y_pred)
print(f"Root Mean Squared Error (RMSE): {rmse}")
print(f"Mean Absolute Error (MAE): {mae}")

#keep original feature names
X_train_scaled_df = pd.DataFrame(X_train_scaled, columns=X_train.columns, index=X_train.index)

#add intercept
X_train_sm = sm.add_constant(X_train_scaled_df)

#fit the model and print summary
ols_model_full = sm.OLS(y_train, X_train_sm).fit()
print(ols_model_full.summary())
# Out:
# Mean Squared Error: 0.00253
# Intercept: 0.13310576836104587
# Root Mean Squared Error (RMSE): 0.05034695852413654
# Mean Absolute Error (MAE): 0.03396019385815539
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         discharge_rate   R-squared:                       0.541
# Model:                            OLS   Adj. R-squared:                  0.529
# Method:                 Least Squares   F-statistic:                     48.27
# Date:                Sat, 17 May 2025   Prob (F-statistic):           3.61e-63
# Time:                        20:52:29   Log-Likelihood:                 695.37
# No. Observations:                 421   AIC:                            -1369.
# Df Residuals:                     410   BIC:                            -1324.
# Df Model:                          10
# Covariance Type:            nonrobust
# ===============================================================================================================================================
#                                                                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------------------------------------------
# const                                                                           0.1331      0.002     58.097      0.000       0.129       0.138
# Year                                                                            0.0247      0.002     10.527      0.000       0.020       0.029
# Month                                                                           0.0115      0.002      4.775      0.000       0.007       0.016
# PM2.5                                                                           0.0060      0.002      2.511      0.012       0.001       0.011
# ISHMT_Asthma (J45-J46)                                                          0.0053      0.003      1.736      0.083      -0.001       0.011
# ISHMT_Chronic obstructive pulmonary disease & bronchiectasis (J40-J44, J47)     0.0411      0.003     13.306      0.000       0.035       0.047
# ISHMT_Other acute lower respiratory infections (J20-J22)                        0.0232      0.003      7.443      0.000       0.017       0.029
# ISHMT_Other diseases of the respiratory system (J60-J99)                        0.0217      0.003      6.984      0.000       0.016       0.028
# ISHMT_Other diseases of upper respiratory tract (J30-J34, J36-J39)              0.0143      0.003      4.537      0.000       0.008       0.021
# ISHMT_Pneumonia (J12-J18)                                                       0.0419      0.003     13.810      0.000       0.036       0.048
# County_Dublin                                                                   0.0131      0.002      5.693      0.000       0.009       0.018
# ==============================================================================
# Omnibus:                      297.627   Durbin-Watson:                   2.082
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4738.007
# Skew:                           2.831   Prob(JB):                         0.00
# Kurtosis:                      18.428   Cond. No.                         3.01
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
#get rid of pm2.5 and pm10 for the COVID version
mydata_model_tog = mydata_2022_encoded.drop(columns=['ISHMT_Asthma (J45-J46)'])

#get rid of date it is not needed
mydata_model_tog = mydata_model_tog.drop(columns=['date'])

#sort X (features) and y (target)
X = mydata_model_tog.drop(columns=['discharge_rate'])
y = mydata_model_tog['discharge_rate']

#split the data into train and test 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

#normalise the data - and fit to train and test data
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

#train the model
model_full = LinearRegression()
model_full.fit(X_train_scaled, y_train)

#predict on the test set
y_pred = model_full.predict(X_test_scaled)

#evaluate the model using 'mean squared error' (mse)
mse = mean_squared_error(y_test, y_pred)

#outputs
print(f"Mean Squared Error: {mse:.5f}")
print(f"Intercept: {model_full.intercept_}")
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test, y_pred)
print(f"Root Mean Squared Error (RMSE): {rmse}")
print(f"Mean Absolute Error (MAE): {mae}")

#keep original feature names
X_train_scaled_df = pd.DataFrame(X_train_scaled, columns=X_train.columns, index=X_train.index)

#add intercept
X_train_sm = sm.add_constant(X_train_scaled_df)

#fit the model and print summary
ols_model_full_drop = sm.OLS(y_train, X_train_sm).fit()
print(ols_model_full_drop.summary())
# Out:
# Mean Squared Error: 0.00258
# Intercept: 0.1331057683610459
# Root Mean Squared Error (RMSE): 0.05075260695514814
# Mean Absolute Error (MAE): 0.034868153688396616
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         discharge_rate   R-squared:                       0.537
# Model:                            OLS   Adj. R-squared:                  0.527
# Method:                 Least Squares   F-statistic:                     53.03
# Date:                Sat, 17 May 2025   Prob (F-statistic):           2.10e-63
# Time:                        20:52:30   Log-Likelihood:                 693.83
# No. Observations:                 421   AIC:                            -1368.
# Df Residuals:                     411   BIC:                            -1327.
# Df Model:                           9
# Covariance Type:            nonrobust
# ===============================================================================================================================================
#                                                                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------------------------------------------
# const                                                                           0.1331      0.002     57.956      0.000       0.129       0.138
# Year                                                                            0.0250      0.002     10.641      0.000       0.020       0.030
# Month                                                                           0.0116      0.002      4.812      0.000       0.007       0.016
# PM2.5                                                                           0.0060      0.002      2.510      0.012       0.001       0.011
# ISHMT_Chronic obstructive pulmonary disease & bronchiectasis (J40-J44, J47)     0.0383      0.003     14.500      0.000       0.033       0.043
# ISHMT_Other acute lower respiratory infections (J20-J22)                        0.0204      0.003      7.674      0.000       0.015       0.026
# ISHMT_Other diseases of the respiratory system (J60-J99)                        0.0188      0.003      7.121      0.000       0.014       0.024
# ISHMT_Other diseases of upper respiratory tract (J30-J34, J36-J39)              0.0114      0.003      4.264      0.000       0.006       0.017
# ISHMT_Pneumonia (J12-J18)                                                       0.0393      0.003     14.989      0.000       0.034       0.044
# County_Dublin                                                                   0.0132      0.002      5.721      0.000       0.009       0.018
# ==============================================================================
# Omnibus:                      287.634   Durbin-Watson:                   2.075
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4326.068
# Skew:                           2.717   Prob(JB):                         0.00
# Kurtosis:                      17.734   Cond. No.                         2.08
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
#compare models
models = {
    "Model Covid": ols_model_pre,
    "Model Covid Reduced": ols_model_pre_drop,
    "Model Post Covid": ols_model_post,
    "Model Post Covid Reduced": ols_model_post_drop,
    "Model Full": ols_model_full,
    "Model Full Reduced": ols_model_full_drop
}

results = []

for name, model in models.items():
    results.append({
        'Model': name,
        'R-squared': model.rsquared,
        'Adj. R-squared': model.rsquared_adj,
        'AIC': model.aic,
        'BIC': model.bic,
        'F-statistic': model.fvalue,
        'F-test p-value': model.f_pvalue
    })

df_results = pd.DataFrame(results)
print(df_results.sort_values(by='Adj. R-squared', ascending=False))
# Out:
#                       Model  R-squared  Adj. R-squared          AIC          BIC  F-statistic  F-test p-value
# 1       Model Covid Reduced   0.582611        0.562415  -639.961731  -607.180585    28.847514    5.768681e-31
# 0               Model Covid   0.583003        0.560462  -638.145654  -602.086393    25.864789    2.944169e-30
# 3  Model Post Covid Reduced   0.556816        0.538264  -741.991822  -707.830818    30.013966    1.602184e-33
# 2          Model Post Covid   0.557089        0.536392  -740.130653  -702.553548    26.916733    8.506834e-33
# 4                Model Full   0.540695        0.529492 -1368.742322 -1324.273361    48.265247    3.611051e-63
# 5        Model Full Reduced   0.537320        0.527188 -1367.660219 -1327.233891    53.033625    2.104389e-63

# %%
print(ols_model_full_drop.params)
# Out:
# const                                                                          0.133106
# Year                                                                           0.024972
# Month                                                                          0.011635
# PM2.5                                                                          0.005975
# ISHMT_Chronic obstructive pulmonary disease & bronchiectasis (J40-J44, J47)    0.038280
# ISHMT_Other acute lower respiratory infections (J20-J22)                       0.020367
# ISHMT_Other diseases of the respiratory system (J60-J99)                       0.018842
# ISHMT_Other diseases of upper respiratory tract (J30-J34, J36-J39)             0.011381
# ISHMT_Pneumonia (J12-J18)                                                      0.039257
# County_Dublin                                                                  0.013225
# dtype: float64

# %%
#create model equation function
def print_model_equation(model, model_name="Model"):
    terms = [f"{coef:.4f}*{var}" if var != 'const' else f"{coef:.4f}"
             for var, coef in model.params.items()]
    equation = " + ".join(terms)
    print(f"{model_name}: discharge_rate = {equation}")
    print('\n')

# %%
#print equations
print_model_equation(ols_model_pre, "Model Covid")
print_model_equation(ols_model_pre_drop, "Model Covid Reduced")
print_model_equation(ols_model_post, "Model Post Covid")
print_model_equation(ols_model_post_drop, "Model Post Covid Reduced")
print_model_equation(ols_model_full, "Model Full Dataset")
print_model_equation(ols_model_full_drop, "Model Full Dataset Reduced")
# Out:
# Model Covid: discharge_rate = 0.1180 + 0.0170*Year + 0.0148*Month + -0.0016*PM2.5 + 0.0160*ISHMT_Asthma (J45-J46) + 0.0476*ISHMT_Chronic obstructive pulmonary disease & bronchiectasis (J40-J44, J47) + 0.0237*ISHMT_Other acute lower respiratory infections (J20-J22) + 0.0357*ISHMT_Other diseases of the respiratory system (J60-J99) + 0.0198*ISHMT_Other diseases of upper respiratory tract (J30-J34, J36-J39) + 0.0547*ISHMT_Pneumonia (J12-J18) + 0.0123*County_Dublin
#
#
# Model Covid Reduced: discharge_rate = 0.1180 + 0.0164*Year + 0.0151*Month + 0.0159*ISHMT_Asthma (J45-J46) + 0.0474*ISHMT_Chronic obstructive pulmonary disease & bronchiectasis (J40-J44, J47) + 0.0236*ISHMT_Other acute lower respiratory infections (J20-J22) + 0.0354*ISHMT_Other diseases of the respiratory system (J60-J99) + 0.0196*ISHMT_Other diseases of upper respiratory tract (J30-J34, J36-J39) + 0.0546*ISHMT_Pneumonia (J12-J18) + 0.0122*County_Dublin
#
#
# Model Post Covid: discharge_rate = 0.1531 + 0.0116*Year + 0.0095*Month + 0.0119*PM2.5 + -0.0015*ISHMT_Asthma (J45-J46) + 0.0379*ISHMT_Chronic obstructive pulmonary disease & bronchiectasis (J40-J44, J47) + 0.0288*ISHMT_Other acute lower respiratory infections (J20-J22) + 0.0142*ISHMT_Other diseases of the respiratory system (J60-J99) + 0.0073*ISHMT_Other diseases of upper respiratory tract (J30-J34, J36-J39) + 0.0367*ISHMT_Pneumonia (J12-J18) + 0.0138*County_Dublin
#
#
# Model Post Covid Reduced: discharge_rate = 0.1531 + 0.0116*Year + 0.0095*Month + 0.0119*PM2.5 + 0.0386*ISHMT_Chronic obstructive pulmonary disease & bronchiectasis (J40-J44, J47) + 0.0296*ISHMT_Other acute lower respiratory infections (J20-J22) + 0.0149*ISHMT_Other diseases of the respiratory system (J60-J99) + 0.0081*ISHMT_Other diseases of upper respiratory tract (J30-J34, J36-J39) + 0.0375*ISHMT_Pneumonia (J12-J18) + 0.0138*County_Dublin
#
#
# Model Full Dataset: discharge_rate = 0.1331 + 0.0247*Year + 0.0115*Month + 0.0060*PM2.5 + 0.0053*ISHMT_Asthma (J45-J46) + 0.0411*ISHMT_Chronic obstructive pulmonary disease & bronchiectasis (J40-J44, J47) + 0.0232*ISHMT_Other acute lower respiratory infections (J20-J22) + 0.0217*ISHMT_Other diseases of the respiratory system (J60-J99) + 0.0143*ISHMT_Other diseases of upper respiratory tract (J30-J34, J36-J39) + 0.0419*ISHMT_Pneumonia (J12-J18) + 0.0131*County_Dublin
#
#
# Model Full Dataset Reduced: discharge_rate = 0.1331 + 0.0250*Year + 0.0116*Month + 0.0060*PM2.5 + 0.0383*ISHMT_Chronic obstructive pulmonary disease & bronchiectasis (J40-J44, J47) + 0.0204*ISHMT_Other acute lower respiratory infections (J20-J22) + 0.0188*ISHMT_Other diseases of the respiratory system (J60-J99) + 0.0114*ISHMT_Other diseases of upper respiratory tract (J30-J34, J36-J39) + 0.0393*ISHMT_Pneumonia (J12-J18) + 0.0132*County_Dublin
